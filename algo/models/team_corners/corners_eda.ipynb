# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect(r'C:\Users\Owner\dev\algobetting\infra\data\db\algobetting.db')

df = pd.read_sql_query("""
                        SELECT 
                            *
                        FROM 
                            fbref_match_summary_v2 f
                       """, conn)

df
# Out:
#                team  is_home  match_date        division     season  \
# 0         Tottenham        1  2025-05-25  Premier League  2024-2025
# 1          Brighton        0  2025-05-25  Premier League  2024-2025
# 2       Bournemouth        1  2025-05-25  Premier League  2024-2025
# 3    Leicester City        0  2025-05-25  Premier League  2024-2025
# 4     Newcastle Utd        1  2025-05-25  Premier League  2024-2025
# ..              ...      ...         ...             ...        ...
# 755     Southampton        0  2024-08-17  Premier League  2024-2025
# 756    Ipswich Town        1  2024-08-17  Premier League  2024-2025
# 757       Liverpool        0  2024-08-17  Premier League  2024-2025
# 758  Manchester Utd        1  2024-08-16  Premier League  2024-2025
# 759          Fulham        0  2024-08-16  Premier League  2024-2025
#
#                                              match_url summary_minutes  \
# 0    https://fbref.com/en/matches/e4bb1c35/Tottenha...             990
# 1    https://fbref.com/en/matches/e4bb1c35/Tottenha...             990
# 2    https://fbref.com/en/matches/1ff370e8/Bournemo...             990
# 3    https://fbref.com/en/matches/1ff370e8/Bournemo...             990
# 4    https://fbref.com/en/matches/36844e73/Newcastl...             990
# ..                                                 ...             ...
# 755  https://fbref.com/en/matches/34557647/Newcastl...             990
# 756  https://fbref.com/en/matches/a1d0d529/Ipswich-...             990
# 757  https://fbref.com/en/matches/a1d0d529/Ipswich-...             990
# 758  https://fbref.com/en/matches/cc5b4244/Manchest...             990
# 759  https://fbref.com/en/matches/cc5b4244/Manchest...             990
#
#      summary_goals summary_assists summary_pens_made  ...  \
# 0              1.0               0                 1  ...
# 1              4.0               1                 1  ...
# 2              2.0               2                 0  ...
# 3              0.0               0                 0  ...
# 4              0.0               0                 0  ...
# ..             ...             ...               ...  ...
# 755            0.0               0                 0  ...
# 756            0.0               0                 0  ...
# 757            2.0               1                 0  ...
# 758            1.0               1                 0  ...
# 759            0.0               0                 0  ...
#
#     opp_defense_challenges  opp_defense_challenge_tackles_pct  \
# 0                       11                               63.6
# 1                       15                               33.3
# 2                       19                               47.4
# 3                       10                               50.0
# 4                       12                               58.3
# ..                     ...                                ...
# 755                     13                               53.8
# 756                      8                               62.5
# 757                     22                               50.0
# 758                     19                               57.9
# 759                     20                               60.0
#
#      opp_defense_challenges_lost  opp_defense_blocks  \
# 0                              4                  12
# 1                             10                  11
# 2                             10                  14
# 3                              5                   4
# 4                              5                   6
# ..                           ...                 ...
# 755                            6                  24
# 756                            3                  14
# 757                           11                  15
# 758                            8                   9
# 759                            8                  11
#
#      opp_defense_blocked_shots  opp_defense_blocked_passes  \
# 0                          1.0                          11
# 1                          7.0                           4
# 2                          6.0                           8
# 3                          0.0                           4
# 4                          4.0                           2
# ..                         ...                         ...
# 755                       11.0                          13
# 756                        2.0                          12
# 757                        6.0                           9
# 758                        2.0                           7
# 759                        3.0                           8
#
#     opp_defense_interceptions opp_defense_tackles_interceptions  \
# 0                           7                                25
# 1                          11                                24
# 2                           6                                24
# 3                           7                                22
# 4                          14                                27
# ..                        ...                               ...
# 755                         4                                20
# 756                         5                                14
# 757                         9                                29
# 758                         9                                33
# 759                        19                                40
#
#     opp_defense_clearances  opp_defense_errors
# 0                        8                   0
# 1                       41                   1
# 2                       31                   1
# 3                       11                   0
# 4                       23                   0
# ..                     ...                 ...
# 755                     39                   0
# 756                     17                   1
# 757                     28                   0
# 758                     18                   2
# 759                     22                   0
#
# [760 rows x 235 columns]

# %%
for col in df.select_dtypes(include=['object']).columns:
    # Try converting a sample
    sample_converted = pd.to_numeric(df[col].dropna().head(), errors='coerce')
    if not sample_converted.isna().all():
        print(f"Column '{col}' can be converted to numeric")
        df[col] = pd.to_numeric(df[col], errors='coerce')
# Out:
# Column 'summary_minutes' can be converted to numeric
# Column 'summary_assists' can be converted to numeric
# Column 'summary_pens_made' can be converted to numeric
# Column 'summary_pens_att' can be converted to numeric
# Column 'summary_tackles' can be converted to numeric
# Column 'summary_interceptions' can be converted to numeric
# Column 'summary_blocks' can be converted to numeric
# Column 'summary_sca' can be converted to numeric
# Column 'summary_gca' can be converted to numeric
# Column 'summary_passes_completed' can be converted to numeric
# Column 'summary_passes' can be converted to numeric
# Column 'summary_passes_pct' can be converted to numeric
# Column 'summary_progressive_passes' can be converted to numeric
# Column 'summary_carries' can be converted to numeric
# Column 'summary_progressive_carries' can be converted to numeric
# Column 'summary_take_ons' can be converted to numeric
# Column 'summary_take_ons_won' can be converted to numeric
# Column 'possession_minutes' can be converted to numeric
# Column 'possession_take_ons' can be converted to numeric
# Column 'possession_take_ons_won' can be converted to numeric
# Column 'possession_take_ons_won_pct' can be converted to numeric
# Column 'possession_take_ons_tackled' can be converted to numeric
# Column 'possession_take_ons_tackled_pct' can be converted to numeric
# Column 'possession_carries' can be converted to numeric
# Column 'possession_carries_distance' can be converted to numeric
# Column 'possession_carries_progressive_distance' can be converted to numeric
# Column 'possession_progressive_carries' can be converted to numeric
# Column 'possession_carries_into_final_third' can be converted to numeric
# Column 'possession_carries_into_penalty_area' can be converted to numeric
# Column 'possession_miscontrols' can be converted to numeric
# Column 'possession_dispossessed' can be converted to numeric
# Column 'possession_passes_received' can be converted to numeric
# Column 'possession_progressive_passes_received' can be converted to numeric
# Column 'misc_minutes' can be converted to numeric
# Column 'misc_fouls' can be converted to numeric
# Column 'misc_fouled' can be converted to numeric
# Column 'misc_offsides' can be converted to numeric
# Column 'misc_crosses' can be converted to numeric
# Column 'misc_interceptions' can be converted to numeric
# Column 'misc_tackles_won' can be converted to numeric
# Column 'misc_pens_won' can be converted to numeric
# Column 'misc_pens_conceded' can be converted to numeric
# Column 'misc_ball_recoveries' can be converted to numeric
# Column 'misc_aerials_won' can be converted to numeric
# Column 'misc_aerials_lost' can be converted to numeric
# Column 'misc_aerials_won_pct' can be converted to numeric
# Column 'pass_types_minutes' can be converted to numeric
# Column 'pass_types_passes' can be converted to numeric
# Column 'pass_types_passes_live' can be converted to numeric
# Column 'pass_types_passes_dead' can be converted to numeric
# Column 'pass_types_passes_free_kicks' can be converted to numeric
# Column 'pass_types_through_balls' can be converted to numeric
# Column 'pass_types_passes_switches' can be converted to numeric
# Column 'pass_types_crosses' can be converted to numeric
# Column 'pass_types_throw_ins' can be converted to numeric
# Column 'pass_types_corner_kicks' can be converted to numeric
# Column 'pass_types_corner_kicks_in' can be converted to numeric
# Column 'pass_types_corner_kicks_out' can be converted to numeric
# Column 'pass_types_corner_kicks_straight' can be converted to numeric
# Column 'pass_types_passes_completed' can be converted to numeric
# Column 'pass_types_passes_offsides' can be converted to numeric
# Column 'pass_types_passes_blocked' can be converted to numeric
# Column 'passing_minutes' can be converted to numeric
# Column 'passing_passes' can be converted to numeric
# Column 'passing_passes_live' can be converted to numeric
# Column 'passing_passes_dead' can be converted to numeric
# Column 'passing_passes_free_kicks' can be converted to numeric
# Column 'passing_through_balls' can be converted to numeric
# Column 'passing_passes_switches' can be converted to numeric
# Column 'passing_crosses' can be converted to numeric
# Column 'passing_throw_ins' can be converted to numeric
# Column 'passing_corner_kicks' can be converted to numeric
# Column 'passing_corner_kicks_in' can be converted to numeric
# Column 'passing_corner_kicks_out' can be converted to numeric
# Column 'passing_corner_kicks_straight' can be converted to numeric
# Column 'passing_passes_completed' can be converted to numeric
# Column 'passing_passes_offsides' can be converted to numeric
# Column 'passing_passes_blocked' can be converted to numeric
# Column 'defense_minutes' can be converted to numeric
# Column 'defense_tackles' can be converted to numeric
# Column 'defense_tackles_won' can be converted to numeric
# Column 'defense_tackles_def_3rd' can be converted to numeric
# Column 'defense_tackles_mid_3rd' can be converted to numeric
# Column 'defense_tackles_att_3rd' can be converted to numeric
# Column 'defense_challenge_tackles' can be converted to numeric
# Column 'defense_challenges' can be converted to numeric
# Column 'defense_challenge_tackles_pct' can be converted to numeric
# Column 'defense_challenges_lost' can be converted to numeric
# Column 'defense_blocks' can be converted to numeric
# Column 'defense_blocked_passes' can be converted to numeric
# Column 'defense_interceptions' can be converted to numeric
# Column 'defense_tackles_interceptions' can be converted to numeric
# Column 'defense_clearances' can be converted to numeric
# Column 'defense_errors' can be converted to numeric
# Column 'opp_summary_minutes' can be converted to numeric
# Column 'opp_summary_assists' can be converted to numeric
# Column 'opp_summary_pens_made' can be converted to numeric
# Column 'opp_summary_pens_att' can be converted to numeric
# Column 'opp_summary_tackles' can be converted to numeric
# Column 'opp_summary_interceptions' can be converted to numeric
# Column 'opp_summary_blocks' can be converted to numeric
# Column 'opp_summary_sca' can be converted to numeric
# Column 'opp_summary_gca' can be converted to numeric
# Column 'opp_summary_passes_completed' can be converted to numeric
# Column 'opp_summary_passes' can be converted to numeric
# Column 'opp_summary_passes_pct' can be converted to numeric
# Column 'opp_summary_progressive_passes' can be converted to numeric
# Column 'opp_summary_carries' can be converted to numeric
# Column 'opp_summary_progressive_carries' can be converted to numeric
# Column 'opp_summary_take_ons' can be converted to numeric
# Column 'opp_summary_take_ons_won' can be converted to numeric
# Column 'opp_possession_minutes' can be converted to numeric
# Column 'opp_possession_take_ons' can be converted to numeric
# Column 'opp_possession_take_ons_won' can be converted to numeric
# Column 'opp_possession_take_ons_won_pct' can be converted to numeric
# Column 'opp_possession_take_ons_tackled' can be converted to numeric
# Column 'opp_possession_take_ons_tackled_pct' can be converted to numeric
# Column 'opp_possession_carries' can be converted to numeric
# Column 'opp_possession_carries_distance' can be converted to numeric
# Column 'opp_possession_carries_progressive_distance' can be converted to numeric
# Column 'opp_possession_progressive_carries' can be converted to numeric
# Column 'opp_possession_carries_into_final_third' can be converted to numeric
# Column 'opp_possession_carries_into_penalty_area' can be converted to numeric
# Column 'opp_possession_miscontrols' can be converted to numeric
# Column 'opp_possession_dispossessed' can be converted to numeric
# Column 'opp_possession_passes_received' can be converted to numeric
# Column 'opp_possession_progressive_passes_received' can be converted to numeric
# Column 'opp_misc_minutes' can be converted to numeric
# Column 'opp_misc_fouls' can be converted to numeric
# Column 'opp_misc_fouled' can be converted to numeric
# Column 'opp_misc_offsides' can be converted to numeric
# Column 'opp_misc_crosses' can be converted to numeric
# Column 'opp_misc_interceptions' can be converted to numeric
# Column 'opp_misc_tackles_won' can be converted to numeric
# Column 'opp_misc_pens_won' can be converted to numeric
# Column 'opp_misc_pens_conceded' can be converted to numeric
# Column 'opp_misc_ball_recoveries' can be converted to numeric
# Column 'opp_misc_aerials_won' can be converted to numeric
# Column 'opp_misc_aerials_lost' can be converted to numeric
# Column 'opp_misc_aerials_won_pct' can be converted to numeric
# Column 'opp_pass_types_minutes' can be converted to numeric
# Column 'opp_pass_types_passes' can be converted to numeric
# Column 'opp_pass_types_passes_live' can be converted to numeric
# Column 'opp_pass_types_passes_dead' can be converted to numeric
# Column 'opp_pass_types_passes_free_kicks' can be converted to numeric
# Column 'opp_pass_types_through_balls' can be converted to numeric
# Column 'opp_pass_types_passes_switches' can be converted to numeric
# Column 'opp_pass_types_crosses' can be converted to numeric
# Column 'opp_pass_types_throw_ins' can be converted to numeric
# Column 'opp_pass_types_corner_kicks' can be converted to numeric
# Column 'opp_pass_types_corner_kicks_in' can be converted to numeric
# Column 'opp_pass_types_corner_kicks_out' can be converted to numeric
# Column 'opp_pass_types_corner_kicks_straight' can be converted to numeric
# Column 'opp_pass_types_passes_completed' can be converted to numeric
# Column 'opp_pass_types_passes_offsides' can be converted to numeric
# Column 'opp_pass_types_passes_blocked' can be converted to numeric
# Column 'opp_passing_minutes' can be converted to numeric
# Column 'opp_passing_passes' can be converted to numeric
# Column 'opp_passing_passes_live' can be converted to numeric
# Column 'opp_passing_passes_dead' can be converted to numeric
# Column 'opp_passing_passes_free_kicks' can be converted to numeric
# Column 'opp_passing_through_balls' can be converted to numeric
# Column 'opp_passing_passes_switches' can be converted to numeric
# Column 'opp_passing_crosses' can be converted to numeric
# Column 'opp_passing_throw_ins' can be converted to numeric
# Column 'opp_passing_corner_kicks' can be converted to numeric
# Column 'opp_passing_corner_kicks_in' can be converted to numeric
# Column 'opp_passing_corner_kicks_out' can be converted to numeric
# Column 'opp_passing_corner_kicks_straight' can be converted to numeric
# Column 'opp_passing_passes_completed' can be converted to numeric
# Column 'opp_passing_passes_offsides' can be converted to numeric
# Column 'opp_passing_passes_blocked' can be converted to numeric
# Column 'opp_defense_minutes' can be converted to numeric
# Column 'opp_defense_tackles' can be converted to numeric
# Column 'opp_defense_tackles_won' can be converted to numeric
# Column 'opp_defense_tackles_def_3rd' can be converted to numeric
# Column 'opp_defense_tackles_mid_3rd' can be converted to numeric
# Column 'opp_defense_tackles_att_3rd' can be converted to numeric
# Column 'opp_defense_challenge_tackles' can be converted to numeric
# Column 'opp_defense_challenges' can be converted to numeric
# Column 'opp_defense_challenge_tackles_pct' can be converted to numeric
# Column 'opp_defense_challenges_lost' can be converted to numeric
# Column 'opp_defense_blocks' can be converted to numeric
# Column 'opp_defense_blocked_passes' can be converted to numeric
# Column 'opp_defense_interceptions' can be converted to numeric
# Column 'opp_defense_tackles_interceptions' can be converted to numeric
# Column 'opp_defense_clearances' can be converted to numeric
# Column 'opp_defense_errors' can be converted to numeric

# %%
# Quick correlation screening
numeric_df = df.select_dtypes(include=['number'])
correlations = numeric_df.corr()["pass_types_corner_kicks"].abs().sort_values(ascending=False)
top_features = correlations
top_features = top_features[top_features > 0.5]

top_features
# Out:
# pass_types_corner_kicks                   1.000000
# passing_corner_kicks                      1.000000
# passing_corner_kicks_in                   0.759521
# pass_types_corner_kicks_in                0.759521
# pass_types_crosses                        0.682711
# misc_crosses                              0.682711
# passing_crosses                           0.682711
# possession_touches_att_pen_area           0.627374
# possession_touches_att_3rd                0.622814
# summary_progressive_passes                0.581169
# possession_progressive_passes_received    0.580000
# opp_possession_touches_def_pen_area       0.578577
# summary_shots                             0.549833
# summary_sca                               0.547465
# opp_defense_clearances                    0.536762
# opp_pass_types_passes                     0.524752
# opp_summary_passes                        0.524752
# opp_passing_passes                        0.524752
# opp_defense_blocked_shots                 0.524152
# opp_passing_passes_live                   0.519541
# opp_pass_types_passes_live                0.519541
# opp_passing_passes_completed              0.510318
# opp_pass_types_passes_completed           0.510318
# opp_summary_passes_completed              0.510318
# opp_possession_passes_received            0.508785
# Name: pass_types_corner_kicks, dtype: float64

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Start with all numeric features
X_train, X_test, y_train, y_test = train_test_split(numeric_df.drop(['pass_types_corner_kicks', 'passing_corner_kicks', 
                                                                     'pass_types_corner_kicks_in', 'passing_corner_kicks_in'], axis=1), 
                                                   numeric_df['pass_types_corner_kicks'], 
                                                   test_size=0.2, random_state=42)

# Basic XGBoost with built-in regularization
model = xgb.XGBRegressor(
   n_estimators=100,
   max_depth=6,
   reg_alpha=0.1,  # L1 regularization
   reg_lambda=1.0, # L2 regularization
   random_state=42
)

model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Simple evaluation
print("Model Performance:")
print(f"R² Score: {r2_score(y_test, y_pred):.4f}")
print(f"RMSE: {np.sqrt(mean_squared_error(y_test, y_pred)):.4f}")
print(f"Mean target value: {y_test.mean():.4f}")

# Get feature importance after training
importance = pd.DataFrame({
   'feature': X_train.columns,
   'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

print("\nTop 10 Most Important Features:")
print(importance.head(25))
# Out:
# Model Performance:
# R² Score: 0.5233
# RMSE: 2.1049
# Mean target value: 5.0921
#
# Top 10 Most Important Features:
#                                   feature  importance
# 57                           misc_crosses    0.231317
# 32             possession_touches_att_3rd    0.062065
# 33        possession_touches_att_pen_area    0.061697
# 120                   opp_summary_touches    0.039742
# 129          opp_summary_passes_completed    0.030688
# 130                    opp_summary_passes    0.025842
# 178            opp_pass_types_passes_live    0.020379
# 69                 pass_types_passes_dead    0.018821
# 128                       opp_summary_gca    0.017037
# 126                 opp_summary_xg_assist    0.015806
# 45   possession_carries_into_penalty_area    0.014469
# 75            pass_types_corner_kicks_out    0.014073
# 188  opp_pass_types_corner_kicks_straight    0.013567
# 123                    opp_summary_blocks    0.013521
# 26                   summary_take_ons_won    0.013335
# 34           possession_touches_live_ball    0.012688
# 219             opp_defense_blocked_shots    0.011086
# 139   opp_possession_touches_def_pen_area    0.011068
# 191         opp_pass_types_passes_blocked    0.009921
# 22             summary_progressive_passes    0.008964
# 18                            summary_gca    0.008874
# 31             possession_touches_mid_3rd    0.008375
# 220            opp_defense_blocked_passes    0.008105
# 124                        opp_summary_xg    0.007784
# 17                            summary_sca    0.007743
