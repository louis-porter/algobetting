# %%
import pandas as pd
import sqlite3
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.metrics import mean_squared_error, mean_absolute_error
import xgboost as xgb
import optuna
import os
import json 


conn = sqlite3.connect(r'C:\Users\Owner\dev\algobetting\infra\data\db\algobetting.db')

df = pd.read_sql_query("""
                        SELECT DISTINCT
                            f.*,
                            ms.summary_goals as goals
                        FROM 
                            team_all_features_180_0077 f
                        JOIN
                            fbref_match_all_columns ms
                                ON ms.match_url = f.match_url
                                AND ms.team = f.team
                        WHERE 
                            f.team_rolling_summary_minutes IS NOT NULL
                       --AND NOT (f.`is_promoted?` = 1 AND f.`is_early_season?` = 1)
                       """, conn)

df
# Out:
#                                                match_url           match_date  \
# 0      https://fbref.com/en/matches/e4bb1c35/Tottenha...  2025-05-25 00:00:00
# 1      https://fbref.com/en/matches/e4bb1c35/Tottenha...  2025-05-25 00:00:00
# 2      https://fbref.com/en/matches/1ff370e8/Bournemo...  2025-05-25 00:00:00
# 3      https://fbref.com/en/matches/1ff370e8/Bournemo...  2025-05-25 00:00:00
# 4      https://fbref.com/en/matches/36844e73/Newcastl...  2025-05-25 00:00:00
# ...                                                  ...                  ...
# 40589  https://fbref.com/en/matches/e8e75a75/Como-Cag...  2022-08-13 00:00:00
# 40590  https://fbref.com/en/matches/e8e75a75/Como-Cag...  2022-08-13 00:00:00
# 40591  https://fbref.com/en/matches/99979e25/Cittadel...  2022-08-13 00:00:00
# 40592  https://fbref.com/en/matches/99979e25/Cittadel...  2022-08-13 00:00:00
# 40593  https://fbref.com/en/matches/be681acc/Parma-Ba...  2022-08-12 00:00:00
#
#           season        division            team        opp_team  is_home  gw  \
# 0      2024-2025  Premier League       Tottenham        Brighton        1  38
# 1      2024-2025  Premier League        Brighton       Tottenham        0  38
# 2      2024-2025  Premier League     Bournemouth  Leicester City        1  38
# 3      2024-2025  Premier League  Leicester City     Bournemouth        0  38
# 4      2024-2025  Premier League   Newcastle Utd         Everton        1  38
# ...          ...             ...             ...             ...      ...  ..
# 40589  2022-2023         Serie B            Como        Cagliari        1   1
# 40590  2022-2023         Serie B        Cagliari            Como        0   1
# 40591  2022-2023         Serie B      Cittadella            Pisa        1   1
# 40592  2022-2023         Serie B            Pisa      Cittadella        0   1
# 40593  2022-2023         Serie B           Parma            Bari        1   1
#
#        is_promoted?  is_early_season?  ...  \
# 0                 0                 0  ...
# 1                 0                 0  ...
# 2                 0                 0  ...
# 3                 1                 0  ...
# 4                 0                 0  ...
# ...             ...               ...  ...
# 40589             0                 1  ...
# 40590             0                 1  ...
# 40591             0                 1  ...
# 40592             0                 1  ...
# 40593             0                 1  ...
#
#        opp_team_rolling_conceded_defense_challenges  \
# 0                                         17.626817
# 1                                         18.967924
# 2                                         12.973336
# 3                                         14.549176
# 4                                         13.494185
# ...                                             ...
# 40589                                     13.865806
# 40590                                     15.974251
# 40591                                     14.470084
# 40592                                     11.689373
# 40593                                           NaN
#
#        opp_team_rolling_conceded_defense_challenge_tackles_pct  \
# 0                                              48.357654
# 1                                              58.906421
# 2                                              53.287432
# 3                                              48.578723
# 4                                              54.012499
# ...                                                  ...
# 40589                                          51.140007
# 40590                                          43.253169
# 40591                                          50.660840
# 40592                                          56.400894
# 40593                                                NaN
#
#        opp_team_rolling_conceded_defense_challenges_lost  \
# 0                                               8.825405
# 1                                               7.531723
# 2                                               6.198606
# 3                                               7.431018
# 4                                               6.318674
# ...                                                  ...
# 40589                                           6.749611
# 40590                                           9.110522
# 40591                                           6.980518
# 40592                                           5.332239
# 40593                                                NaN
#
#        opp_team_rolling_conceded_defense_blocked_shots  \
# 0                                             3.079800
# 1                                             3.214026
# 2                                             2.647510
# 3                                             4.033535
# 4                                             2.577873
# ...                                                ...
# 40589                                         4.156406
# 40590                                         1.830221
# 40591                                         3.145323
# 40592                                         3.975192
# 40593                                              NaN
#
#        opp_team_rolling_conceded_defense_blocked_passes  \
# 0                                              6.920357
# 1                                              8.753274
# 2                                              6.934026
# 3                                              6.855790
# 4                                              5.406179
# ...                                                 ...
# 40589                                          6.419369
# 40590                                          6.919110
# 40591                                          6.960094
# 40592                                          9.716700
# 40593                                               NaN
#
#        opp_team_rolling_conceded_defense_tackles_interceptions  \
# 0                                              25.259719
# 1                                              31.687899
# 2                                              21.619704
# 3                                              23.310313
# 4                                              23.600076
# ...                                                  ...
# 40589                                          24.242237
# 40590                                          23.896380
# 40591                                          27.732300
# 40592                                          27.966362
# 40593                                                NaN
#
#        opp_team_rolling_conceded_defense_clearances  \
# 0                                         29.267004
# 1                                         22.755722
# 2                                         22.187666
# 3                                         27.477550
# 4                                         27.815311
# ...                                             ...
# 40589                                     19.279783
# 40590                                     14.582846
# 40591                                     19.685275
# 40592                                     19.311856
# 40593                                           NaN
#
#        opp_team_rolling_conceded_defense_errors  \
# 0                                      0.816211
# 1                                      0.782216
# 2                                      0.665972
# 3                                      1.633190
# 4                                      0.509854
# ...                                         ...
# 40589                                  0.205490
# 40590                                  0.000000
# 40591                                  0.323261
# 40592                                  0.176218
# 40593                                       NaN
#
#        opp_team_rolling_conceded_keeper_psxg  goals
# 0                                   1.269035    1.0
# 1                                   1.890708    4.0
# 2                                   1.738255    2.0
# 3                                   1.354963    0.0
# 4                                   1.247472    0.0
# ...                                      ...    ...
# 40589                               1.159798    1.0
# 40590                               1.668266    1.0
# 40591                               1.194049    4.0
# 40592                               0.765247    3.0
# 40593                                    NaN    2.0
#
# [40594 rows x 397 columns]

# %%
# Check for duplicate columns (identical values)
def find_duplicate_columns(df):
    duplicate_pairs = []
    cols = df.columns.tolist()
    
    for i in range(len(cols)):
        for j in range(i+1, len(cols)):
            if df[cols[i]].equals(df[cols[j]]):
                duplicate_pairs.append((cols[i], cols[j]))
    
    return duplicate_pairs

# Find duplicates in your FEATURE MATRIX (not the full df)
duplicates = find_duplicate_columns(df)
print("Duplicate column pairs:")
for pair in duplicates:
    print(f"  {pair[0]} == {pair[1]}")

# More sophisticated duplicate removal logic
columns_to_drop = []
for pair in duplicates:
    col1, col2 = pair
    
    # Priority rules for which column to keep:
    # 1. Keep shorter names
    # 2. Prefer "passing" over "pass_types" 
    # 3. Prefer "summary" over other categories
    # 4. Prefer team stats over opp_team stats (less processing)
    
    keep_col1 = True
    
    # Rule 1: Shorter name
    if len(col1) > len(col2):
        keep_col1 = False
    elif len(col1) < len(col2):
        keep_col1 = True
    else:
        # Same length, apply other rules
        # Rule 2: Prefer passing over pass_types
        if "pass_types" in col1 and "passing" in col2:
            keep_col1 = False
        elif "passing" in col1 and "pass_types" in col2:
            keep_col1 = True
        # Rule 3: Prefer summary stats
        elif "summary" in col1 and "summary" not in col2:
            keep_col1 = True
        elif "summary" in col2 and "summary" not in col1:
            keep_col1 = False
        # Rule 4: Prefer team over opp_team (less nested)
        elif col1.startswith("team_") and col2.startswith("opp_team_"):
            keep_col1 = True
        elif col2.startswith("team_") and col1.startswith("opp_team_"):
            keep_col1 = False
    
    # Add the column to drop
    if keep_col1:
        columns_to_drop.append(col2)
        print(f"  Keeping: {col1}")
        print(f"  Dropping: {col2}")
    else:
        columns_to_drop.append(col1)
        print(f"  Keeping: {col2}")
        print(f"  Dropping: {col1}")
    print()

print(f"Columns to drop: {len(columns_to_drop)}")
print(columns_to_drop)

# Create cleaned feature matrix
df = df.drop(columns=columns_to_drop)
# Out:
# Duplicate column pairs:
#   team_rolling_summary_passes_completed == team_rolling_pass_types_passes_completed
#   team_rolling_summary_passes == team_rolling_pass_types_passes
#   team_rolling_misc_crosses == team_rolling_pass_types_crosses
#   team_rolling_pass_types_passes_live == team_rolling_passing_passes_live
#   team_rolling_pass_types_passes_dead == team_rolling_passing_passes_dead
#   team_rolling_pass_types_passes_free_kicks == team_rolling_passing_passes_free_kicks
#   team_rolling_pass_types_through_balls == team_rolling_passing_through_balls
#   team_rolling_pass_types_passes_switches == team_rolling_passing_passes_switches
#   team_rolling_pass_types_throw_ins == team_rolling_passing_throw_ins
#   team_rolling_pass_types_corner_kicks == team_rolling_passing_corner_kicks
#   team_rolling_pass_types_corner_kicks_in == team_rolling_passing_corner_kicks_in
#   team_rolling_pass_types_corner_kicks_out == team_rolling_passing_corner_kicks_out
#   team_rolling_pass_types_corner_kicks_straight == team_rolling_passing_corner_kicks_straight
#   team_rolling_pass_types_passes_offsides == team_rolling_passing_passes_offsides
#   team_rolling_pass_types_passes_blocked == team_rolling_passing_passes_blocked
#   team_rolling_conceded_summary_passes_completed == team_rolling_conceded_pass_types_passes_completed
#   team_rolling_conceded_summary_passes == team_rolling_conceded_pass_types_passes
#   team_rolling_conceded_misc_crosses == team_rolling_conceded_pass_types_crosses
#   team_rolling_conceded_pass_types_passes_live == team_rolling_conceded_passing_passes_live
#   team_rolling_conceded_pass_types_passes_dead == team_rolling_conceded_passing_passes_dead
#   team_rolling_conceded_pass_types_passes_free_kicks == team_rolling_conceded_passing_passes_free_kicks
#   team_rolling_conceded_pass_types_through_balls == team_rolling_conceded_passing_through_balls
#   team_rolling_conceded_pass_types_passes_switches == team_rolling_conceded_passing_passes_switches
#   team_rolling_conceded_pass_types_throw_ins == team_rolling_conceded_passing_throw_ins
#   team_rolling_conceded_pass_types_corner_kicks == team_rolling_conceded_passing_corner_kicks
#   team_rolling_conceded_pass_types_corner_kicks_in == team_rolling_conceded_passing_corner_kicks_in
#   team_rolling_conceded_pass_types_corner_kicks_out == team_rolling_conceded_passing_corner_kicks_out
#   team_rolling_conceded_pass_types_corner_kicks_straight == team_rolling_conceded_passing_corner_kicks_straight
#   team_rolling_conceded_pass_types_passes_offsides == team_rolling_conceded_passing_passes_offsides
#   team_rolling_conceded_pass_types_passes_blocked == team_rolling_conceded_passing_passes_blocked
#   opp_team_rolling_summary_passes_completed == opp_team_rolling_pass_types_passes_completed
#   opp_team_rolling_summary_passes == opp_team_rolling_pass_types_passes
#   opp_team_rolling_misc_crosses == opp_team_rolling_pass_types_crosses
#   opp_team_rolling_pass_types_passes_live == opp_team_rolling_passing_passes_live
#   opp_team_rolling_pass_types_passes_dead == opp_team_rolling_passing_passes_dead
#   opp_team_rolling_pass_types_passes_free_kicks == opp_team_rolling_passing_passes_free_kicks
#   opp_team_rolling_pass_types_through_balls == opp_team_rolling_passing_through_balls
#   opp_team_rolling_pass_types_passes_switches == opp_team_rolling_passing_passes_switches
#   opp_team_rolling_pass_types_throw_ins == opp_team_rolling_passing_throw_ins
#   opp_team_rolling_pass_types_corner_kicks == opp_team_rolling_passing_corner_kicks
#   opp_team_rolling_pass_types_corner_kicks_in == opp_team_rolling_passing_corner_kicks_in
#   opp_team_rolling_pass_types_corner_kicks_out == opp_team_rolling_passing_corner_kicks_out
#   opp_team_rolling_pass_types_corner_kicks_straight == opp_team_rolling_passing_corner_kicks_straight
#   opp_team_rolling_pass_types_passes_offsides == opp_team_rolling_passing_passes_offsides
#   opp_team_rolling_pass_types_passes_blocked == opp_team_rolling_passing_passes_blocked
#   opp_team_rolling_conceded_summary_passes_completed == opp_team_rolling_conceded_pass_types_passes_completed
#   opp_team_rolling_conceded_summary_passes == opp_team_rolling_conceded_pass_types_passes
#   opp_team_rolling_conceded_misc_crosses == opp_team_rolling_conceded_pass_types_crosses
#   opp_team_rolling_conceded_pass_types_passes_live == opp_team_rolling_conceded_passing_passes_live
#   opp_team_rolling_conceded_pass_types_passes_dead == opp_team_rolling_conceded_passing_passes_dead
#   opp_team_rolling_conceded_pass_types_passes_free_kicks == opp_team_rolling_conceded_passing_passes_free_kicks
#   opp_team_rolling_conceded_pass_types_through_balls == opp_team_rolling_conceded_passing_through_balls
#   opp_team_rolling_conceded_pass_types_passes_switches == opp_team_rolling_conceded_passing_passes_switches
#   opp_team_rolling_conceded_pass_types_throw_ins == opp_team_rolling_conceded_passing_throw_ins
#   opp_team_rolling_conceded_pass_types_corner_kicks == opp_team_rolling_conceded_passing_corner_kicks
#   opp_team_rolling_conceded_pass_types_corner_kicks_in == opp_team_rolling_conceded_passing_corner_kicks_in
#   opp_team_rolling_conceded_pass_types_corner_kicks_out == opp_team_rolling_conceded_passing_corner_kicks_out
#   opp_team_rolling_conceded_pass_types_corner_kicks_straight == opp_team_rolling_conceded_passing_corner_kicks_straight
#   opp_team_rolling_conceded_pass_types_passes_offsides == opp_team_rolling_conceded_passing_passes_offsides
#   opp_team_rolling_conceded_pass_types_passes_blocked == opp_team_rolling_conceded_passing_passes_blocked
#   Keeping: team_rolling_summary_passes_completed
#   Dropping: team_rolling_pass_types_passes_completed
#
#   Keeping: team_rolling_summary_passes
#   Dropping: team_rolling_pass_types_passes
#
#   Keeping: team_rolling_misc_crosses
#   Dropping: team_rolling_pass_types_crosses
#
#   Keeping: team_rolling_passing_passes_live
#   Dropping: team_rolling_pass_types_passes_live
#
#   Keeping: team_rolling_passing_passes_dead
#   Dropping: team_rolling_pass_types_passes_dead
#
#   Keeping: team_rolling_passing_passes_free_kicks
#   Dropping: team_rolling_pass_types_passes_free_kicks
#
#   Keeping: team_rolling_passing_through_balls
#   Dropping: team_rolling_pass_types_through_balls
#
#   Keeping: team_rolling_passing_passes_switches
#   Dropping: team_rolling_pass_types_passes_switches
#
#   Keeping: team_rolling_passing_throw_ins
#   Dropping: team_rolling_pass_types_throw_ins
#
#   Keeping: team_rolling_passing_corner_kicks
#   Dropping: team_rolling_pass_types_corner_kicks
#
#   Keeping: team_rolling_passing_corner_kicks_in
#   Dropping: team_rolling_pass_types_corner_kicks_in
#
#   Keeping: team_rolling_passing_corner_kicks_out
#   Dropping: team_rolling_pass_types_corner_kicks_out
#
#   Keeping: team_rolling_passing_corner_kicks_straight
#   Dropping: team_rolling_pass_types_corner_kicks_straight
#
#   Keeping: team_rolling_passing_passes_offsides
#   Dropping: team_rolling_pass_types_passes_offsides
#
#   Keeping: team_rolling_passing_passes_blocked
#   Dropping: team_rolling_pass_types_passes_blocked
#
#   Keeping: team_rolling_conceded_summary_passes_completed
#   Dropping: team_rolling_conceded_pass_types_passes_completed
#
#   Keeping: team_rolling_conceded_summary_passes
#   Dropping: team_rolling_conceded_pass_types_passes
#
#   Keeping: team_rolling_conceded_misc_crosses
#   Dropping: team_rolling_conceded_pass_types_crosses
#
#   Keeping: team_rolling_conceded_passing_passes_live
#   Dropping: team_rolling_conceded_pass_types_passes_live
#
#   Keeping: team_rolling_conceded_passing_passes_dead
#   Dropping: team_rolling_conceded_pass_types_passes_dead
#
#   Keeping: team_rolling_conceded_passing_passes_free_kicks
#   Dropping: team_rolling_conceded_pass_types_passes_free_kicks
#
#   Keeping: team_rolling_conceded_passing_through_balls
#   Dropping: team_rolling_conceded_pass_types_through_balls
#
#   Keeping: team_rolling_conceded_passing_passes_switches
#   Dropping: team_rolling_conceded_pass_types_passes_switches
#
#   Keeping: team_rolling_conceded_passing_throw_ins
#   Dropping: team_rolling_conceded_pass_types_throw_ins
#
#   Keeping: team_rolling_conceded_passing_corner_kicks
#   Dropping: team_rolling_conceded_pass_types_corner_kicks
#
#   Keeping: team_rolling_conceded_passing_corner_kicks_in
#   Dropping: team_rolling_conceded_pass_types_corner_kicks_in
#
#   Keeping: team_rolling_conceded_passing_corner_kicks_out
#   Dropping: team_rolling_conceded_pass_types_corner_kicks_out
#
#   Keeping: team_rolling_conceded_passing_corner_kicks_straight
#   Dropping: team_rolling_conceded_pass_types_corner_kicks_straight
#
#   Keeping: team_rolling_conceded_passing_passes_offsides
#   Dropping: team_rolling_conceded_pass_types_passes_offsides
#
#   Keeping: team_rolling_conceded_passing_passes_blocked
#   Dropping: team_rolling_conceded_pass_types_passes_blocked
#
#   Keeping: opp_team_rolling_summary_passes_completed
#   Dropping: opp_team_rolling_pass_types_passes_completed
#
#   Keeping: opp_team_rolling_summary_passes
#   Dropping: opp_team_rolling_pass_types_passes
#
#   Keeping: opp_team_rolling_misc_crosses
#   Dropping: opp_team_rolling_pass_types_crosses
#
#   Keeping: opp_team_rolling_passing_passes_live
#   Dropping: opp_team_rolling_pass_types_passes_live
#
#   Keeping: opp_team_rolling_passing_passes_dead
#   Dropping: opp_team_rolling_pass_types_passes_dead
#
#   Keeping: opp_team_rolling_passing_passes_free_kicks
#   Dropping: opp_team_rolling_pass_types_passes_free_kicks
#
#   Keeping: opp_team_rolling_passing_through_balls
#   Dropping: opp_team_rolling_pass_types_through_balls
#
#   Keeping: opp_team_rolling_passing_passes_switches
#   Dropping: opp_team_rolling_pass_types_passes_switches
#
#   Keeping: opp_team_rolling_passing_throw_ins
#   Dropping: opp_team_rolling_pass_types_throw_ins
#
#   Keeping: opp_team_rolling_passing_corner_kicks
#   Dropping: opp_team_rolling_pass_types_corner_kicks
#
#   Keeping: opp_team_rolling_passing_corner_kicks_in
#   Dropping: opp_team_rolling_pass_types_corner_kicks_in
#
#   Keeping: opp_team_rolling_passing_corner_kicks_out
#   Dropping: opp_team_rolling_pass_types_corner_kicks_out
#
#   Keeping: opp_team_rolling_passing_corner_kicks_straight
#   Dropping: opp_team_rolling_pass_types_corner_kicks_straight
#
#   Keeping: opp_team_rolling_passing_passes_offsides
#   Dropping: opp_team_rolling_pass_types_passes_offsides
#
#   Keeping: opp_team_rolling_passing_passes_blocked
#   Dropping: opp_team_rolling_pass_types_passes_blocked
#
#   Keeping: opp_team_rolling_conceded_summary_passes_completed
#   Dropping: opp_team_rolling_conceded_pass_types_passes_completed
#
#   Keeping: opp_team_rolling_conceded_summary_passes
#   Dropping: opp_team_rolling_conceded_pass_types_passes
#
#   Keeping: opp_team_rolling_conceded_misc_crosses
#   Dropping: opp_team_rolling_conceded_pass_types_crosses
#
#   Keeping: opp_team_rolling_conceded_passing_passes_live
#   Dropping: opp_team_rolling_conceded_pass_types_passes_live
#
#   Keeping: opp_team_rolling_conceded_passing_passes_dead
#   Dropping: opp_team_rolling_conceded_pass_types_passes_dead
#
#   Keeping: opp_team_rolling_conceded_passing_passes_free_kicks
#   Dropping: opp_team_rolling_conceded_pass_types_passes_free_kicks
#
#   Keeping: opp_team_rolling_conceded_passing_through_balls
#   Dropping: opp_team_rolling_conceded_pass_types_through_balls
#
#   Keeping: opp_team_rolling_conceded_passing_passes_switches
#   Dropping: opp_team_rolling_conceded_pass_types_passes_switches
#
#   Keeping: opp_team_rolling_conceded_passing_throw_ins
#   Dropping: opp_team_rolling_conceded_pass_types_throw_ins
#
#   Keeping: opp_team_rolling_conceded_passing_corner_kicks
#   Dropping: opp_team_rolling_conceded_pass_types_corner_kicks
#
#   Keeping: opp_team_rolling_conceded_passing_corner_kicks_in
#   Dropping: opp_team_rolling_conceded_pass_types_corner_kicks_in
#
#   Keeping: opp_team_rolling_conceded_passing_corner_kicks_out
#   Dropping: opp_team_rolling_conceded_pass_types_corner_kicks_out
#
#   Keeping: opp_team_rolling_conceded_passing_corner_kicks_straight
#   Dropping: opp_team_rolling_conceded_pass_types_corner_kicks_straight
#
#   Keeping: opp_team_rolling_conceded_passing_passes_offsides
#   Dropping: opp_team_rolling_conceded_pass_types_passes_offsides
#
#   Keeping: opp_team_rolling_conceded_passing_passes_blocked
#   Dropping: opp_team_rolling_conceded_pass_types_passes_blocked
#
# Columns to drop: 60
# ['team_rolling_pass_types_passes_completed', 'team_rolling_pass_types_passes', 'team_rolling_pass_types_crosses', 'team_rolling_pass_types_passes_live', 'team_rolling_pass_types_passes_dead', 'team_rolling_pass_types_passes_free_kicks', 'team_rolling_pass_types_through_balls', 'team_rolling_pass_types_passes_switches', 'team_rolling_pass_types_throw_ins', 'team_rolling_pass_types_corner_kicks', 'team_rolling_pass_types_corner_kicks_in', 'team_rolling_pass_types_corner_kicks_out', 'team_rolling_pass_types_corner_kicks_straight', 'team_rolling_pass_types_passes_offsides', 'team_rolling_pass_types_passes_blocked', 'team_rolling_conceded_pass_types_passes_completed', 'team_rolling_conceded_pass_types_passes', 'team_rolling_conceded_pass_types_crosses', 'team_rolling_conceded_pass_types_passes_live', 'team_rolling_conceded_pass_types_passes_dead', 'team_rolling_conceded_pass_types_passes_free_kicks', 'team_rolling_conceded_pass_types_through_balls', 'team_rolling_conceded_pass_types_passes_switches', 'team_rolling_conceded_pass_types_throw_ins', 'team_rolling_conceded_pass_types_corner_kicks', 'team_rolling_conceded_pass_types_corner_kicks_in', 'team_rolling_conceded_pass_types_corner_kicks_out', 'team_rolling_conceded_pass_types_corner_kicks_straight', 'team_rolling_conceded_pass_types_passes_offsides', 'team_rolling_conceded_pass_types_passes_blocked', 'opp_team_rolling_pass_types_passes_completed', 'opp_team_rolling_pass_types_passes', 'opp_team_rolling_pass_types_crosses', 'opp_team_rolling_pass_types_passes_live', 'opp_team_rolling_pass_types_passes_dead', 'opp_team_rolling_pass_types_passes_free_kicks', 'opp_team_rolling_pass_types_through_balls', 'opp_team_rolling_pass_types_passes_switches', 'opp_team_rolling_pass_types_throw_ins', 'opp_team_rolling_pass_types_corner_kicks', 'opp_team_rolling_pass_types_corner_kicks_in', 'opp_team_rolling_pass_types_corner_kicks_out', 'opp_team_rolling_pass_types_corner_kicks_straight', 'opp_team_rolling_pass_types_passes_offsides', 'opp_team_rolling_pass_types_passes_blocked', 'opp_team_rolling_conceded_pass_types_passes_completed', 'opp_team_rolling_conceded_pass_types_passes', 'opp_team_rolling_conceded_pass_types_crosses', 'opp_team_rolling_conceded_pass_types_passes_live', 'opp_team_rolling_conceded_pass_types_passes_dead', 'opp_team_rolling_conceded_pass_types_passes_free_kicks', 'opp_team_rolling_conceded_pass_types_through_balls', 'opp_team_rolling_conceded_pass_types_passes_switches', 'opp_team_rolling_conceded_pass_types_throw_ins', 'opp_team_rolling_conceded_pass_types_corner_kicks', 'opp_team_rolling_conceded_pass_types_corner_kicks_in', 'opp_team_rolling_conceded_pass_types_corner_kicks_out', 'opp_team_rolling_conceded_pass_types_corner_kicks_straight', 'opp_team_rolling_conceded_pass_types_passes_offsides', 'opp_team_rolling_conceded_pass_types_passes_blocked']

# %%
X = df.drop(columns=["team", "opp_team", "goals", "match_url", "match_date"])
X = pd.get_dummies(X, columns=["season", "division"], drop_first=True)

#X = df[["is_home", "team_rolling_summary_goals", "opp_team_rolling_conceded_summary_goals"]] # goals only

y = df["goals"]

# Use matches after a certain date as test
cutoff_date = '2024-08-01'
df['match_date'] = pd.to_datetime(df['match_date'])

train_mask = df['match_date'] < cutoff_date
test_mask = df['match_date'] >= cutoff_date

X_train = X[train_mask]
X_test = X[test_mask]
y_train = y[train_mask]
y_test = y[test_mask]

# Create DMatrix objects BEFORE using them in eval_list
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

params = {
    'objective': 'count:poisson',
    'max_depth': 7,
    'eta': 0.1,
    'subsample': 0.7,
    'colsample_bytree': 0.8,
    'eval_metric': 'poisson-nloglik'
}

num_rounds = 100
eval_list = [(dtrain, 'train'), (dtest, 'eval')]  # Now dtrain and dtest are defined

model = xgb.train(
    params, 
    dtrain, 
    num_rounds, 
    eval_list, 
    early_stopping_rounds=10,
    verbose_eval=10
)

# Make predictions
preds = model.predict(dtest)

rmse = np.sqrt(mean_squared_error(y_test, preds))
mae = mean_absolute_error(y_test, preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# c:\Users\Owner\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:727: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [0]	train-poisson-nloglik:1.50430	eval-poisson-nloglik:1.49440
# [10]	train-poisson-nloglik:1.44200	eval-poisson-nloglik:1.45455
# [20]	train-poisson-nloglik:1.41107	eval-poisson-nloglik:1.44125
# [30]	train-poisson-nloglik:1.39128	eval-poisson-nloglik:1.43732
# [40]	train-poisson-nloglik:1.37611	eval-poisson-nloglik:1.43506
# [50]	train-poisson-nloglik:1.36302	eval-poisson-nloglik:1.43415
# [60]	train-poisson-nloglik:1.35160	eval-poisson-nloglik:1.43395
# [70]	train-poisson-nloglik:1.34141	eval-poisson-nloglik:1.43385
# [71]	train-poisson-nloglik:1.34052	eval-poisson-nloglik:1.43395
# RMSE: 1.1223
# MAE: 0.8814

# %%
# Get feature importance
importance = model.get_score(importance_type='gain')
feature_names = X_train.columns.tolist()

# Create a DataFrame for better visualization
importance_df = pd.DataFrame({
    'feature': list(importance.keys()),
    'importance': list(importance.values())
}).sort_values('importance', ascending=False)

print("Top 10 Most Important Features:")
print(importance_df.head(15))
# Out:
# Top 10 Most Important Features:
#                                                feature  importance
# 59                    team_rolling_passing_passes_live   82.381851
# 33        team_rolling_possession_touches_att_pen_area   52.050701
# 17                           team_rolling_summary_npxg   37.707771
# 21               team_rolling_summary_passes_completed   32.820927
# 16                             team_rolling_summary_xg   21.786440
# 279  opp_team_rolling_conceded_possession_touches_a...   21.773891
# 34           team_rolling_possession_touches_live_ball   19.757393
# 45   team_rolling_possession_progressive_passes_rec...   19.206972
# 264        opp_team_rolling_conceded_summary_xg_assist   18.982849
# 263             opp_team_rolling_conceded_summary_npxg   18.011448
# 0                                              is_home   13.927182
# 332                                   division_Ligue 1   13.794147
# 83                            team_rolling_keeper_psxg   13.290424
# 262               opp_team_rolling_conceded_summary_xg   12.862399
# 195        opp_team_rolling_possession_touches_att_3rd   11.294014

# %% [markdown]
# # Hyperparameter Tuning

# %%
# Set to True to tune new parameters, False to load existing
TUNE_NEW_PARAMS = True  # Change this to False to load saved params

# Tuning settings
N_TRIALS = 100
PARAMS_FILE = "best_xgb_params.json"

# %%
if TUNE_NEW_PARAMS or not os.path.exists(PARAMS_FILE):
    print("Tuning new hyperparameters...")
    
    def objective(trial):
        # Define search space
        params = {
            'objective': 'count:poisson',
            'eval_metric': 'poisson-nloglik',
            'max_depth': trial.suggest_int('max_depth', 4, 12),  # Deeper trees for more data
            'eta': trial.suggest_float('eta', 0.005, 0.2, log=True),  # Wider range, log scale
            'subsample': trial.suggest_float('subsample', 0.6, 0.95),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 0.8),  # More aggressive for 350 cols
            'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.5, 1.0),  # Additional sampling
            'min_child_weight': trial.suggest_int('min_child_weight', 3, 15),  # Higher for larger dataset
            'gamma': trial.suggest_float('gamma', 0, 5),  # Wider regularization range
            'alpha': trial.suggest_float('alpha', 0, 10),  # L1 reg - good for feature selection
            'lambda': trial.suggest_float('lambda', 1, 10),  # L2 reg - important with many features
            'max_leaves': trial.suggest_int('max_leaves', 0, 200),  # Control tree complexity
            'random_state': 42
        }
        
        n_estimators = trial.suggest_int('n_estimators', 100, 500)
        
        # Train model
        dtrain = xgb.DMatrix(X_train, label=y_train)
        dtest = xgb.DMatrix(X_test, label=y_test)
        
        model = xgb.train(
            params,
            dtrain,
            num_boost_round=n_estimators,
            evals=[(dtrain, 'train'), (dtest, 'eval')],
            early_stopping_rounds=20,
            verbose_eval=False
        )
        
        # Calculate RMSE
        preds = model.predict(dtest)
        rmse = np.sqrt(mean_squared_error(y_test, preds))
        
        return rmse
    
    # Run optimization
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=N_TRIALS, show_progress_bar=True)
    
    # Get best parameters
    best_params = study.best_params.copy()
    n_estimators = best_params.pop('n_estimators')
    
    print(f"Best RMSE: {study.best_value:.4f}")
    print("Best parameters:")
    for key, value in best_params.items():
        if key not in ['objective', 'eval_metric', 'random_state']:
            print(f"  {key}: {value}")
    print(f"  n_estimators: {n_estimators}")
    
    # Save parameters
    params_to_save = {
        'best_params': best_params,
        'n_estimators': n_estimators,
        'best_rmse': study.best_value
    }
    
    with open(PARAMS_FILE, 'w') as f:
        json.dump(params_to_save, f, indent=2)
    print(f"\nParameters saved to {PARAMS_FILE}")
    
else:
    print("Loading saved hyperparameters...")
    
    with open(PARAMS_FILE, 'r') as f:
        saved_params = json.load(f)
    
    best_params = saved_params['best_params']
    n_estimators = saved_params['n_estimators']
    
    print("Loaded parameters:")
    for key, value in best_params.items():
        if key not in ['objective', 'eval_metric', 'random_state']:
            print(f"  {key}: {value}")
    print(f"  n_estimators: {n_estimators}")
    print(f"Previous best RMSE: {saved_params['best_rmse']:.4f}")
# Out:
# [I 2025-08-04 08:59:37,015] A new study created in memory with name: no-name-ca2a9f4a-3183-46c1-98f1-853d9973272c
# Tuning new hyperparameters...
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-08-04 08:59:43,485] Trial 0 finished with value: 1.1217046694822748 and parameters: {'max_depth': 8, 'eta': 0.14387335213037086, 'subsample': 0.6585146876269514, 'colsample_bytree': 0.449926767193743, 'colsample_bylevel': 0.8707069736123407, 'min_child_weight': 4, 'gamma': 1.3110368536023886, 'alpha': 9.987137217823067, 'lambda': 1.6454575309146338, 'max_leaves': 53, 'n_estimators': 491}. Best is trial 0 with value: 1.1217046694822748.
# [I 2025-08-04 08:59:48,984] Trial 1 finished with value: 1.1183080904698435 and parameters: {'max_depth': 4, 'eta': 0.14589124639255763, 'subsample': 0.7124403386516207, 'colsample_bytree': 0.7733684205496411, 'colsample_bylevel': 0.8462070311506342, 'min_child_weight': 10, 'gamma': 0.3951562858074964, 'alpha': 0.5938581369843521, 'lambda': 2.6807480636274903, 'max_leaves': 180, 'n_estimators': 189}. Best is trial 1 with value: 1.1183080904698435.
# [I 2025-08-04 08:59:56,088] Trial 2 finished with value: 1.1179510530607564 and parameters: {'max_depth': 8, 'eta': 0.06344569631887842, 'subsample': 0.7393997626270886, 'colsample_bytree': 0.7451257699925884, 'colsample_bylevel': 0.5058207208656944, 'min_child_weight': 15, 'gamma': 1.4692221386305182, 'alpha': 4.190887191711202, 'lambda': 6.9706237795029935, 'max_leaves': 7, 'n_estimators': 485}. Best is trial 2 with value: 1.1179510530607564.
# [I 2025-08-04 09:00:06,821] Trial 3 finished with value: 1.1175286294061122 and parameters: {'max_depth': 6, 'eta': 0.056906659977775886, 'subsample': 0.604910274826469, 'colsample_bytree': 0.655057870525223, 'colsample_bylevel': 0.597319333784398, 'min_child_weight': 7, 'gamma': 2.7653833726830666, 'alpha': 6.7559088627826105, 'lambda': 4.276713836144832, 'max_leaves': 106, 'n_estimators': 380}. Best is trial 3 with value: 1.1175286294061122.
# [I 2025-08-04 09:00:11,904] Trial 4 finished with value: 1.1195575085053615 and parameters: {'max_depth': 5, 'eta': 0.1645403464822262, 'subsample': 0.6155130028649856, 'colsample_bytree': 0.30504170048116597, 'colsample_bylevel': 0.5215196434717969, 'min_child_weight': 8, 'gamma': 3.5601203615965424, 'alpha': 9.153387708475229, 'lambda': 3.1413209110948968, 'max_leaves': 22, 'n_estimators': 291}. Best is trial 3 with value: 1.1175286294061122.
# [I 2025-08-04 09:00:27,797] Trial 5 finished with value: 1.1283432975542105 and parameters: {'max_depth': 5, 'eta': 0.008207027083997905, 'subsample': 0.829679901735088, 'colsample_bytree': 0.45395626151050644, 'colsample_bylevel': 0.5289693066900576, 'min_child_weight': 15, 'gamma': 3.49787195819522, 'alpha': 3.9728467929055142, 'lambda': 5.139359764813112, 'max_leaves': 22, 'n_estimators': 333}. Best is trial 3 with value: 1.1175286294061122.
# [I 2025-08-04 09:00:36,718] Trial 6 finished with value: 1.1422619201431303 and parameters: {'max_depth': 6, 'eta': 0.011076715631212682, 'subsample': 0.7003953235383586, 'colsample_bytree': 0.37868252582843426, 'colsample_bylevel': 0.6335509208081405, 'min_child_weight': 5, 'gamma': 3.4509659245866042, 'alpha': 3.5036635959243156, 'lambda': 4.376877915103682, 'max_leaves': 157, 'n_estimators': 136}. Best is trial 3 with value: 1.1175286294061122.
. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:19:49,041] Trial 61 finished with value: 1.1170236745722002 and parameters: {'max_depth': 7, 'eta': 0.018311429489426236, 'subsample': 0.6539607484283981, 'colsample_bytree': 0.5987300108512461, 'colsample_bylevel': 0.6608850820703728, 'min_child_weight': 13, 'gamma': 2.2668397435311185, 'alpha': 8.12495980431115, 'lambda': 9.991661012220895, 'max_leaves': 113, 'n_estimators': 397}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:20:12,304] Trial 62 finished with value: 1.1170202881980886 and parameters: {'max_depth': 7, 'eta': 0.02631600008030007, 'subsample': 0.6431696949785478, 'colsample_bytree': 0.5714843925169429, 'colsample_bylevel': 0.6949997258534191, 'min_child_weight': 12, 'gamma': 2.404497628996918, 'alpha': 9.752594828855166, 'lambda': 9.894538455461003, 'max_leaves': 131, 'n_estimators': 342}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:20:25,792] Trial 63 finished with value: 1.1180603811447345 and parameters: {'max_depth': 7, 'eta': 0.03923856431932562, 'subsample': 0.6662639324641614, 'colsample_bytree': 0.5782450692861527, 'colsample_bylevel': 0.5817661864500165, 'min_child_weight': 13, 'gamma': 2.938113436600389, 'alpha': 6.598862913330714, 'lambda': 9.45134587849667, 'max_leaves': 84, 'n_estimators': 457}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:20:43,888] Trial 64 finished with value: 1.115471689745041 and parameters: {'max_depth': 7, 'eta': 0.030407677207748108, 'subsample': 0.6265284038795927, 'colsample_bytree': 0.5453430524816922, 'colsample_bylevel': 0.6172431189690567, 'min_child_weight': 11, 'gamma': 1.952082875295016, 'alpha': 8.394248957322457, 'lambda': 8.84528049613192, 'max_leaves': 106, 'n_estimators': 269}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:21:02,929] Trial 65 finished with value: 1.1162990392278855 and parameters: {'max_depth': 8, 'eta': 0.03000115368441622, 'subsample': 0.602630882747639, 'colsample_bytree': 0.4285640130330849, 'colsample_bylevel': 0.6162966953483513, 'min_child_weight': 11, 'gamma': 2.0239387401716216, 'alpha': 8.725068393122523, 'lambda': 8.76889499625318, 'max_leaves': 108, 'n_estimators': 217}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:21:10,609] Trial 66 finished with value: 1.119437950656331 and parameters: {'max_depth': 6, 'eta': 0.057085615541948125, 'subsample': 0.6272997014848449, 'colsample_bytree': 0.5351371672813496, 'colsample_bylevel': 0.5307266475760635, 'min_child_weight': 10, 'gamma': 1.390211964399736, 'alpha': 5.236523830265612, 'lambda': 9.06609308416866, 'max_leaves': 121, 'n_estimators': 284}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:21:25,289] Trial 67 finished with value: 1.1174806704673503 and parameters: {'max_depth': 6, 'eta': 0.02532947776677948, 'subsample': 0.6104768584310334, 'colsample_bytree': 0.7259419094739489, 'colsample_bylevel': 0.6055652091908067, 'min_child_weight': 11, 'gamma': 1.0731477784676007, 'alpha': 5.81300749433459, 'lambda': 7.9695355892104836, 'max_leaves': 0, 'n_estimators': 271}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:21:41,810] Trial 68 finished with value: 1.118011725448941 and parameters: {'max_depth': 8, 'eta': 0.03478558644715958, 'subsample': 0.6206583685613685, 'colsample_bytree': 0.5089177905010898, 'colsample_bylevel': 0.5655801185478723, 'min_child_weight': 9, 'gamma': 3.289497494264482, 'alpha': 9.231205261559559, 'lambda': 8.564312258116418, 'max_leaves': 80, 'n_estimators': 258}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09
. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:25:26,735] Trial 77 finished with value: 1.12130328548932 and parameters: {'max_depth': 7, 'eta': 0.0071926065784838145, 'subsample': 0.6538885893203072, 'colsample_bytree': 0.653348259439968, 'colsample_bylevel': 0.7502839733701725, 'min_child_weight': 10, 'gamma': 2.4927717742974482, 'alpha': 3.7428122346174186, 'lambda': 9.401253450413188, 'max_leaves': 97, 'n_estimators': 467}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:25:53,013] Trial 78 finished with value: 1.1187216084963412 and parameters: {'max_depth': 8, 'eta': 0.02653702369526102, 'subsample': 0.6739994851372841, 'colsample_bytree': 0.5988059467708589, 'colsample_bylevel': 0.5771749718641089, 'min_child_weight': 13, 'gamma': 1.5392212288126421, 'alpha': 7.2369758105410495, 'lambda': 9.806572135417683, 'max_leaves': 173, 'n_estimators': 395}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:26:27,519] Trial 79 finished with value: 1.116892743094718 and parameters: {'max_depth': 9, 'eta': 0.033126861928294456, 'subsample': 0.6184358490708501, 'colsample_bytree': 0.67868687808215, 'colsample_bylevel': 0.9984181137026473, 'min_child_weight': 12, 'gamma': 1.8813678851402644, 'alpha': 4.973336356669426, 'lambda': 7.694713989086588, 'max_leaves': 183, 'n_estimators': 318}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:26:40,090] Trial 80 finished with value: 1.11590038872625 and parameters: {'max_depth': 5, 'eta': 0.024615474090013703, 'subsample': 0.7105521076127026, 'colsample_bytree': 0.4856567334418037, 'colsample_bylevel': 0.8174421281803353, 'min_child_weight': 9, 'gamma': 0.8136055875815487, 'alpha': 9.353244432830166, 'lambda': 2.8566371336454823, 'max_leaves': 143, 'n_estimators': 480}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:26:58,015] Trial 81 finished with value: 1.1163634798222517 and parameters: {'max_depth': 5, 'eta': 0.019117346169898266, 'subsample': 0.717081237918759, 'colsample_bytree': 0.48029680521731805, 'colsample_bylevel': 0.7847617240593829, 'min_child_weight': 9, 'gamma': 0.8182968203413088, 'alpha': 9.290123705123968, 'lambda': 2.927264418304192, 'max_leaves': 144, 'n_estimators': 488}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:27:08,414] Trial 82 finished with value: 1.1170828815122587 and parameters: {'max_depth': 4, 'eta': 0.02445045077137594, 'subsample': 0.8029607671120845, 'colsample_bytree': 0.518301426402062, 'colsample_bylevel': 0.817969212597181, 'min_child_weight': 8, 'gamma': 1.1536868119063717, 'alpha': 9.934814696606407, 'lambda': 2.16458260137392, 'max_leaves': 159, 'n_estimators': 451}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:27:23,626] Trial 83 finished with value: 1.1173710896636395 and parameters: {'max_depth': 6, 'eta': 0.02960663746997812, 'subsample': 0.7512003931891833, 'colsample_bytree': 0.4886029794984894, 'colsample_bylevel': 0.7971186622709773, 'min_child_weight': 9, 'gamma': 0.2914096134523279, 'alpha': 8.865619748508013, 'lambda': 5.05942674630762, 'max_leaves': 133, 'n_estimators': 478}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:27:36,777] Trial 84 finished with value: 1.116600740556128 and parameters: {'max_depth': 7, 'eta': 0.04143948109022741, 'subsample': 0.6927220932637591, 'colsample_bytree': 0.43968332999991466, 'colsample_bylevel': 0.7212580542984844, 'min_child_weight': 10, 'gamma': 0.9523750719545452, 'alpha': 8.300596310749668, 'lambda': 5.753334777299447, 'max_leaves': 124, 'n_estimators': 471}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:27:48,249] Trial 85 finished with value: 1.1163866537770306 and parameters: {'max_depth': 5, 'eta': 0.03498467793558163, 'subsample': 0.7310583875105235, 'colsample_bytree': 0.465986980512595, 'colsample_bylevel': 0.7581147074949822, 'min_child_weight': 9, 'gamma': 0.6985957891225336, 'alpha': 9.511537179226426, 'lambda': 4.151072269603411, 'max_leaves': 141, 'n_estimators': 439}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:28:12,296] Trial 86 finished with value: 1.1162278447594802 and parameters: {'max_depth': 6, 'eta': 0.015987987305845774, 'subsample': 0.7082173416505454, 'colsample_bytree': 0.6929659765336884, 'colsample_bylevel': 0.7804207489986537, 'min_child_weight': 11, 'gamma': 1.2920381456839116, 'alpha': 6.373866539562133, 'lambda': 8.972371498828227, 'max_leaves': 110, 'n_estimators': 463}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:28:21,395] Trial 87 finished with value: 1.1174151282160834 and parameters: {'max_depth': 4, 'eta': 0.022568187927659522, 'subsample': 0.6489678952978036, 'colsample_bytree': 0.5458410473809691, 'colsample_bylevel': 0.5890264212074804, 'min_child_weight': 10, 'gamma': 2.7073683834333617, 'alpha': 4.39551834044576, 'lambda': 1.1844567360974043, 'max_leaves': 149, 'n_estimators': 296}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:28:43,257] Trial 88 finished with value: 1.1171840488695464 and parameters: {'max_depth': 7, 'eta': 0.02731186277109214, 'subsample': 0.6629452797142857, 'colsample_bytree': 0.4963039818874581, 'colsample_bylevel': 0.8349336114385095, 'min_child_weight': 7, 'gamma': 0.5635756268257788, 'alpha': 8.541287220545604, 'lambda': 9.391421163454376, 'max_leaves': 129, 'n_estimators': 427}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:28:57,687] Trial 89 finished with value: 1.1171543584696384 and parameters: {'max_depth': 7, 'eta': 0.05145397030400609, 'subsample': 0.6401016983443029, 'colsample_bytree': 0.7608177063146977, 'colsample_bylevel': 0.8947701682044373, 'min_child_weight': 8, 'gamma': 2.963020751055632, 'alpha': 7.741344939230739, 'lambda': 3.5216028738530283, 'max_leaves': 165, 'n_estimators': 407}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:29:07,550] Trial 90 finished with value: 1.1158194963578534 and parameters: {'max_depth': 5, 'eta': 0.031795953326465246, 'subsample': 0.6085505710993079, 'colsample_bytree': 0.40142313904335636, 'colsample_bylevel': 0.8053355651316673, 'min_child_weight': 9, 'gamma': 3.7923768885124494, 'alpha': 5.234989159061078, 'lambda': 6.144446370020092, 'max_leaves': 103, 'n_estimators': 449}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09:29:16,615] Trial 91 finished with value: 1.11633380431139 and parameters: {'max_depth': 5, 'eta': 0.037588989904136304, 'subsample': 0.6066093771515872, 'colsample_bytree': 0.39539620041788104, 'colsample_bylevel': 0.8072668711326846, 'min_child_weight': 9, 'gamma': 3.698165947259843, 'alpha': 6.029287881721789, 'lambda': 9.75582228364713, 'max_leaves': 105, 'n_estimators': 446}. Best is trial 9 with value: 1.1151079367071461.
# [I 2025-08-04 09
# Best RMSE: 1.1151
# Best parameters:
#   max_depth: 6
#   eta: 0.04246603565531645
#   subsample: 0.6131439058951896
#   colsample_bytree: 0.4955221956586915
#   colsample_bylevel: 0.9558992038277195
#   min_child_weight: 9
#   gamma: 4.045720376209846
#   alpha: 6.131879946873397
#   lambda: 9.61585217846589
#   max_leaves: 111
#   n_estimators: 488
#
# Parameters saved to best_xgb_params.json

# %%
print("\nTraining final model...")

# Prepare data
dtrain_final = xgb.DMatrix(X_train, label=y_train)
dtest_final = xgb.DMatrix(X_test, label=y_test)

# Train with best parameters
final_model = xgb.train(
    best_params,
    dtrain_final,
    num_boost_round=n_estimators,
    evals=[(dtrain_final, 'train'), (dtest_final, 'eval')],
    early_stopping_rounds=20,
    verbose_eval=10
)

# Make predictions and evaluate
preds_final = final_model.predict(dtest_final)
rmse_final = np.sqrt(mean_squared_error(y_test, preds_final))
mae_final = mean_absolute_error(y_test, preds_final)

print(f"\nFinal Model Performance:")
print(f"RMSE: {rmse_final:.4f}")
print(f"MAE: {mae_final:.4f}")

# Save the trained model
final_model.save_model("best_xgb_model.json")
print("Model saved as 'best_xgb_model.json'")
# Out:
# Training final model...
# [0]	train-rmse:1.20870	eval-rmse:1.18961
# [10]	train-rmse:1.16761	eval-rmse:1.15648
# [20]	train-rmse:1.14045	eval-rmse:1.13757
# [30]	train-rmse:1.12197	eval-rmse:1.12813
# [40]	train-rmse:1.10924	eval-rmse:1.12377
# [50]	train-rmse:1.09898	eval-rmse:1.12173
# [60]	train-rmse:1.09051	eval-rmse:1.12084
# [70]	train-rmse:1.08318	eval-rmse:1.11966
# [80]	train-rmse:1.07658	eval-rmse:1.11929
# [90]	train-rmse:1.07013	eval-rmse:1.11902
# [100]	train-rmse:1.06373	eval-rmse:1.11943
# [106]	train-rmse:1.06033	eval-rmse:1.12007
#
# Final Model Performance:
# RMSE: 1.1201
# MAE: 0.8820
# Model saved as 'best_xgb_model.json'

# %%
print("\nTop 10 Feature Importance (Gain):")
importance = final_model.get_score(importance_type='gain')
importance_df = pd.DataFrame({
    'feature': list(importance.keys()),
    'importance': list(importance.values())
}).sort_values('importance', ascending=False)

print(importance_df.head(10).to_string(index=False))
# Out:
# Top 10 Feature Importance (Gain):
#                                                   feature  importance
#                              team_rolling_summary_touches  179.686142
#                          team_rolling_passing_passes_live  160.319351
#                   team_rolling_possession_passes_received  126.460159
#                            team_rolling_summary_xg_assist  100.019966
#                                 team_rolling_summary_npxg   99.978600
#                               team_rolling_summary_passes   93.963310
#              team_rolling_possession_touches_att_pen_area   93.568680
#                                                   is_home   82.524269
#                   team_rolling_possession_touches_att_3rd   79.989845
#                     team_rolling_summary_passes_completed   60.474033
#                                   team_rolling_summary_xg   57.729107
#                 team_rolling_possession_touches_live_ball   55.937267
# opp_team_rolling_conceded_possession_touches_att_pen_area   54.153584
#               opp_team_rolling_conceded_summary_xg_assist   43.478348
#                                  team_rolling_summary_gca   43.149845
