# %%
import pandas as pd
import sqlite3
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.metrics import mean_squared_error, mean_absolute_error
import xgboost as xgb
import optuna
import os
import json 


conn = sqlite3.connect(r'C:\Users\Owner\dev\algobetting\infra\data\db\algobetting.db')

df = pd.read_sql_query("""
                        SELECT DISTINCT
                            f.*,
                            ms.summary_goals as goals
                        FROM 
                            team_all_features_365_005 f
                        JOIN
                            fbref_match_all_columns ms
                                ON ms.match_url = f.match_url
                                AND ms.team = f.team
                        WHERE 
                            f.team_rolling_summary_minutes IS NOT NULL
                            AND f.division = 'Premier League'
                       --AND NOT (f.`is_promoted?` = 1 AND f.`is_early_season?` = 1)
                       """, conn)

df
# Out:
#                                               match_url           match_date  \
# 0     https://fbref.com/en/matches/e4bb1c35/Tottenha...  2025-05-25 00:00:00
# 1     https://fbref.com/en/matches/e4bb1c35/Tottenha...  2025-05-25 00:00:00
# 2     https://fbref.com/en/matches/1ff370e8/Bournemo...  2025-05-25 00:00:00
# 3     https://fbref.com/en/matches/1ff370e8/Bournemo...  2025-05-25 00:00:00
# 4     https://fbref.com/en/matches/36844e73/Newcastl...  2025-05-25 00:00:00
# ...                                                 ...                  ...
# 5956  https://fbref.com/en/matches/21b58926/Liverpoo...  2020-09-12 00:00:00
# 5957  https://fbref.com/en/matches/db261cb0/Crystal-...  2020-09-12 00:00:00
# 5958  https://fbref.com/en/matches/db261cb0/Crystal-...  2020-09-12 00:00:00
# 5959  https://fbref.com/en/matches/bf52349b/Fulham-A...  2020-09-12 00:00:00
# 5960  https://fbref.com/en/matches/bf52349b/Fulham-A...  2020-09-12 00:00:00
#
#          season        division            team        opp_team  is_home  gw  \
# 0     2024-2025  Premier League       Tottenham        Brighton        1  38
# 1     2024-2025  Premier League        Brighton       Tottenham        0  38
# 2     2024-2025  Premier League     Bournemouth  Leicester City        1  38
# 3     2024-2025  Premier League  Leicester City     Bournemouth        0  38
# 4     2024-2025  Premier League   Newcastle Utd         Everton        1  38
# ...         ...             ...             ...             ...      ...  ..
# 5956  2020-2021  Premier League    Leeds United       Liverpool        0   1
# 5957  2020-2021  Premier League  Crystal Palace     Southampton        1   1
# 5958  2020-2021  Premier League     Southampton  Crystal Palace        0   1
# 5959  2020-2021  Premier League          Fulham         Arsenal        1   1
# 5960  2020-2021  Premier League         Arsenal          Fulham        0   1
#
#       is_promoted?  is_early_season?  ...  \
# 0                0                 0  ...
# 1                0                 0  ...
# 2                0                 0  ...
# 3                1                 0  ...
# 4                0                 0  ...
# ...            ...               ...  ...
# 5956             1                 1  ...
# 5957             0                 1  ...
# 5958             0                 1  ...
# 5959             1                 1  ...
# 5960             0                 1  ...
#
#       opp_team_rolling_conceded_defense_challenges  \
# 0                                        18.309716
# 1                                        19.336254
# 2                                        14.039872
# 3                                        14.891199
# 4                                        14.492786
# ...                                            ...
# 5956                                     17.351282
# 5957                                     17.968617
# 5958                                     17.930510
# 5959                                     17.279478
# 5960                                     16.585263
#
#       opp_team_rolling_conceded_defense_challenge_tackles_pct  \
# 0                                             50.720617
# 1                                             57.889854
# 2                                             53.893970
# 3                                             49.279905
# 4                                             53.064874
# ...                                                 ...
# 5956                                          39.725765
# 5957                                          37.087656
# 5958                                          38.966705
# 5959                                          40.691854
# 5960                                          41.120229
#
#       opp_team_rolling_conceded_defense_challenges_lost  \
# 0                                              8.796946
# 1                                              7.949406
# 2                                              6.606014
# 3                                              7.520887
# 4                                              6.895930
# ...                                                 ...
# 5956                                          10.328149
# 5957                                          11.181068
# 5958                                          10.953040
# 5959                                          10.211788
# 5960                                           9.983310
#
#       opp_team_rolling_conceded_defense_blocked_shots  \
# 0                                            3.393454
# 1                                            3.378971
# 2                                            2.506894
# 3                                            4.153870
# 4                                            2.600829
# ...                                               ...
# 5956                                         4.258163
# 5957                                         3.952485
# 5958                                         2.684821
# 5959                                         2.561171
# 5960                                         3.740820
#
#       opp_team_rolling_conceded_defense_blocked_passes  \
# 0                                             7.020603
# 1                                             9.378588
# 2                                             6.904780
# 3                                             6.746572
# 4                                             6.075265
# ...                                                ...
# 5956                                          7.257168
# 5957                                          7.942267
# 5958                                          8.033599
# 5959                                          6.396202
# 5960                                          6.319124
#
#       opp_team_rolling_conceded_defense_tackles_interceptions  \
# 0                                             26.403010
# 1                                             32.038948
# 2                                             22.901258
# 3                                             23.732322
# 4                                             24.063503
# ...                                                 ...
# 5956                                          27.029413
# 5957                                          26.825346
# 5958                                          32.571362
# 5959                                          26.695362
# 5960                                          27.863677
#
#       opp_team_rolling_conceded_defense_clearances  \
# 0                                        27.177737
# 1                                        23.558919
# 2                                        21.697324
# 3                                        26.770789
# 4                                        26.142993
# ...                                            ...
# 5956                                     29.952466
# 5957                                     21.945053
# 5958                                     18.209727
# 5959                                     18.161359
# 5960                                     22.246159
#
#       opp_team_rolling_conceded_defense_errors  \
# 0                                     0.862971
# 1                                     0.911136
# 2                                     0.636969
# 3                                     1.451179
# 4                                     0.567784
# ...                                        ...
# 5956                                  0.750397
# 5957                                  0.489783
# 5958                                  0.459216
# 5959                                  0.624812
# 5960                                  0.365258
#
#       opp_team_rolling_conceded_keeper_psxg  goals
# 0                                  1.299603    1.0
# 1                                  1.805191    4.0
# 2                                  1.811285    2.0
# 3                                  1.460762    0.0
# 4                                  1.251694    0.0
# ...                                     ...    ...
# 5956                               0.852680    3.0
# 5957                               1.307413    1.0
# 5958                               1.642488    0.0
# 5959                               1.269339    0.0
# 5960                               1.095485    3.0
#
# [5961 rows x 397 columns]

# %%
# Check for duplicate columns (identical values)
def find_duplicate_columns(df):
    duplicate_pairs = []
    cols = df.columns.tolist()
    
    for i in range(len(cols)):
        for j in range(i+1, len(cols)):
            if df[cols[i]].equals(df[cols[j]]):
                duplicate_pairs.append((cols[i], cols[j]))
    
    return duplicate_pairs

# Find duplicates in your FEATURE MATRIX (not the full df)
duplicates = find_duplicate_columns(df)
print("Duplicate column pairs:")
for pair in duplicates:
    print(f"  {pair[0]} == {pair[1]}")

# More sophisticated duplicate removal logic
columns_to_drop = []
for pair in duplicates:
    col1, col2 = pair
    
    # Priority rules for which column to keep:
    # 1. Keep shorter names
    # 2. Prefer "passing" over "pass_types" 
    # 3. Prefer "summary" over other categories
    # 4. Prefer team stats over opp_team stats (less processing)
    
    keep_col1 = True
    
    # Rule 1: Shorter name
    if len(col1) > len(col2):
        keep_col1 = False
    elif len(col1) < len(col2):
        keep_col1 = True
    else:
        # Same length, apply other rules
        # Rule 2: Prefer passing over pass_types
        if "pass_types" in col1 and "passing" in col2:
            keep_col1 = False
        elif "passing" in col1 and "pass_types" in col2:
            keep_col1 = True
        # Rule 3: Prefer summary stats
        elif "summary" in col1 and "summary" not in col2:
            keep_col1 = True
        elif "summary" in col2 and "summary" not in col1:
            keep_col1 = False
        # Rule 4: Prefer team over opp_team (less nested)
        elif col1.startswith("team_") and col2.startswith("opp_team_"):
            keep_col1 = True
        elif col2.startswith("team_") and col1.startswith("opp_team_"):
            keep_col1 = False
    
    # Add the column to drop
    if keep_col1:
        columns_to_drop.append(col2)
        print(f"  Keeping: {col1}")
        print(f"  Dropping: {col2}")
    else:
        columns_to_drop.append(col1)
        print(f"  Keeping: {col2}")
        print(f"  Dropping: {col1}")
    print()

print(f"Columns to drop: {len(columns_to_drop)}")
print(columns_to_drop)

# Create cleaned feature matrix
df = df.drop(columns=columns_to_drop)
# Out:
# Duplicate column pairs:
#   team_rolling_summary_minutes == team_rolling_pass_types_minutes
#   team_rolling_summary_passes_completed == team_rolling_pass_types_passes_completed
#   team_rolling_summary_passes == team_rolling_pass_types_passes
#   team_rolling_misc_offsides == team_rolling_pass_types_passes_offsides
#   team_rolling_misc_offsides == team_rolling_passing_passes_offsides
#   team_rolling_misc_crosses == team_rolling_pass_types_crosses
#   team_rolling_pass_types_passes_live == team_rolling_passing_passes_live
#   team_rolling_pass_types_passes_dead == team_rolling_passing_passes_dead
#   team_rolling_pass_types_passes_free_kicks == team_rolling_passing_passes_free_kicks
#   team_rolling_pass_types_through_balls == team_rolling_passing_through_balls
#   team_rolling_pass_types_passes_switches == team_rolling_passing_passes_switches
#   team_rolling_pass_types_throw_ins == team_rolling_passing_throw_ins
#   team_rolling_pass_types_corner_kicks == team_rolling_passing_corner_kicks
#   team_rolling_pass_types_corner_kicks_in == team_rolling_passing_corner_kicks_in
#   team_rolling_pass_types_corner_kicks_out == team_rolling_passing_corner_kicks_out
#   team_rolling_pass_types_corner_kicks_straight == team_rolling_passing_corner_kicks_straight
#   team_rolling_pass_types_passes_offsides == team_rolling_passing_passes_offsides
#   team_rolling_pass_types_passes_blocked == team_rolling_passing_passes_blocked
#   team_rolling_conceded_summary_minutes == team_rolling_conceded_pass_types_minutes
#   team_rolling_conceded_summary_passes_completed == team_rolling_conceded_pass_types_passes_completed
#   team_rolling_conceded_summary_passes == team_rolling_conceded_pass_types_passes
#   team_rolling_conceded_misc_offsides == team_rolling_conceded_pass_types_passes_offsides
#   team_rolling_conceded_misc_offsides == team_rolling_conceded_passing_passes_offsides
#   team_rolling_conceded_misc_crosses == team_rolling_conceded_pass_types_crosses
#   team_rolling_conceded_pass_types_passes_live == team_rolling_conceded_passing_passes_live
#   team_rolling_conceded_pass_types_passes_dead == team_rolling_conceded_passing_passes_dead
#   team_rolling_conceded_pass_types_passes_free_kicks == team_rolling_conceded_passing_passes_free_kicks
#   team_rolling_conceded_pass_types_through_balls == team_rolling_conceded_passing_through_balls
#   team_rolling_conceded_pass_types_passes_switches == team_rolling_conceded_passing_passes_switches
#   team_rolling_conceded_pass_types_throw_ins == team_rolling_conceded_passing_throw_ins
#   team_rolling_conceded_pass_types_corner_kicks == team_rolling_conceded_passing_corner_kicks
#   team_rolling_conceded_pass_types_corner_kicks_in == team_rolling_conceded_passing_corner_kicks_in
#   team_rolling_conceded_pass_types_corner_kicks_out == team_rolling_conceded_passing_corner_kicks_out
#   team_rolling_conceded_pass_types_corner_kicks_straight == team_rolling_conceded_passing_corner_kicks_straight
#   team_rolling_conceded_pass_types_passes_offsides == team_rolling_conceded_passing_passes_offsides
#   team_rolling_conceded_pass_types_passes_blocked == team_rolling_conceded_passing_passes_blocked
#   opp_team_rolling_summary_minutes == opp_team_rolling_pass_types_minutes
#   opp_team_rolling_summary_passes_completed == opp_team_rolling_pass_types_passes_completed
#   opp_team_rolling_summary_passes == opp_team_rolling_pass_types_passes
#   opp_team_rolling_misc_offsides == opp_team_rolling_pass_types_passes_offsides
#   opp_team_rolling_misc_offsides == opp_team_rolling_passing_passes_offsides
#   opp_team_rolling_misc_crosses == opp_team_rolling_pass_types_crosses
#   opp_team_rolling_pass_types_passes_live == opp_team_rolling_passing_passes_live
#   opp_team_rolling_pass_types_passes_dead == opp_team_rolling_passing_passes_dead
#   opp_team_rolling_pass_types_passes_free_kicks == opp_team_rolling_passing_passes_free_kicks
#   opp_team_rolling_pass_types_through_balls == opp_team_rolling_passing_through_balls
#   opp_team_rolling_pass_types_passes_switches == opp_team_rolling_passing_passes_switches
#   opp_team_rolling_pass_types_throw_ins == opp_team_rolling_passing_throw_ins
#   opp_team_rolling_pass_types_corner_kicks == opp_team_rolling_passing_corner_kicks
#   opp_team_rolling_pass_types_corner_kicks_in == opp_team_rolling_passing_corner_kicks_in
#   opp_team_rolling_pass_types_corner_kicks_out == opp_team_rolling_passing_corner_kicks_out
#   opp_team_rolling_pass_types_corner_kicks_straight == opp_team_rolling_passing_corner_kicks_straight
#   opp_team_rolling_pass_types_passes_offsides == opp_team_rolling_passing_passes_offsides
#   opp_team_rolling_pass_types_passes_blocked == opp_team_rolling_passing_passes_blocked
#   opp_team_rolling_conceded_summary_minutes == opp_team_rolling_conceded_pass_types_minutes
#   opp_team_rolling_conceded_summary_passes_completed == opp_team_rolling_conceded_pass_types_passes_completed
#   opp_team_rolling_conceded_summary_passes == opp_team_rolling_conceded_pass_types_passes
#   opp_team_rolling_conceded_misc_offsides == opp_team_rolling_conceded_pass_types_passes_offsides
#   opp_team_rolling_conceded_misc_offsides == opp_team_rolling_conceded_passing_passes_offsides
#   opp_team_rolling_conceded_misc_crosses == opp_team_rolling_conceded_pass_types_crosses
#   opp_team_rolling_conceded_pass_types_passes_live == opp_team_rolling_conceded_passing_passes_live
#   opp_team_rolling_conceded_pass_types_passes_dead == opp_team_rolling_conceded_passing_passes_dead
#   opp_team_rolling_conceded_pass_types_passes_free_kicks == opp_team_rolling_conceded_passing_passes_free_kicks
#   opp_team_rolling_conceded_pass_types_through_balls == opp_team_rolling_conceded_passing_through_balls
#   opp_team_rolling_conceded_pass_types_passes_switches == opp_team_rolling_conceded_passing_passes_switches
#   opp_team_rolling_conceded_pass_types_throw_ins == opp_team_rolling_conceded_passing_throw_ins
#   opp_team_rolling_conceded_pass_types_corner_kicks == opp_team_rolling_conceded_passing_corner_kicks
#   opp_team_rolling_conceded_pass_types_corner_kicks_in == opp_team_rolling_conceded_passing_corner_kicks_in
#   opp_team_rolling_conceded_pass_types_corner_kicks_out == opp_team_rolling_conceded_passing_corner_kicks_out
#   opp_team_rolling_conceded_pass_types_corner_kicks_straight == opp_team_rolling_conceded_passing_corner_kicks_straight
#   opp_team_rolling_conceded_pass_types_passes_offsides == opp_team_rolling_conceded_passing_passes_offsides
#   opp_team_rolling_conceded_pass_types_passes_blocked == opp_team_rolling_conceded_passing_passes_blocked
#   Keeping: team_rolling_summary_minutes
#   Dropping: team_rolling_pass_types_minutes
#
#   Keeping: team_rolling_summary_passes_completed
#   Dropping: team_rolling_pass_types_passes_completed
#
#   Keeping: team_rolling_summary_passes
#   Dropping: team_rolling_pass_types_passes
#
#   Keeping: team_rolling_misc_offsides
#   Dropping: team_rolling_pass_types_passes_offsides
#
#   Keeping: team_rolling_misc_offsides
#   Dropping: team_rolling_passing_passes_offsides
#
#   Keeping: team_rolling_misc_crosses
#   Dropping: team_rolling_pass_types_crosses
#
#   Keeping: team_rolling_passing_passes_live
#   Dropping: team_rolling_pass_types_passes_live
#
#   Keeping: team_rolling_passing_passes_dead
#   Dropping: team_rolling_pass_types_passes_dead
#
#   Keeping: team_rolling_passing_passes_free_kicks
#   Dropping: team_rolling_pass_types_passes_free_kicks
#
#   Keeping: team_rolling_passing_through_balls
#   Dropping: team_rolling_pass_types_through_balls
#
#   Keeping: team_rolling_passing_passes_switches
#   Dropping: team_rolling_pass_types_passes_switches
#
#   Keeping: team_rolling_passing_throw_ins
#   Dropping: team_rolling_pass_types_throw_ins
#
#   Keeping: team_rolling_passing_corner_kicks
#   Dropping: team_rolling_pass_types_corner_kicks
#
#   Keeping: team_rolling_passing_corner_kicks_in
#   Dropping: team_rolling_pass_types_corner_kicks_in
#
#   Keeping: team_rolling_passing_corner_kicks_out
#   Dropping: team_rolling_pass_types_corner_kicks_out
#
#   Keeping: team_rolling_passing_corner_kicks_straight
#   Dropping: team_rolling_pass_types_corner_kicks_straight
#
#   Keeping: team_rolling_passing_passes_offsides
#   Dropping: team_rolling_pass_types_passes_offsides
#
#   Keeping: team_rolling_passing_passes_blocked
#   Dropping: team_rolling_pass_types_passes_blocked
#
#   Keeping: team_rolling_conceded_summary_minutes
#   Dropping: team_rolling_conceded_pass_types_minutes
#
#   Keeping: team_rolling_conceded_summary_passes_completed
#   Dropping: team_rolling_conceded_pass_types_passes_completed
#
#   Keeping: team_rolling_conceded_summary_passes
#   Dropping: team_rolling_conceded_pass_types_passes
#
#   Keeping: team_rolling_conceded_misc_offsides
#   Dropping: team_rolling_conceded_pass_types_passes_offsides
#
#   Keeping: team_rolling_conceded_misc_offsides
#   Dropping: team_rolling_conceded_passing_passes_offsides
#
#   Keeping: team_rolling_conceded_misc_crosses
#   Dropping: team_rolling_conceded_pass_types_crosses
#
#   Keeping: team_rolling_conceded_passing_passes_live
#   Dropping: team_rolling_conceded_pass_types_passes_live
#
#   Keeping: team_rolling_conceded_passing_passes_dead
#   Dropping: team_rolling_conceded_pass_types_passes_dead
#
#   Keeping: team_rolling_conceded_passing_passes_free_kicks
#   Dropping: team_rolling_conceded_pass_types_passes_free_kicks
#
#   Keeping: team_rolling_conceded_passing_through_balls
#   Dropping: team_rolling_conceded_pass_types_through_balls
#
#   Keeping: team_rolling_conceded_passing_passes_switches
#   Dropping: team_rolling_conceded_pass_types_passes_switches
#
#   Keeping: team_rolling_conceded_passing_throw_ins
#   Dropping: team_rolling_conceded_pass_types_throw_ins
#
#   Keeping: team_rolling_conceded_passing_corner_kicks
#   Dropping: team_rolling_conceded_pass_types_corner_kicks
#
#   Keeping: team_rolling_conceded_passing_corner_kicks_in
#   Dropping: team_rolling_conceded_pass_types_corner_kicks_in
#
#   Keeping: team_rolling_conceded_passing_corner_kicks_out
#   Dropping: team_rolling_conceded_pass_types_corner_kicks_out
#
#   Keeping: team_rolling_conceded_passing_corner_kicks_straight
#   Dropping: team_rolling_conceded_pass_types_corner_kicks_straight
#
#   Keeping: team_rolling_conceded_passing_passes_offsides
#   Dropping: team_rolling_conceded_pass_types_passes_offsides
#
#   Keeping: team_rolling_conceded_passing_passes_blocked
#   Dropping: team_rolling_conceded_pass_types_passes_blocked
#
#   Keeping: opp_team_rolling_summary_minutes
#   Dropping: opp_team_rolling_pass_types_minutes
#
#   Keeping: opp_team_rolling_summary_passes_completed
#   Dropping: opp_team_rolling_pass_types_passes_completed
#
#   Keeping: opp_team_rolling_summary_passes
#   Dropping: opp_team_rolling_pass_types_passes
#
#   Keeping: opp_team_rolling_misc_offsides
#   Dropping: opp_team_rolling_pass_types_passes_offsides
#
#   Keeping: opp_team_rolling_misc_offsides
#   Dropping: opp_team_rolling_passing_passes_offsides
#
#   Keeping: opp_team_rolling_misc_crosses
#   Dropping: opp_team_rolling_pass_types_crosses
#
#   Keeping: opp_team_rolling_passing_passes_live
#   Dropping: opp_team_rolling_pass_types_passes_live
#
#   Keeping: opp_team_rolling_passing_passes_dead
#   Dropping: opp_team_rolling_pass_types_passes_dead
#
#   Keeping: opp_team_rolling_passing_passes_free_kicks
#   Dropping: opp_team_rolling_pass_types_passes_free_kicks
#
#   Keeping: opp_team_rolling_passing_through_balls
#   Dropping: opp_team_rolling_pass_types_through_balls
#
#   Keeping: opp_team_rolling_passing_passes_switches
#   Dropping: opp_team_rolling_pass_types_passes_switches
#
#   Keeping: opp_team_rolling_passing_throw_ins
#   Dropping: opp_team_rolling_pass_types_throw_ins
#
#   Keeping: opp_team_rolling_passing_corner_kicks
#   Dropping: opp_team_rolling_pass_types_corner_kicks
#
#   Keeping: opp_team_rolling_passing_corner_kicks_in
#   Dropping: opp_team_rolling_pass_types_corner_kicks_in
#
#   Keeping: opp_team_rolling_passing_corner_kicks_out
#   Dropping: opp_team_rolling_pass_types_corner_kicks_out
#
#   Keeping: opp_team_rolling_passing_corner_kicks_straight
#   Dropping: opp_team_rolling_pass_types_corner_kicks_straight
#
#   Keeping: opp_team_rolling_passing_passes_offsides
#   Dropping: opp_team_rolling_pass_types_passes_offsides
#
#   Keeping: opp_team_rolling_passing_passes_blocked
#   Dropping: opp_team_rolling_pass_types_passes_blocked
#
#   Keeping: opp_team_rolling_conceded_summary_minutes
#   Dropping: opp_team_rolling_conceded_pass_types_minutes
#
#   Keeping: opp_team_rolling_conceded_summary_passes_completed
#   Dropping: opp_team_rolling_conceded_pass_types_passes_completed
#
#   Keeping: opp_team_rolling_conceded_summary_passes
#   Dropping: opp_team_rolling_conceded_pass_types_passes
#
#   Keeping: opp_team_rolling_conceded_misc_offsides
#   Dropping: opp_team_rolling_conceded_pass_types_passes_offsides
#
#   Keeping: opp_team_rolling_conceded_misc_offsides
#   Dropping: opp_team_rolling_conceded_passing_passes_offsides
#
#   Keeping: opp_team_rolling_conceded_misc_crosses
#   Dropping: opp_team_rolling_conceded_pass_types_crosses
#
#   Keeping: opp_team_rolling_conceded_passing_passes_live
#   Dropping: opp_team_rolling_conceded_pass_types_passes_live
#
#   Keeping: opp_team_rolling_conceded_passing_passes_dead
#   Dropping: opp_team_rolling_conceded_pass_types_passes_dead
#
#   Keeping: opp_team_rolling_conceded_passing_passes_free_kicks
#   Dropping: opp_team_rolling_conceded_pass_types_passes_free_kicks
#
#   Keeping: opp_team_rolling_conceded_passing_through_balls
#   Dropping: opp_team_rolling_conceded_pass_types_through_balls
#
#   Keeping: opp_team_rolling_conceded_passing_passes_switches
#   Dropping: opp_team_rolling_conceded_pass_types_passes_switches
#
#   Keeping: opp_team_rolling_conceded_passing_throw_ins
#   Dropping: opp_team_rolling_conceded_pass_types_throw_ins
#
#   Keeping: opp_team_rolling_conceded_passing_corner_kicks
#   Dropping: opp_team_rolling_conceded_pass_types_corner_kicks
#
#   Keeping: opp_team_rolling_conceded_passing_corner_kicks_in
#   Dropping: opp_team_rolling_conceded_pass_types_corner_kicks_in
#
#   Keeping: opp_team_rolling_conceded_passing_corner_kicks_out
#   Dropping: opp_team_rolling_conceded_pass_types_corner_kicks_out
#
#   Keeping: opp_team_rolling_conceded_passing_corner_kicks_straight
#   Dropping: opp_team_rolling_conceded_pass_types_corner_kicks_straight
#
#   Keeping: opp_team_rolling_conceded_passing_passes_offsides
#   Dropping: opp_team_rolling_conceded_pass_types_passes_offsides
#
#   Keeping: opp_team_rolling_conceded_passing_passes_blocked
#   Dropping: opp_team_rolling_conceded_pass_types_passes_blocked
#
# Columns to drop: 72
# ['team_rolling_pass_types_minutes', 'team_rolling_pass_types_passes_completed', 'team_rolling_pass_types_passes', 'team_rolling_pass_types_passes_offsides', 'team_rolling_passing_passes_offsides', 'team_rolling_pass_types_crosses', 'team_rolling_pass_types_passes_live', 'team_rolling_pass_types_passes_dead', 'team_rolling_pass_types_passes_free_kicks', 'team_rolling_pass_types_through_balls', 'team_rolling_pass_types_passes_switches', 'team_rolling_pass_types_throw_ins', 'team_rolling_pass_types_corner_kicks', 'team_rolling_pass_types_corner_kicks_in', 'team_rolling_pass_types_corner_kicks_out', 'team_rolling_pass_types_corner_kicks_straight', 'team_rolling_pass_types_passes_offsides', 'team_rolling_pass_types_passes_blocked', 'team_rolling_conceded_pass_types_minutes', 'team_rolling_conceded_pass_types_passes_completed', 'team_rolling_conceded_pass_types_passes', 'team_rolling_conceded_pass_types_passes_offsides', 'team_rolling_conceded_passing_passes_offsides', 'team_rolling_conceded_pass_types_crosses', 'team_rolling_conceded_pass_types_passes_live', 'team_rolling_conceded_pass_types_passes_dead', 'team_rolling_conceded_pass_types_passes_free_kicks', 'team_rolling_conceded_pass_types_through_balls', 'team_rolling_conceded_pass_types_passes_switches', 'team_rolling_conceded_pass_types_throw_ins', 'team_rolling_conceded_pass_types_corner_kicks', 'team_rolling_conceded_pass_types_corner_kicks_in', 'team_rolling_conceded_pass_types_corner_kicks_out', 'team_rolling_conceded_pass_types_corner_kicks_straight', 'team_rolling_conceded_pass_types_passes_offsides', 'team_rolling_conceded_pass_types_passes_blocked', 'opp_team_rolling_pass_types_minutes', 'opp_team_rolling_pass_types_passes_completed', 'opp_team_rolling_pass_types_passes', 'opp_team_rolling_pass_types_passes_offsides', 'opp_team_rolling_passing_passes_offsides', 'opp_team_rolling_pass_types_crosses', 'opp_team_rolling_pass_types_passes_live', 'opp_team_rolling_pass_types_passes_dead', 'opp_team_rolling_pass_types_passes_free_kicks', 'opp_team_rolling_pass_types_through_balls', 'opp_team_rolling_pass_types_passes_switches', 'opp_team_rolling_pass_types_throw_ins', 'opp_team_rolling_pass_types_corner_kicks', 'opp_team_rolling_pass_types_corner_kicks_in', 'opp_team_rolling_pass_types_corner_kicks_out', 'opp_team_rolling_pass_types_corner_kicks_straight', 'opp_team_rolling_pass_types_passes_offsides', 'opp_team_rolling_pass_types_passes_blocked', 'opp_team_rolling_conceded_pass_types_minutes', 'opp_team_rolling_conceded_pass_types_passes_completed', 'opp_team_rolling_conceded_pass_types_passes', 'opp_team_rolling_conceded_pass_types_passes_offsides', 'opp_team_rolling_conceded_passing_passes_offsides', 'opp_team_rolling_conceded_pass_types_crosses', 'opp_team_rolling_conceded_pass_types_passes_live', 'opp_team_rolling_conceded_pass_types_passes_dead', 'opp_team_rolling_conceded_pass_types_passes_free_kicks', 'opp_team_rolling_conceded_pass_types_through_balls', 'opp_team_rolling_conceded_pass_types_passes_switches', 'opp_team_rolling_conceded_pass_types_throw_ins', 'opp_team_rolling_conceded_pass_types_corner_kicks', 'opp_team_rolling_conceded_pass_types_corner_kicks_in', 'opp_team_rolling_conceded_pass_types_corner_kicks_out', 'opp_team_rolling_conceded_pass_types_corner_kicks_straight', 'opp_team_rolling_conceded_pass_types_passes_offsides', 'opp_team_rolling_conceded_pass_types_passes_blocked']

# %%
X = df.drop(columns=["team", "opp_team", "goals", "match_url", "match_date", "division"])
X = pd.get_dummies(X, columns=["season"], drop_first=True)

#X = df[["is_home", "team_rolling_summary_goals", "opp_team_rolling_conceded_summary_goals"]] # goals only

y = df["goals"]

# Use matches after a certain date as test
cutoff_date = '2024-08-01'
df['match_date'] = pd.to_datetime(df['match_date'])

train_mask = df['match_date'] < cutoff_date
test_mask = df['match_date'] >= cutoff_date

X_train = X[train_mask]
X_test = X[test_mask]
y_train = y[train_mask]
y_test = y[test_mask]

# Create DMatrix objects BEFORE using them in eval_list
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

params = {
    'objective': 'count:poisson',
    'max_depth': 7,
    'eta': 0.1,
    'subsample': 0.7,
    'colsample_bytree': 0.8,
    'eval_metric': 'poisson-nloglik'
}

num_rounds = 100
eval_list = [(dtrain, 'train'), (dtest, 'eval')]  # Now dtrain and dtest are defined

model = xgb.train(
    params, 
    dtrain, 
    num_rounds, 
    eval_list, 
    early_stopping_rounds=10,
    verbose_eval=10
)

# Make predictions
preds = model.predict(dtest)

rmse = np.sqrt(mean_squared_error(y_test, preds))
mae = mean_absolute_error(y_test, preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# c:\Users\Owner\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:727: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [0]	train-poisson-nloglik:1.55351	eval-poisson-nloglik:1.54975
# [10]	train-poisson-nloglik:1.42637	eval-poisson-nloglik:1.51450
# [20]	train-poisson-nloglik:1.35398	eval-poisson-nloglik:1.50968
# [30]	train-poisson-nloglik:1.30347	eval-poisson-nloglik:1.50562
# [40]	train-poisson-nloglik:1.26598	eval-poisson-nloglik:1.50342
# [50]	train-poisson-nloglik:1.23947	eval-poisson-nloglik:1.50331
# [55]	train-poisson-nloglik:1.22843	eval-poisson-nloglik:1.50359
# RMSE: 1.1970
# MAE: 0.9583

# %%
# Get feature importance
importance = model.get_score(importance_type='gain')
feature_names = X_train.columns.tolist()

# Create a DataFrame for better visualization
importance_df = pd.DataFrame({
    'feature': list(importance.keys()),
    'importance': list(importance.values())
}).sort_values('importance', ascending=False)

print("Top 10 Most Important Features:")
print(importance_df.head(15))
# Out:
# Top 10 Most Important Features:
#                                                feature  importance
# 25                        team_rolling_summary_carries   18.513756
# 33        team_rolling_possession_touches_att_pen_area   13.144480
# 191        opp_team_rolling_possession_touches_att_3rd   12.994490
# 156      team_rolling_conceded_defense_challenges_lost   12.385612
# 10                team_rolling_summary_shots_on_target   10.003927
# 183        opp_team_rolling_summary_progressive_passes    9.794761
# 21               team_rolling_summary_passes_completed    9.411849
# 40    team_rolling_possession_carries_into_final_third    8.350016
# 198  opp_team_rolling_possession_carries_into_final...    8.059331
# 61                  team_rolling_passing_through_balls    7.868461
# 17                           team_rolling_summary_npxg    7.781621
# 105   team_rolling_conceded_summary_progressive_passes    7.462657
# 144            team_rolling_conceded_passing_throw_ins    7.208937
# 113   team_rolling_conceded_possession_touches_att_3rd    7.076101
# 81                            team_rolling_keeper_psxg    6.949488

# %% [markdown]
# # Hyperparameter Tuning

# %%
# Set to True to tune new parameters, False to load existing
TUNE_NEW_PARAMS = True  # Change this to False to load saved params

# Tuning settings
N_TRIALS = 100
PARAMS_FILE = "best_xgb_params_365.json"

# %%
if TUNE_NEW_PARAMS or not os.path.exists(PARAMS_FILE):
    print("Tuning new hyperparameters...")
    
    def objective(trial):
        # Define search space
        params = {
            'objective': 'count:poisson',
            'eval_metric': 'poisson-nloglik',
            'max_depth': trial.suggest_int('max_depth', 4, 12),  # Deeper trees for more data
            'eta': trial.suggest_float('eta', 0.005, 0.2, log=True),  # Wider range, log scale
            'subsample': trial.suggest_float('subsample', 0.6, 0.95),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 0.8),  # More aggressive for 350 cols
            'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.5, 1.0),  # Additional sampling
            'min_child_weight': trial.suggest_int('min_child_weight', 3, 15),  # Higher for larger dataset
            'gamma': trial.suggest_float('gamma', 0, 5),  # Wider regularization range
            'alpha': trial.suggest_float('alpha', 0, 10),  # L1 reg - good for feature selection
            'lambda': trial.suggest_float('lambda', 1, 10),  # L2 reg - important with many features
            'max_leaves': trial.suggest_int('max_leaves', 0, 200),  # Control tree complexity
            'random_state': 42
        }
        
        n_estimators = trial.suggest_int('n_estimators', 100, 500)
        
        # Train model
        dtrain = xgb.DMatrix(X_train, label=y_train)
        dtest = xgb.DMatrix(X_test, label=y_test)
        
        model = xgb.train(
            params,
            dtrain,
            num_boost_round=n_estimators,
            evals=[(dtrain, 'train'), (dtest, 'eval')],
            early_stopping_rounds=20,
            verbose_eval=False
        )
        
        # Calculate RMSE
        preds = model.predict(dtest)
        rmse = np.sqrt(mean_squared_error(y_test, preds))
        
        return rmse
    
    # Run optimization
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=N_TRIALS, show_progress_bar=True)
    
    # Get best parameters
    best_params = study.best_params.copy()
    n_estimators = best_params.pop('n_estimators')
    
    print(f"Best RMSE: {study.best_value:.4f}")
    print("Best parameters:")
    for key, value in best_params.items():
        if key not in ['objective', 'eval_metric', 'random_state']:
            print(f"  {key}: {value}")
    print(f"  n_estimators: {n_estimators}")
    
    # Save parameters
    params_to_save = {
        'best_params': best_params,
        'n_estimators': n_estimators,
        'best_rmse': study.best_value
    }
    
    with open(PARAMS_FILE, 'w') as f:
        json.dump(params_to_save, f, indent=2)
    print(f"\nParameters saved to {PARAMS_FILE}")
    
else:
    print("Loading saved hyperparameters...")
    
    with open(PARAMS_FILE, 'r') as f:
        saved_params = json.load(f)
    
    best_params = saved_params['best_params']
    n_estimators = saved_params['n_estimators']
    
    print("Loaded parameters:")
    for key, value in best_params.items():
        if key not in ['objective', 'eval_metric', 'random_state']:
            print(f"  {key}: {value}")
    print(f"  n_estimators: {n_estimators}")
    print(f"Previous best RMSE: {saved_params['best_rmse']:.4f}")
# Out:
# [I 2025-08-05 07:57:33,108] A new study created in memory with name: no-name-428d21dd-b66c-4bc6-acd6-27fe129c5f5a
# Tuning new hyperparameters...
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-08-05 07:57:34,815] Trial 0 finished with value: 1.181246250703139 and parameters: {'max_depth': 11, 'eta': 0.1258835806704184, 'subsample': 0.8320633613133379, 'colsample_bytree': 0.5700170367804736, 'colsample_bylevel': 0.5497904681717609, 'min_child_weight': 10, 'gamma': 2.733018787769079, 'alpha': 2.3716021748757496, 'lambda': 6.812002395361921, 'max_leaves': 24, 'n_estimators': 477}. Best is trial 0 with value: 1.181246250703139.
# [I 2025-08-05 07:57:36,715] Trial 1 finished with value: 1.18758339571922 and parameters: {'max_depth': 4, 'eta': 0.01857178925164573, 'subsample': 0.7163163320933111, 'colsample_bytree': 0.6779209628614776, 'colsample_bylevel': 0.7510876880344842, 'min_child_weight': 3, 'gamma': 0.3905458332609635, 'alpha': 6.821523925528719, 'lambda': 7.164711611619235, 'max_leaves': 7, 'n_estimators': 139}. Best is trial 0 with value: 1.181246250703139.
# [I 2025-08-05 07:57:42,923] Trial 2 finished with value: 1.1742605737523697 and parameters: {'max_depth': 12, 'eta': 0.028309055440903313, 'subsample': 0.7210541430925536, 'colsample_bytree': 0.615324155161582, 'colsample_bylevel': 0.5427473039680646, 'min_child_weight': 14, 'gamma': 2.2313577096351835, 'alpha': 6.568861726359061, 'lambda': 7.17119881720525, 'max_leaves': 39, 'n_estimators': 356}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:57:45,364] Trial 3 finished with value: 1.194717094893794 and parameters: {'max_depth': 12, 'eta': 0.14364168537631078, 'subsample': 0.624477691039783, 'colsample_bytree': 0.4201427702488384, 'colsample_bylevel': 0.699917115791621, 'min_child_weight': 15, 'gamma': 3.56419315877197, 'alpha': 1.848168279754887, 'lambda': 1.623876648395977, 'max_leaves': 171, 'n_estimators': 216}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:57:47,550] Trial 4 finished with value: 1.1911922285998038 and parameters: {'max_depth': 5, 'eta': 0.05137557447246161, 'subsample': 0.813317589131918, 'colsample_bytree': 0.6546160464325708, 'colsample_bylevel': 0.560656311552997, 'min_child_weight': 14, 'gamma': 1.1314801498369338, 'alpha': 5.505505098233988, 'lambda': 2.1735000303665113, 'max_leaves': 4, 'n_estimators': 256}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:57:49,687] Trial 5 finished with value: 1.1843368081626928 and parameters: {'max_depth': 10, 'eta': 0.07644085422589397, 'subsample': 0.9442803767877651, 'colsample_bytree': 0.39437782142371774, 'colsample_bylevel': 0.7636214830153811, 'min_child_weight': 9, 'gamma': 4.753945174460178, 'alpha': 9.831650476612296, 'lambda': 1.7252258660351185, 'max_leaves': 32, 'n_estimators': 185}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:57:50,813] Trial 6 finished with value: 1.1953977001873968 and parameters: {'max_depth': 5, 'eta': 0.16366132749064072, 'subsample': 0.7645369952813557, 'colsample_bytree': 0.5416743088146587, 'colsample_bylevel': 0.9496693159681975, 'min_child_weight': 9, 'gamma': 0.01967624863867312, 'alpha': 0.5823889298573481, 'lambda': 3.8204876849199727, 'max_leaves': 144, 'n_estimators': 346}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:57:54,269] Trial 7 finished with value: 1.17457460107238 and parameters: {'max_depth': 9, 'eta': 0.08667759315840072, 'subsample': 0.6255831904907498, 'colsample_bytree': 0.4455664433747076, 'colsample_bylevel': 0.5119535537444351, 'min_child_weight': 11, 'gamma': 2.5521934807133513, 'alpha': 9.53786282332144, 'lambda': 2.4843236043557866, 'max_leaves': 136, 'n_estimators': 206}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:57:56,315] Trial 8 finished with value: 1.1952545759974613 and parameters: {'max_depth': 12, 'eta': 0.16278420254212012, 'subsample': 0.6898170809323447, 'colsample_bytree': 0.3299159284049071, 'colsample_bylevel': 0.7013664911253737, 'min_child_weight': 11, 'gamma': 1.826877793268387, 'alpha': 7.1616715706905145, 'lambda': 2.0309035656263035, 'max_leaves': 49, 'n_estimators': 348}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:57:57,308] Trial 9 finished with value: 1.1860378568489502 and parameters: {'max_depth': 4, 'eta': 0.10476455307315707, 'subsample': 0.8425865053692253, 'colsample_bytree': 0.40286918443294645, 'colsample_bylevel': 0.515420881685817, 'min_child_weight': 12, 'gamma': 2.9796941889752473, 'alpha': 8.937205905077208, 'lambda': 4.170124523898332, 'max_leaves': 42, 'n_estimators': 319}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:58:13,601] Trial 10 finished with value: 1.1832331976883876 and parameters: {'max_depth': 7, 'eta': 0.005688103391151247, 'subsample': 0.9312503528452887, 'colsample_bytree': 0.7800044666869437, 'colsample_bylevel': 0.9949408592636326, 'min_child_weight': 6, 'gamma': 3.949392251249998, 'alpha': 4.167153230086525, 'lambda': 9.782104553236866, 'max_leaves': 83, 'n_estimators': 447}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:58:19,108] Trial 11 finished with value: 1.1883276705736305 and parameters: {'max_depth': 9, 'eta': 0.022484969011916787, 'subsample': 0.6203405637433579, 'colsample_bytree': 0.5092052838158773, 'colsample_bylevel': 0.6199868348553254, 'min_child_weight': 13, 'gamma': 1.845319080781314, 'alpha': 7.841608501094288, 'lambda': 8.172366974963895, 'max_leaves': 114, 'n_estimators': 100}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:58:25,314] Trial 12 finished with value: 1.1757080205842587 and parameters: {'max_depth': 8, 'eta': 0.04046086885813785, 'subsample': 0.6823670717293578, 'colsample_bytree': 0.6341612231363616, 'colsample_bylevel': 0.620245400429436, 'min_child_weight': 15, 'gamma': 1.8572887387694847, 'alpha': 5.216801702388653, 'lambda': 5.382243865458067, 'max_leaves': 90, 'n_estimators': 413}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:58:39,063] Trial 13 finished with value: 1.1803313707446996 and parameters: {'max_depth': 10, 'eta': 0.01317868926462354, 'subsample': 0.7429530379559066, 'colsample_bytree': 0.475233018490987, 'colsample_bylevel': 0.8748909062840486, 'min_child_weight': 12, 'gamma': 2.440585867767646, 'alpha': 8.389518386714702, 'lambda': 4.134869424458962, 'max_leaves': 137, 'n_estimators': 278}. Best is trial 2 with value: 1.1742605737523697.
# [I 2025-08-05 07:58:45,439] Trial 14 finished with value: 1.1707341812442578 and parameters: {'max_depth': 7, 'eta': 0.06615990697298679, 'subsample': 0.6481102311816317, 'colsample_bytree': 0.736744868330053, 'colsample_bylevel': 0.5054789694882442, 'min_child_weight': 7, 'gamma': 1.0427436347908243, 'alpha': 9.99514586442668, 'lambda': 5.898536175348958, 'max_leaves': 183, 'n_estimators': 393}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:58:51,708] Trial 15 finished with value: 1.1917056758201192 and parameters: {'max_depth': 7, 'eta': 0.05617031675852503, 'subsample': 0.6666637945910262, 'colsample_bytree': 0.7967154015995206, 'colsample_bylevel': 0.6038603385078778, 'min_child_weight': 7, 'gamma': 0.9180521449228252, 'alpha': 6.243687222431248, 'lambda': 6.060378547208593, 'max_leaves': 198, 'n_estimators': 409}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:59:02,945] Trial 16 finished with value: 1.1752304384265397 and parameters: {'max_depth': 7, 'eta': 0.02814544034422379, 'subsample': 0.7903073604778673, 'colsample_bytree': 0.7221066584192721, 'colsample_bylevel': 0.8185670044431537, 'min_child_weight': 6, 'gamma': 1.1663611221475363, 'alpha': 3.933173479014025, 'lambda': 8.40491135089437, 'max_leaves': 64, 'n_estimators': 374}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:59:13,848] Trial 17 finished with value: 1.1824445691161043 and parameters: {'max_depth': 6, 'eta': 0.0070153527261841014, 'subsample': 0.7226409205554428, 'colsample_bytree': 0.607761744840394, 'colsample_bylevel': 0.6698719717794147, 'min_child_weight': 7, 'gamma': 0.6219564002836648, 'alpha': 7.888493638419014, 'lambda': 5.539171933342898, 'max_leaves': 197, 'n_estimators': 401}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:59:36,020] Trial 18 finished with value: 1.1767168974613953 and parameters: {'max_depth': 8, 'eta': 0.012825163720463188, 'subsample': 0.6590042688625544, 'colsample_bytree': 0.721352440388777, 'colsample_bylevel': 0.5014027283400095, 'min_child_weight': 3, 'gamma': 1.5127277826536178, 'alpha': 3.6241491650766977, 'lambda': 7.784650616165544, 'max_leaves': 112, 'n_estimators': 454}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:59:41,323] Trial 19 finished with value: 1.176074670489319 and parameters: {'max_depth': 11, 'eta': 0.03469098604271018, 'subsample': 0.8746639471924602, 'colsample_bytree': 0.7117756573359906, 'colsample_bylevel': 0.5737202141434177, 'min_child_weight': 5, 'gamma': 3.3245749126715385, 'alpha': 6.495812932807841, 'lambda': 9.082836710041377, 'max_leaves': 67, 'n_estimators': 315}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:59:43,892] Trial 20 finished with value: 1.1825738471438643 and parameters: {'max_depth': 9, 'eta': 0.059631428291894814, 'subsample': 0.7137816266076639, 'colsample_bytree': 0.580102043433982, 'colsample_bylevel': 0.6585708474488831, 'min_child_weight': 8, 'gamma': 4.783680779786764, 'alpha': 9.83930706586012, 'lambda': 6.583598875043699, 'max_leaves': 167, 'n_estimators': 493}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:59:47,491] Trial 21 finished with value: 1.1809723531805971 and parameters: {'max_depth': 10, 'eta': 0.08717379396586285, 'subsample': 0.607943813383039, 'colsample_bytree': 0.4573925043294215, 'colsample_bylevel': 0.5031573983018189, 'min_child_weight': 11, 'gamma': 2.3389285305902234, 'alpha': 8.928775259825606, 'lambda': 3.135517809701766, 'max_leaves': 139, 'n_estimators': 233}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:59:50,870] Trial 22 finished with value: 1.1866656572516772 and parameters: {'max_depth': 9, 'eta': 0.07769675615623164, 'subsample': 0.645447501361104, 'colsample_bytree': 0.3070745717338924, 'colsample_bylevel': 0.5492713319188112, 'min_child_weight': 13, 'gamma': 2.1756455899812854, 'alpha': 9.985625563491215, 'lambda': 4.873411972410567, 'max_leaves': 174, 'n_estimators': 286}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:59:54,200] Trial 23 finished with value: 1.1823661679178648 and parameters: {'max_depth': 6, 'eta': 0.041263863732876854, 'subsample': 0.6472205082135343, 'colsample_bytree': 0.7579467817212363, 'colsample_bylevel': 0.5888173326773329, 'min_child_weight': 10, 'gamma': 2.8790592611973276, 'alpha': 8.904530029015, 'lambda': 3.1197283175266994, 'max_leaves': 155, 'n_estimators': 165}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:59:57,338] Trial 24 finished with value: 1.175365018342299 and parameters: {'max_depth': 11, 'eta': 0.06632251585214845, 'subsample': 0.6950114112365805, 'colsample_bytree': 0.5210100309429626, 'colsample_bylevel': 0.5400071757395212, 'min_child_weight': 14, 'gamma': 4.2261007003167155, 'alpha': 7.515563835733011, 'lambda': 7.2764812688469656, 'max_leaves': 128, 'n_estimators': 365}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 07:59:59,178] Trial 25 finished with value: 1.1942564121793766 and parameters: {'max_depth': 6, 'eta': 0.10757823349608443, 'subsample': 0.6045576809225618, 'colsample_bytree': 0.47574056619329297, 'colsample_bylevel': 0.6312112621287215, 'min_child_weight': 8, 'gamma': 1.4605737714747649, 'alpha': 9.003911113546826, 'lambda': 6.159217703133953, 'max_leaves': 116, 'n_estimators': 325}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:00:04,111] Trial 26 finished with value: 1.1798526427610823 and parameters: {'max_depth': 8, 'eta': 0.02591968995490078, 'subsample': 0.7492312008131208, 'colsample_bytree': 0.36000110793232626, 'colsample_bylevel': 0.5240249901373181, 'min_child_weight': 5, 'gamma': 3.126848239606635, 'alpha': 5.829106256778515, 'lambda': 4.66094938622752, 'max_leaves': 177, 'n_estimators': 212}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:00:20,252] Trial 27 finished with value: 1.1742337870490358 and parameters: {'max_depth': 12, 'eta': 0.017109605457270412, 'subsample': 0.6387727192252288, 'colsample_bytree': 0.6120401029816385, 'colsample_bylevel': 0.5901834553292129, 'min_child_weight': 11, 'gamma': 2.0995118741791727, 'alpha': 4.523073530682316, 'lambda': 2.670490728288683, 'max_leaves': 97, 'n_estimators': 388}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:00:37,538] Trial 28 finished with value: 1.176833137804046 and parameters: {'max_depth': 12, 'eta': 0.016878249472735113, 'subsample': 0.6733314502985934, 'colsample_bytree': 0.6247066983265817, 'colsample_bylevel': 0.5814233224937435, 'min_child_weight': 13, 'gamma': 1.517637652019169, 'alpha': 4.67234802217486, 'lambda': 5.544086154978689, 'max_leaves': 80, 'n_estimators': 390}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:00:43,308] Trial 29 finished with value: 1.178429161480751 and parameters: {'max_depth': 11, 'eta': 0.010479053752400772, 'subsample': 0.6430339521395956, 'colsample_bytree': 0.575699088451972, 'colsample_bylevel': 0.6556169366898648, 'min_child_weight': 10, 'gamma': 2.1297278955679015, 'alpha': 3.067501542854886, 'lambda': 1.0325172712728181, 'max_leaves': 19, 'n_estimators': 438}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:00:52,987] Trial 30 finished with value: 1.1783404873768115 and parameters: {'max_depth': 12, 'eta': 0.018956777192513805, 'subsample': 0.7832187645575521, 'colsample_bytree': 0.6788796795362955, 'colsample_bylevel': 0.559997654975796, 'min_child_weight': 12, 'gamma': 0.8289195882097746, 'alpha': 2.4392077733436244, 'lambda': 6.950953331465628, 'max_leaves': 57, 'n_estimators': 466}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:00:59,343] Trial 31 finished with value: 1.179597132467303 and parameters: {'max_depth': 10, 'eta': 0.04691745221027249, 'subsample': 0.6362225970322387, 'colsample_bytree': 0.6011120812338755, 'colsample_bylevel': 0.5326800073369378, 'min_child_weight': 11, 'gamma': 2.294807276838269, 'alpha': 4.7521546095290335, 'lambda': 3.2411529582563396, 'max_leaves': 94, 'n_estimators': 426}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:01:08,683] Trial 32 finished with value: 1.177397936360723 and parameters: {'max_depth': 11, 'eta': 0.03344467931247483, 'subsample': 0.7009628272355263, 'colsample_bytree': 0.6819174786913098, 'colsample_bylevel': 0.5374910844557208, 'min_child_weight': 8, 'gamma': 2.5784250635033406, 'alpha': 8.19688248271364, 'lambda': 2.72512995460712, 'max_leaves': 153, 'n_estimators': 370}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:01:27,909] Trial 33 finished with value: 1.1795718447246486 and parameters: {'max_depth': 12, 'eta': 0.008770800141414167, 'subsample': 0.6247041494538119, 'colsample_bytree': 0.5557230242980404, 'colsample_bylevel': 0.5863905009340982, 'min_child_weight': 10, 'gamma': 2.6116894696815818, 'alpha': 6.8223817884764735, 'lambda': 2.5471521611090084, 'max_leaves': 123, 'n_estimators': 343}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:01:34,882] Trial 34 finished with value: 1.179495608961237 and parameters: {'max_depth': 9, 'eta': 0.022798366407787343, 'subsample': 0.7325640753167563, 'colsample_bytree': 0.7509748796497022, 'colsample_bylevel': 0.5000817156128687, 'min_child_weight': 14, 'gamma': 3.4134124695593755, 'alpha': 9.328723128908678, 'lambda': 1.1158467327487716, 'max_leaves': 105, 'n_estimators': 292}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:01:38,108] Trial 35 finished with value: 1.198310594391486 and parameters: {'max_depth': 8, 'eta': 0.12047718793582839, 'subsample': 0.6661416113408306, 'colsample_bytree': 0.645013924879918, 'colsample_bylevel': 0.6963053292614698, 'min_child_weight': 11, 'gamma': 0.40739653182459445, 'alpha': 1.6862757352333477, 'lambda': 7.507286942583225, 'max_leaves': 187, 'n_estimators': 261}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:01:46,756] Trial 36 finished with value: 1.1768095779301162 and parameters: {'max_depth': 11, 'eta': 0.01839984816217608, 'subsample': 0.7083536780141696, 'colsample_bytree': 0.6674466243706301, 'colsample_bylevel': 0.7806987990010332, 'min_child_weight': 9, 'gamma': 3.6931454349636694, 'alpha': 5.639793679693367, 'lambda': 6.439691613630969, 'max_leaves': 160, 'n_estimators': 388}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:01:48,378] Trial 37 finished with value: 1.1884378061383425 and parameters: {'max_depth': 12, 'eta': 0.09118303148745338, 'subsample': 0.6009609945722721, 'colsample_bytree': 0.5431899515582479, 'colsample_bylevel': 0.5655766470669974, 'min_child_weight': 14, 'gamma': 1.2368173830316946, 'alpha': 3.150404230188577, 'lambda': 3.6204199202346183, 'max_leaves': 24, 'n_estimators': 178}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:01:49,728] Trial 38 finished with value: 1.1899442952423676 and parameters: {'max_depth': 5, 'eta': 0.14209067099605213, 'subsample': 0.6283196191623099, 'colsample_bytree': 0.7009165747914966, 'colsample_bylevel': 0.7353009941874926, 'min_child_weight': 9, 'gamma': 1.8590560631642616, 'alpha': 9.4194960047945, 'lambda': 4.842329326038357, 'max_leaves': 12, 'n_estimators': 126}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:01:55,955] Trial 39 finished with value: 1.1871577114795653 and parameters: {'max_depth': 10, 'eta': 0.015077934192888689, 'subsample': 0.7629409276791943, 'colsample_bytree': 0.5065573146440399, 'colsample_bylevel': 0.5299996033155494, 'min_child_weight': 12, 'gamma': 0.06688232409362249, 'alpha': 7.191149225887, 'lambda': 2.214979546051267, 'max_leaves': 37, 'n_estimators': 216}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:01:58,902] Trial 40 finished with value: 1.1826300505086627 and parameters: {'max_depth': 7, 'eta': 0.06735330284569345, 'subsample': 0.683960609011526, 'colsample_bytree': 0.42918916212307967, 'colsample_bylevel': 0.6015060568162177, 'min_child_weight': 7, 'gamma': 2.8049787324654702, 'alpha': 8.472111293589943, 'lambda': 1.581218507868342, 'max_leaves': 72, 'n_estimators': 335}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:05,573] Trial 41 finished with value: 1.1878330744664494 and parameters: {'max_depth': 7, 'eta': 0.02753966152381362, 'subsample': 0.798518742877287, 'colsample_bytree': 0.7303960201616015, 'colsample_bylevel': 0.8074442955139691, 'min_child_weight': 5, 'gamma': 1.1826812039451855, 'alpha': 4.120542781092564, 'lambda': 8.337813292019673, 'max_leaves': 57, 'n_estimators': 364}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:07,363] Trial 42 finished with value: 1.2032955384534638 and parameters: {'max_depth': 6, 'eta': 0.19349650537068802, 'subsample': 0.8361897666607659, 'colsample_bytree': 0.7435426113444079, 'colsample_bylevel': 0.8519062161771797, 'min_child_weight': 6, 'gamma': 1.99879678283888, 'alpha': 4.192829035599575, 'lambda': 9.048627984061532, 'max_leaves': 101, 'n_estimators': 371}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:18,072] Trial 43 finished with value: 1.1772443952738798 and parameters: {'max_depth': 7, 'eta': 0.02792092226327427, 'subsample': 0.8176039588262818, 'colsample_bytree': 0.7763545023124713, 'colsample_bylevel': 0.852038512092446, 'min_child_weight': 4, 'gamma': 1.638300916094175, 'alpha': 5.05597246458064, 'lambda': 8.617659262173913, 'max_leaves': 53, 'n_estimators': 429}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:24,407] Trial 44 finished with value: 1.1734085025310423 and parameters: {'max_depth': 5, 'eta': 0.04336886830218604, 'subsample': 0.7914578891263843, 'colsample_bytree': 0.6937223214320591, 'colsample_bylevel': 0.7996559485664196, 'min_child_weight': 15, 'gamma': 0.976502281383445, 'alpha': 3.6596051193335986, 'lambda': 7.684544834080256, 'max_leaves': 72, 'n_estimators': 305}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:27,157] Trial 45 finished with value: 1.1810062766335485 and parameters: {'max_depth': 4, 'eta': 0.040862275599624014, 'subsample': 0.8563002515059915, 'colsample_bytree': 0.6139030762758101, 'colsample_bylevel': 0.7280526437422994, 'min_child_weight': 15, 'gamma': 0.544845327010766, 'alpha': 1.2333373172663564, 'lambda': 7.663741632149037, 'max_leaves': 81, 'n_estimators': 308}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:29,995] Trial 46 finished with value: 1.185123072135937 and parameters: {'max_depth': 5, 'eta': 0.05265137089893961, 'subsample': 0.7649970555256619, 'colsample_bytree': 0.6545692755016512, 'colsample_bylevel': 0.879387472469745, 'min_child_weight': 15, 'gamma': 0.7863129704127805, 'alpha': 3.073795168041463, 'lambda': 5.962101022993365, 'max_leaves': 90, 'n_estimators': 269}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:33,017] Trial 47 finished with value: 1.178051678952308 and parameters: {'max_depth': 5, 'eta': 0.04823464897631327, 'subsample': 0.652243638552937, 'colsample_bytree': 0.6985009186124808, 'colsample_bylevel': 0.5606911601320581, 'min_child_weight': 13, 'gamma': 0.19577841766182935, 'alpha': 6.002592310049501, 'lambda': 6.805961027778285, 'max_leaves': 43, 'n_estimators': 240}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:36,724] Trial 48 finished with value: 1.1805527119937949 and parameters: {'max_depth': 4, 'eta': 0.0225240404626449, 'subsample': 0.9018977274645015, 'colsample_bytree': 0.646357585921527, 'colsample_bylevel': 0.9059521227798691, 'min_child_weight': 15, 'gamma': 1.0348006997734518, 'alpha': 0.014772981036584198, 'lambda': 7.943478783214555, 'max_leaves': 30, 'n_estimators': 351}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:39,571] Trial 49 finished with value: 1.23481454722471 and parameters: {'max_depth': 12, 'eta': 0.034865836623975355, 'subsample': 0.807201613863168, 'colsample_bytree': 0.5915506879450173, 'colsample_bylevel': 0.7654958284089463, 'min_child_weight': 14, 'gamma': 1.3322644842261933, 'alpha': 2.5486881696916424, 'lambda': 7.302990799495971, 'max_leaves': 1, 'n_estimators': 397}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:41,365] Trial 50 finished with value: 1.191022320591579 and parameters: {'max_depth': 6, 'eta': 0.06797278821731305, 'subsample': 0.6174166959220471, 'colsample_bytree': 0.3596540516549647, 'colsample_bylevel': 0.6259288321262649, 'min_child_weight': 12, 'gamma': 3.0833150361497124, 'alpha': 3.6105587380145683, 'lambda': 5.190836857627983, 'max_leaves': 126, 'n_estimators': 327}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:02:56,497] Trial 51 finished with value: 1.1753089799780314 and parameters: {'max_depth': 8, 'eta': 0.030155951826624405, 'subsample': 0.7775555052640978, 'colsample_bytree': 0.7249267907020646, 'colsample_bylevel': 0.7853801667933102, 'min_child_weight': 7, 'gamma': 0.9957011413857668, 'alpha': 4.439906399440336, 'lambda': 9.416164798158457, 'max_leaves': 65, 'n_estimators': 302}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:03:04,524] Trial 52 finished with value: 1.1786257441734835 and parameters: {'max_depth': 7, 'eta': 0.037225262571843956, 'subsample': 0.7974494645533637, 'colsample_bytree': 0.7785118410889587, 'colsample_bylevel': 0.81963578790854, 'min_child_weight': 6, 'gamma': 1.6711428306655982, 'alpha': 3.6935294031595745, 'lambda': 8.086966542837024, 'max_leaves': 72, 'n_estimators': 420}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:03:08,165] Trial 53 finished with value: 1.1765627246883765 and parameters: {'max_depth': 9, 'eta': 0.08980659873877243, 'subsample': 0.739953886283151, 'colsample_bytree': 0.6954483463094758, 'colsample_bylevel': 0.5171093423109919, 'min_child_weight': 8, 'gamma': 0.7176115320486978, 'alpha': 5.3428101416850176, 'lambda': 8.681411006868776, 'max_leaves': 63, 'n_estimators': 380}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:03:15,731] Trial 54 finished with value: 1.180880813632937 and parameters: {'max_depth': 8, 'eta': 0.04342221684840451, 'subsample': 0.7228865680074686, 'colsample_bytree': 0.6682956050122675, 'colsample_bylevel': 0.8276277251422605, 'min_child_weight': 6, 'gamma': 2.454606850475204, 'alpha': 3.8536178852211536, 'lambda': 5.820088485204266, 'max_leaves': 96, 'n_estimators': 356}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:03:21,168] Trial 55 finished with value: 1.1831183308091762 and parameters: {'max_depth': 5, 'eta': 0.024626247926515153, 'subsample': 0.8161613848784379, 'colsample_bytree': 0.6219934660017855, 'colsample_bylevel': 0.7129096737948306, 'min_child_weight': 10, 'gamma': 2.009918199448982, 'alpha': 9.579840321042727, 'lambda': 6.401706382981436, 'max_leaves': 49, 'n_estimators': 400}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:03:32,663] Trial 56 finished with value: 1.178820397941234 and parameters: {'max_depth': 6, 'eta': 0.019705076244002525, 'subsample': 0.7876127862981971, 'colsample_bytree': 0.7999534259415308, 'colsample_bylevel': 0.9517547374035156, 'min_child_weight': 9, 'gamma': 1.3610497546377514, 'alpha': 4.8269093969577215, 'lambda': 9.812763658535257, 'max_leaves': 87, 'n_estimators': 338}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:03:36,939] Trial 57 finished with value: 1.187948008510362 and parameters: {'max_depth': 7, 'eta': 0.057103390059924874, 'subsample': 0.7594765472477271, 'colsample_bytree': 0.7636608606097669, 'colsample_bylevel': 0.7981571925191892, 'min_child_weight': 13, 'gamma': 0.48692770991211354, 'alpha': 3.3756131444639697, 'lambda': 4.001273681907043, 'max_leaves': 73, 'n_estimators': 377}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:03:57,960] Trial 58 finished with value: 1.1752302983075076 and parameters: {'max_depth': 10, 'eta': 0.01293340872248268, 'subsample': 0.675821293699902, 'colsample_bytree': 0.5633810031637109, 'colsample_bylevel': 0.7548488845481388, 'min_child_weight': 15, 'gamma': 1.724965434795343, 'alpha': 2.582656831283887, 'lambda': 8.540143613253568, 'max_leaves': 106, 'n_estimators': 410}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:04:20,116] Trial 59 finished with value: 1.1731581175219925 and parameters: {'max_depth': 10, 'eta': 0.010780914586685245, 'subsample': 0.6759512278173593, 'colsample_bytree': 0.5222753845398084, 'colsample_bylevel': 0.7512292743835047, 'min_child_weight': 15, 'gamma': 1.7837011618680751, 'alpha': 2.702440223140328, 'lambda': 4.49155553218112, 'max_leaves': 107, 'n_estimators': 406}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:04:40,215] Trial 60 finished with value: 1.1764997792034995 and parameters: {'max_depth': 9, 'eta': 0.010358439144720127, 'subsample': 0.6599117220084131, 'colsample_bytree': 0.5269247242666242, 'colsample_bylevel': 0.5464748386541632, 'min_child_weight': 14, 'gamma': 2.2071507262199797, 'alpha': 2.053055942742299, 'lambda': 3.6209632502276845, 'max_leaves': 133, 'n_estimators': 468}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:05:04,878] Trial 61 finished with value: 1.1766854029587996 and parameters: {'max_depth': 10, 'eta': 0.012144779789137184, 'subsample': 0.6360404619096391, 'colsample_bytree': 0.4820753461874842, 'colsample_bylevel': 0.7591135992787832, 'min_child_weight': 15, 'gamma': 1.7227488360847345, 'alpha': 2.691129257908959, 'lambda': 4.562110142530147, 'max_leaves': 113, 'n_estimators': 402}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:05:29,734] Trial 62 finished with value: 1.175928941551905 and parameters: {'max_depth': 10, 'eta': 0.008207983278847704, 'subsample': 0.6777604026702373, 'colsample_bytree': 0.5611812262570601, 'colsample_bylevel': 0.7357665597153603, 'min_child_weight': 15, 'gamma': 1.9963737306185816, 'alpha': 2.1042037273044967, 'lambda': 1.8553094885648655, 'max_leaves': 106, 'n_estimators': 440}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:05:43,284] Trial 63 finished with value: 1.173917115371133 and parameters: {'max_depth': 11, 'eta': 0.014502604236167773, 'subsample': 0.6947585613559499, 'colsample_bytree': 0.4490754886160497, 'colsample_bylevel': 0.6932790039898774, 'min_child_weight': 14, 'gamma': 2.6617063778723398, 'alpha': 2.8445742923784874, 'lambda': 2.740820335131566, 'max_leaves': 144, 'n_estimators': 414}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:05:58,717] Trial 64 finished with value: 1.1800610493957682 and parameters: {'max_depth': 11, 'eta': 0.0150979577995884, 'subsample': 0.6919398847983846, 'colsample_bytree': 0.42565125190475867, 'colsample_bylevel': 0.6877396542664423, 'min_child_weight': 13, 'gamma': 2.687695470407437, 'alpha': 1.1983782632656519, 'lambda': 2.6541067481940637, 'max_leaves': 144, 'n_estimators': 449}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:06:27,127] Trial 65 finished with value: 1.1857696275106788 and parameters: {'max_depth': 12, 'eta': 0.005544658302006494, 'subsample': 0.655687908473761, 'colsample_bytree': 0.3981008960712316, 'colsample_bylevel': 0.6408691104414069, 'min_child_weight': 14, 'gamma': 2.4332872970130044, 'alpha': 2.9024017653011254, 'lambda': 2.8986403659801114, 'max_leaves': 145, 'n_estimators': 384}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:06:47,637] Trial 66 finished with value: 1.1786183012098583 and parameters: {'max_depth': 11, 'eta': 0.006750575143060034, 'subsample': 0.6125417885739219, 'colsample_bytree': 0.45093594616479415, 'colsample_bylevel': 0.5144585032571638, 'min_child_weight': 12, 'gamma': 2.9417427670285456, 'alpha': 1.6130429386835632, 'lambda': 2.178395496972717, 'max_leaves': 120, 'n_estimators': 425}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:07:09,887] Trial 67 finished with value: 1.1814220457932292 and parameters: {'max_depth': 12, 'eta': 0.011267124901637372, 'subsample': 0.6989558551149695, 'colsample_bytree': 0.4491953512558524, 'colsample_bylevel': 0.600987764033035, 'min_child_weight': 14, 'gamma': 2.2981314159523376, 'alpha': 3.387503704601687, 'lambda': 1.4022156568370692, 'max_leaves': 163, 'n_estimators': 481}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:07:25,245] Trial 68 finished with value: 1.1782431853732314 and parameters: {'max_depth': 11, 'eta': 0.0150872768894421, 'subsample': 0.6339829972552832, 'colsample_bytree': 0.48691046137056027, 'colsample_bylevel': 0.6788743288183443, 'min_child_weight': 13, 'gamma': 2.707006567805588, 'alpha': 4.490539198954685, 'lambda': 3.348197010317329, 'max_leaves': 181, 'n_estimators': 313}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:07:39,355] Trial 69 finished with value: 1.1792752175728682 and parameters: {'max_depth': 11, 'eta': 0.009196056222074658, 'subsample': 0.7063078760953156, 'colsample_bytree': 0.3821173847462315, 'colsample_bylevel': 0.7137169141334179, 'min_child_weight': 11, 'gamma': 3.1838328061832457, 'alpha': 9.141704171800875, 'lambda': 4.2420569048735075, 'max_leaves': 192, 'n_estimators': 355}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:07:43,608] Trial 70 finished with value: 1.1813614303773643 and parameters: {'max_depth': 9, 'eta': 0.07712574827362792, 'subsample': 0.6637443075195258, 'colsample_bytree': 0.4986631651265663, 'colsample_bylevel': 0.514880484546029, 'min_child_weight': 14, 'gamma': 2.1045674157778276, 'alpha': 8.635100159606965, 'lambda': 2.4694316639368914, 'max_leaves': 132, 'n_estimators': 414}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:08:05,633] Trial 71 finished with value: 1.178325210652134 and parameters: {'max_depth': 10, 'eta': 0.014098192265570963, 'subsample': 0.6708896804187953, 'colsample_bytree': 0.5839215147698733, 'colsample_bylevel': 0.773135171948599, 'min_child_weight': 15, 'gamma': 1.8321392817732727, 'alpha': 9.719012020993626, 'lambda': 6.795925220994608, 'max_leaves': 108, 'n_estimators': 406}. Best is trial 14 with value: 1.1707341812442578.
# [I 2025-08-05 08:08:29,250] Trial 72 finished with value: 1.1693906957464844 and parameters: {'max_depth': 10, 'eta': 0.017547050693121728, 'subsample': 0.6801844359622221, 'colsample_bytree': 0.5339353330352706, 'colsample_bylevel': 0.7488248985951886, 'min_child_weight': 15, 'gamma': 1.5127841286229993, 'alpha': 2.1628536493115957, 'lambda': 7.0836055178883015, 'max_leaves': 118, 'n_estimators': 391}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:08:47,614] Trial 73 finished with value: 1.174119710507872 and parameters: {'max_depth': 12, 'eta': 0.016721345267976917, 'subsample': 0.6889782155537028, 'colsample_bytree': 0.5330964785543478, 'colsample_bylevel': 0.571187550530668, 'min_child_weight': 14, 'gamma': 1.4849913054203063, 'alpha': 2.1221646445268973, 'lambda': 7.047737316917563, 'max_leaves': 120, 'n_estimators': 389}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:09:09,519] Trial 74 finished with value: 1.1735928990521232 and parameters: {'max_depth': 12, 'eta': 0.017386824651381153, 'subsample': 0.724056116928868, 'colsample_bytree': 0.5274792815402362, 'colsample_bylevel': 0.5746626745490646, 'min_child_weight': 15, 'gamma': 1.4276365531898898, 'alpha': 1.216645990431029, 'lambda': 6.955621666711755, 'max_leaves': 119, 'n_estimators': 381}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:09:32,295] Trial 75 finished with value: 1.1759115464894563 and parameters: {'max_depth': 12, 'eta': 0.017350561606862557, 'subsample': 0.7157181846244418, 'colsample_bytree': 0.5267114544222081, 'colsample_bylevel': 0.6565855301314647, 'min_child_weight': 15, 'gamma': 1.4644549150639163, 'alpha': 0.9201260618390941, 'lambda': 7.076507338158776, 'max_leaves': 119, 'n_estimators': 394}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:09:52,106] Trial 76 finished with value: 1.1789298144307907 and parameters: {'max_depth': 12, 'eta': 0.020338302944140137, 'subsample': 0.6857689939903095, 'colsample_bytree': 0.5397078917419753, 'colsample_bylevel': 0.6444805849765948, 'min_child_weight': 14, 'gamma': 1.25524565521736, 'alpha': 2.0947219007594455, 'lambda': 6.586951251073646, 'max_leaves': 150, 'n_estimators': 433}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:10:09,120] Trial 77 finished with value: 1.1703841129921118 and parameters: {'max_depth': 11, 'eta': 0.016107373308438068, 'subsample': 0.6888418956781055, 'colsample_bytree': 0.4650169730950755, 'colsample_bylevel': 0.7438669833188244, 'min_child_weight': 14, 'gamma': 1.5695912148190174, 'alpha': 0.5920774376173723, 'lambda': 7.5335412519720535, 'max_leaves': 99, 'n_estimators': 454}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:10:39,961] Trial 78 finished with value: 1.177625680277429 and parameters: {'max_depth': 11, 'eta': 0.011944904422122265, 'subsample': 0.7255562904836719, 'colsample_bytree': 0.5102531427450155, 'colsample_bylevel': 0.7498192048634983, 'min_child_weight': 15, 'gamma': 0.9537765173581687, 'alpha': 0.6433811818646875, 'lambda': 7.510678825277651, 'max_leaves': 140, 'n_estimators': 461}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:11:05,204] Trial 79 finished with value: 1.1745888650248513 and parameters: {'max_depth': 11, 'eta': 0.01677641948608661, 'subsample': 0.6875355144854255, 'colsample_bytree': 0.46353427088893606, 'colsample_bylevel': 0.7938145331092846, 'min_child_weight': 14, 'gamma': 1.0661697211363161, 'alpha': 0.07484584512264614, 'lambda': 6.194885838731377, 'max_leaves': 129, 'n_estimators': 442}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:11:23,625] Trial 80 finished with value: 1.1798509250959262 and parameters: {'max_depth': 10, 'eta': 0.013496110531639812, 'subsample': 0.7507436298891323, 'colsample_bytree': 0.5460890115327917, 'colsample_bylevel': 0.724123283438542, 'min_child_weight': 15, 'gamma': 1.5811325647656895, 'alpha': 1.6419372586399312, 'lambda': 7.29135525470268, 'max_leaves': 101, 'n_estimators': 482}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:11:39,409] Trial 81 finished with value: 1.1813919536725335 and parameters: {'max_depth': 12, 'eta': 0.020768123536519866, 'subsample': 0.7091980095904329, 'colsample_bytree': 0.4975200606812473, 'colsample_bylevel': 0.7411682550003765, 'min_child_weight': 14, 'gamma': 1.3502020507607664, 'alpha': 0.46179480543157325, 'lambda': 7.835537319301095, 'max_leaves': 111, 'n_estimators': 419}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:11:56,721] Trial 82 finished with value: 1.1746506092965392 and parameters: {'max_depth': 11, 'eta': 0.01606345833907645, 'subsample': 0.6454855875687848, 'colsample_bytree': 0.52086151215494, 'colsample_bylevel': 0.6157303993580917, 'min_child_weight': 15, 'gamma': 1.127385336516794, 'alpha': 1.1473311923165572, 'lambda': 7.467304525282383, 'max_leaves': 95, 'n_estimators': 388}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:12:13,000] Trial 83 finished with value: 1.1808212170089467 and parameters: {'max_depth': 12, 'eta': 0.02405120449737937, 'subsample': 0.680151136511036, 'colsample_bytree': 0.41499406146626666, 'colsample_bylevel': 0.5735836006686561, 'min_child_weight': 13, 'gamma': 1.4859772732813876, 'alpha': 2.238482330011651, 'lambda': 6.991470549857961, 'max_leaves': 118, 'n_estimators': 361}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:12:43,135] Trial 84 finished with value: 1.1786442522382374 and parameters: {'max_depth': 12, 'eta': 0.009789448541403218, 'subsample': 0.6983805478483137, 'colsample_bytree': 0.4666798585011729, 'colsample_bylevel': 0.7043777905252343, 'min_child_weight': 14, 'gamma': 0.8550413290238688, 'alpha': 1.4727656479105455, 'lambda': 6.674284350129979, 'max_leaves': 123, 'n_estimators': 376}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:13:00,770] Trial 85 finished with value: 1.178625114505903 and parameters: {'max_depth': 11, 'eta': 0.018358885974069424, 'subsample': 0.6688803122126116, 'colsample_bytree': 0.4348374528695228, 'colsample_bylevel': 0.6734981890235897, 'min_child_weight': 15, 'gamma': 1.9113873654352598, 'alpha': 1.8887937982061889, 'lambda': 5.374433415870492, 'max_leaves': 101, 'n_estimators': 459}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:13:25,507] Trial 86 finished with value: 1.177297514490962 and parameters: {'max_depth': 11, 'eta': 0.011608338380217425, 'subsample': 0.6516765666364908, 'colsample_bytree': 0.5366976328368707, 'colsample_bylevel': 0.5930882867813801, 'min_child_weight': 14, 'gamma': 1.6536242196882829, 'alpha': 2.8177192629739833, 'lambda': 5.64206663164018, 'max_leaves': 86, 'n_estimators': 500}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:13:48,128] Trial 87 finished with value: 1.174260979993074 and parameters: {'max_depth': 12, 'eta': 0.014153843416894246, 'subsample': 0.7302017098533583, 'colsample_bytree': 0.6039182682982233, 'colsample_bylevel': 0.5541998302467861, 'min_child_weight': 13, 'gamma': 0.7087415372715008, 'alpha': 2.393052034107301, 'lambda': 6.3192159285195295, 'max_leaves': 112, 'n_estimators': 432}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:14:01,919] Trial 88 finished with value: 1.1777975849236688 and parameters: {'max_depth': 12, 'eta': 0.007992822456183983, 'subsample': 0.6917103975134488, 'colsample_bytree': 0.5725846991477735, 'colsample_bylevel': 0.7809883293966875, 'min_child_weight': 15, 'gamma': 4.551765576385871, 'alpha': 0.7704770348091325, 'lambda': 8.217912446421844, 'max_leaves': 169, 'n_estimators': 391}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:14:14,603] Trial 89 finished with value: 1.1793053058476481 and parameters: {'max_depth': 11, 'eta': 0.021052594155903964, 'subsample': 0.7042002349516225, 'colsample_bytree': 0.49994124972106135, 'colsample_bylevel': 0.5721934432868385, 'min_child_weight': 15, 'gamma': 1.3376090439616024, 'alpha': 0.33850217365311597, 'lambda': 7.6255726713951075, 'max_leaves': 91, 'n_estimators': 417}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:14:34,546] Trial 90 finished with value: 1.1750030717193156 and parameters: {'max_depth': 10, 'eta': 0.016018148072278925, 'subsample': 0.718775244015883, 'colsample_bytree': 0.5143122138355849, 'colsample_bylevel': 0.7450853034027701, 'min_child_weight': 14, 'gamma': 1.7505327908316821, 'alpha': 3.317908095833019, 'lambda': 5.137866972620353, 'max_leaves': 98, 'n_estimators': 367}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:14:43,344] Trial 91 finished with value: 1.176819480001261 and parameters: {'max_depth': 12, 'eta': 0.02964214738598179, 'subsample': 0.7380093153106253, 'colsample_bytree': 0.5556908643910666, 'colsample_bylevel': 0.5427034461510977, 'min_child_weight': 13, 'gamma': 2.1368396374073098, 'alpha': 1.8103268923151028, 'lambda': 7.193532449600825, 'max_leaves': 75, 'n_estimators': 345}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:15:04,176] Trial 92 finished with value: 1.1799294298024654 and parameters: {'max_depth': 12, 'eta': 0.01789912779402422, 'subsample': 0.6790406856114436, 'colsample_bytree': 0.48648131176747444, 'colsample_bylevel': 0.5269218052706138, 'min_child_weight': 14, 'gamma': 1.53119250703736, 'alpha': 1.0072843504130635, 'lambda': 7.942779566306632, 'max_leaves': 127, 'n_estimators': 405}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:15:08,962] Trial 93 finished with value: 1.179822107621034 and parameters: {'max_depth': 12, 'eta': 0.024694351637703157, 'subsample': 0.6619570803962768, 'colsample_bytree': 0.6366266760383263, 'colsample_bylevel': 0.6148084240262801, 'min_child_weight': 15, 'gamma': 1.9520260751273673, 'alpha': 1.4203973019567224, 'lambda': 6.889595660315061, 'max_leaves': 10, 'n_estimators': 326}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:15:31,501] Trial 94 finished with value: 1.172477967998203 and parameters: {'max_depth': 12, 'eta': 0.02145321445363419, 'subsample': 0.7133272080162423, 'colsample_bytree': 0.7106182671375588, 'colsample_bylevel': 0.7684801245960353, 'min_child_weight': 14, 'gamma': 1.234129943839062, 'alpha': 6.664374088352686, 'lambda': 5.828452200556755, 'max_leaves': 80, 'n_estimators': 379}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:15:52,844] Trial 95 finished with value: 1.1746123038379892 and parameters: {'max_depth': 11, 'eta': 0.014955910127765676, 'subsample': 0.7129011104523599, 'colsample_bytree': 0.7447062510850093, 'colsample_bylevel': 0.8361088555125461, 'min_child_weight': 14, 'gamma': 1.1788082204746715, 'alpha': 4.04625450173065, 'lambda': 5.899036335695927, 'max_leaves': 78, 'n_estimators': 386}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:16:05,934] Trial 96 finished with value: 1.1781608545885276 and parameters: {'max_depth': 12, 'eta': 0.022416819531797527, 'subsample': 0.6956982529739865, 'colsample_bytree': 0.7144025925276669, 'colsample_bylevel': 0.7666973157703916, 'min_child_weight': 15, 'gamma': 1.3862268557528228, 'alpha': 7.638163791053696, 'lambda': 5.657254158191338, 'max_leaves': 83, 'n_estimators': 370}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:16:19,120] Trial 97 finished with value: 1.1802967732229512 and parameters: {'max_depth': 12, 'eta': 0.01935700288603542, 'subsample': 0.6402684805158165, 'colsample_bytree': 0.5300401489351801, 'colsample_bylevel': 0.807516528842086, 'min_child_weight': 12, 'gamma': 0.9169844044186275, 'alpha': 2.3252478094120757, 'lambda': 6.1966515100420825, 'max_leaves': 93, 'n_estimators': 395}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:16:24,938] Trial 98 finished with value: 1.1783714531586962 and parameters: {'max_depth': 4, 'eta': 0.01281766284361115, 'subsample': 0.6712483892297706, 'colsample_bytree': 0.6892745738174205, 'colsample_bylevel': 0.7260943279655427, 'min_child_weight': 15, 'gamma': 1.0683234991270747, 'alpha': 2.870225278901399, 'lambda': 2.9605172463326923, 'max_leaves': 86, 'n_estimators': 449}. Best is trial 72 with value: 1.1693906957464844.
# [I 2025-08-05 08:16:50,226] Trial 99 finished with value: 1.1729179156105727 and parameters: {'max_depth': 11, 'eta': 0.01633042747110332, 'subsample': 0.6295922628111174, 'colsample_bytree': 0.7365912106433433, 'colsample_bylevel': 0.7880899389973671, 'min_child_weight': 3, 'gamma': 1.237789861668349, 'alpha': 3.7166021059729655, 'lambda': 4.35477219850644, 'max_leaves': 105, 'n_estimators': 410}. Best is trial 72 with value: 1.1693906957464844.
# Best RMSE: 1.1694
# Best parameters:
#   max_depth: 10
#   eta: 0.017547050693121728
#   subsample: 0.6801844359622221
#   colsample_bytree: 0.5339353330352706
#   colsample_bylevel: 0.7488248985951886
#   min_child_weight: 15
#   gamma: 1.5127841286229993
#   alpha: 2.1628536493115957
#   lambda: 7.0836055178883015
#   max_leaves: 118
#   n_estimators: 391
#
# Parameters saved to best_xgb_params_365.json

# %%
print("\nTraining final model...")

# Prepare data
dtrain_final = xgb.DMatrix(X_train, label=y_train)
dtest_final = xgb.DMatrix(X_test, label=y_test)

# Train with best parameters
final_model = xgb.train(
    best_params,
    dtrain_final,
    num_boost_round=n_estimators,
    evals=[(dtrain_final, 'train'), (dtest_final, 'eval')],
    early_stopping_rounds=20,
    verbose_eval=10
)

# Make predictions and evaluate
preds_final = final_model.predict(dtest_final)
rmse_final = np.sqrt(mean_squared_error(y_test, preds_final))
mae_final = mean_absolute_error(y_test, preds_final)

print(f"\nFinal Model Performance:")
print(f"RMSE: {rmse_final:.4f}")
print(f"MAE: {mae_final:.4f}")

# Save the trained model
final_model.save_model("best_xgb_model_365.json")
print("Model saved as 'best_xgb_model_365.json'")
# Out:
# Training final model...
# [0]	train-rmse:1.28176	eval-rmse:1.23298
# [10]	train-rmse:1.23019	eval-rmse:1.21918
# [20]	train-rmse:1.18451	eval-rmse:1.20864
# [30]	train-rmse:1.14391	eval-rmse:1.20095
# [40]	train-rmse:1.10638	eval-rmse:1.19591
# [50]	train-rmse:1.07244	eval-rmse:1.19083
# [60]	train-rmse:1.04066	eval-rmse:1.18739
# [70]	train-rmse:1.01136	eval-rmse:1.18399
# [80]	train-rmse:0.98459	eval-rmse:1.18230
# [90]	train-rmse:0.95932	eval-rmse:1.18258
# [100]	train-rmse:0.93488	eval-rmse:1.18219
# [110]	train-rmse:0.91253	eval-rmse:1.18224
# [120]	train-rmse:0.89124	eval-rmse:1.18335
# [130]	train-rmse:0.87050	eval-rmse:1.18380
# [131]	train-rmse:0.86904	eval-rmse:1.18351
#
# Final Model Performance:
# RMSE: 1.1835
# MAE: 0.9502
# Model saved as 'best_xgb_model_365.json'

# %%
print("\nTop 10 Feature Importance (Gain):")
importance = final_model.get_score(importance_type='gain')
importance_df = pd.DataFrame({
    'feature': list(importance.keys()),
    'importance': list(importance.values())
}).sort_values('importance', ascending=False)

print(importance_df.head(15).to_string(index=False))
# Out:
# Top 10 Feature Importance (Gain):
#                                                      feature  importance
#                 team_rolling_possession_touches_att_pen_area   50.053787
#                         team_rolling_summary_shots_on_target   42.916401
#                                      team_rolling_summary_xg   37.828583
#                                 team_rolling_summary_touches   29.921967
#                                     team_rolling_keeper_psxg   28.650259
#                                 team_rolling_summary_carries   28.178934
#                               team_rolling_summary_xg_assist   27.358438
#                  opp_team_rolling_possession_passes_received   22.579401
# team_rolling_conceded_possession_progressive_passes_received   21.472067
#             team_rolling_possession_carries_into_final_third   21.094284
#                  opp_team_rolling_possession_touches_att_3rd   20.673637
#                                     team_rolling_summary_sca   20.607796
#             team_rolling_conceded_possession_touches_att_3rd   19.440392
#         opp_team_rolling_possession_carries_into_final_third   17.921385
#                           team_rolling_passing_through_balls   17.875624
