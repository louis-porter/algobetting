# %% [markdown]
# # Load Data

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from scipy.stats import poisson
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import sqlite3

conn = sqlite3.connect(r'C:\Users\Owner\dev\algobetting\infra\data\db\algobetting.db')

df = pd.read_sql_query("""
    SELECT DISTINCT
       f.match_date,
       f.team,
       f.team_rolling_summary_goals,
       f.team_rolling_summary_xg,
       f.team_rolling_summary_npxg,
       f.team_rolling_keeper_psxg,
       f.team_rolling_conceded_summary_goals,
       f.team_rolling_conceded_summary_xg,
       f.team_rolling_conceded_summary_npxg,
       f.team_rolling_conceded_keeper_psxg,
       fb.summary_goals as goals,
       f.opp_team,
       f.opp_team_rolling_summary_goals,
       f.opp_team_rolling_summary_xg,
       f.opp_team_rolling_summary_npxg,
       f.opp_team_rolling_keeper_psxg,
       f.opp_team_rolling_conceded_summary_goals,
       f.opp_team_rolling_conceded_summary_xg,
       f.opp_team_rolling_conceded_summary_npxg,
       f.opp_team_rolling_conceded_keeper_psxg,
       fb.opp_summary_goals as opp_goals
    FROM 
        team_all_features_365_00050 f
    JOIN
        fbref_match_all_columns fb
            ON fb.match_url = f.match_url AND fb.team = f.team
    WHERE f.division = 'Premier League'
            AND f.season = '2024-2025'
            AND team_rolling_summary_goals IS NOT NULL
            AND f.is_home = 1
                        """, conn)

conn.close()

df
# Out:
#               match_date             team  team_rolling_summary_goals  \
# 0    2025-05-25 00:00:00        Tottenham                    1.500408
# 1    2025-05-25 00:00:00      Bournemouth                    1.608621
# 2    2025-05-25 00:00:00    Newcastle Utd                    1.895577
# 3    2025-05-25 00:00:00           Fulham                    1.445887
# 4    2025-05-25 00:00:00  Nott'ham Forest                    1.578072
# ..                   ...              ...                         ...
# 375  2024-08-17 00:00:00  Nott'ham Forest                    1.296371
# 376  2024-08-17 00:00:00          Everton                    1.068233
# 377  2024-08-17 00:00:00    Newcastle Utd                    2.211730
# 378  2024-08-17 00:00:00     Ipswich Town                    1.987621
# 379  2024-08-16 00:00:00   Manchester Utd                    1.634428
#
#      team_rolling_summary_xg  team_rolling_summary_npxg  \
# 0                   1.419083                   1.338374
# 1                   1.726044                   1.600831
# 2                   1.739969                   1.610403
# 3                   1.245589                   1.178877
# 4                   1.179114                   1.133311
# ..                       ...                        ...
# 375                 1.424365                   1.418664
# 376                 1.453716                   1.360224
# 377                 2.023807                   1.848153
# 378                 1.652822                   1.601648
# 379                 1.472340                   1.314195
#
#      team_rolling_keeper_psxg  team_rolling_conceded_summary_goals  \
# 0                    1.413362                             1.838188
# 1                    1.742328                             1.334089
# 2                    1.693188                             1.345745
# 3                    1.433139                             1.480788
# 4                    1.428674                             1.311202
# ..                        ...                                  ...
# 375                  1.215678                             1.822696
# 376                  1.158816                             1.353958
# 377                  1.832712                             1.693598
# 378                  1.665831                             1.218097
# 379                  1.510262                             1.636426
#
#      team_rolling_conceded_summary_xg  team_rolling_conceded_summary_npxg  \
# 0                            1.755202                            1.720501
# 1                            1.331399                            1.220682
# 2                            1.226171                            1.155783
# 3                            1.251556                            1.160657
# 4                            1.418029                            1.339274
# ..                                ...                                 ...
# 375                          1.378234                            1.337462
# 376                          1.555156                            1.398703
# 377                          1.686495                            1.570390
# 378                          1.005455                            0.949889
# 379                          1.913564                            1.736019
#
#      team_rolling_conceded_keeper_psxg  ...         opp_team  \
# 0                             1.805191  ...         Brighton
# 1                             1.460762  ...   Leicester City
# 2                             1.312582  ...          Everton
# 3                             1.317218  ...  Manchester City
# 4                             1.384869  ...          Chelsea
# ..                                 ...  ...              ...
# 375                           1.181650  ...      Bournemouth
# 376                           1.456195  ...         Brighton
# 377                           1.615495  ...      Southampton
# 378                           1.026538  ...        Liverpool
# 379                           1.619416  ...           Fulham
#
#     opp_team_rolling_summary_goals  opp_team_rolling_summary_xg  \
# 0                         1.706913                     1.605220
# 1                         0.807435                     0.817617
# 2                         1.206227                     1.169747
# 3                         1.855950                     1.747285
# 4                         1.562918                     1.703940
# ..                             ...                          ...
# 375                       1.470426                     1.540680
# 376                       0.996871                     1.365028
# 377                       1.746484                     1.640530
# 378                       2.356665                     2.474557
# 379                       1.593007                     1.484353
#
#      opp_team_rolling_summary_npxg  opp_team_rolling_keeper_psxg  \
# 0                         1.414512                      1.829008
# 1                         0.765214                      0.826943
# 2                         1.117807                      1.162522
# 3                         1.681626                      1.732629
# 4                         1.582041                      1.705193
# ..                             ...                           ...
# 375                       1.459409                      1.204111
# 376                       1.244065                      1.401611
# 377                       1.565486                      1.708088
# 378                       2.301927                      2.187080
# 379                       1.449735                      1.572475
#
#      opp_team_rolling_conceded_summary_goals  \
# 0                                   1.582692
# 1                                   2.064578
# 2                                   1.096034
# 3                                   1.065178
# 4                                   1.074680
# ..                                       ...
# 375                                 1.752710
# 376                                 1.662358
# 377                                 1.195353
# 378                                 1.220762
# 379                                 1.497796
#
#      opp_team_rolling_conceded_summary_xg  \
# 0                                1.398281
# 1                                1.948015
# 2                                1.188877
# 3                                1.212474
# 4                                1.149933
# ..                                    ...
# 375                              1.526086
# 376                              1.523636
# 377                              1.029815
# 378                              1.213207
# 379                              1.496039
#
#      opp_team_rolling_conceded_summary_npxg  \
# 0                                  1.220604
# 1                                  1.838669
# 2                                  1.149149
# 3                                  1.128386
# 4                                  1.043757
# ..                                      ...
# 375                                1.373257
# 376                                1.445034
# 377                                0.972503
# 378                                1.208176
# 379                                1.367420
#
#      opp_team_rolling_conceded_keeper_psxg  opp_goals
# 0                                 1.299603        4.0
# 1                                 1.811285        0.0
# 2                                 1.251694        1.0
# 3                                 1.117500        2.0
# 4                                 1.091591        1.0
# ..                                     ...        ...
# 375                               1.656592        1.0
# 376                               1.406198        3.0
# 377                               0.988693        0.0
# 378                               1.128665        2.0
# 379                               1.273723        0.0
#
# [380 rows x 21 columns]

# %%
class MatchPredictionModel(nn.Module):
    """
    Neural network that takes home and away team features and predicts match goals.
    Also outputs interpretable team ratings (attack/defense strengths).
    """
    
    def __init__(self, n_team_features):
        super().__init__()
        
        # Shared feature processing
        self.feature_encoder = nn.Sequential(
            nn.Linear(n_team_features, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, 16),
            nn.ReLU(),
        )
        
        # Team strength heads (for interpretable ratings)
        self.attack_head = nn.Sequential(
            nn.Linear(16, 8),
            nn.ReLU(),
            nn.Linear(8, 1)
        )
        
        self.defense_head = nn.Sequential(
            nn.Linear(16, 8),
            nn.ReLU(), 
            nn.Linear(8, 1)
        )
        
        # Learnable home advantage
        self.home_advantage = nn.Parameter(torch.tensor(0.2))
    
    def get_team_strengths(self, team_features):
        """Get interpretable attack and defense ratings for teams"""
        encoded = self.feature_encoder(team_features)
        
        # Use softplus to ensure positive values
        attack = torch.nn.functional.softplus(self.attack_head(encoded))
        defense = torch.nn.functional.softplus(self.defense_head(encoded))
        
        return attack.squeeze(), defense.squeeze()
    
    def forward(self, home_features, away_features):
        """
        Predict expected goals using Dixon-Coles style team strengths
        
        Args:
            home_features: Tensor of home team's rolling stats
            away_features: Tensor of away team's rolling stats
            
        Returns:
            home_lambda, away_lambda: Expected goals for home and away teams
        """
        # Get team strengths
        home_attack, home_defense = self.get_team_strengths(home_features)
        away_attack, away_defense = self.get_team_strengths(away_features)
        
        # Dixon-Coles style calculation
        home_lambda = home_attack * away_defense * torch.exp(self.home_advantage)
        away_lambda = away_attack * home_defense
        
        return home_lambda, away_lambda

def prepare_training_data(df):
   """
   Prepare your dataframe for training the neural network
   
   Args:
       df: Your dataframe with rolling features and match results
       
   Returns:
       Features, targets, scaler, and column info for training
   """
   
   print(f"📊 Preparing {len(df)} matches for training...")
   
   # Define feature columns split into attack and defense
   attack_feature_cols = [
       'team_rolling_summary_goals', 
       'team_rolling_summary_xg',
       #'team_rolling_summary_npxg',
       #'team_rolling_keeper_psxg'
   ]
   
   defense_feature_cols = [
       'team_rolling_conceded_summary_goals',
       'team_rolling_conceded_summary_xg', 
       #'team_rolling_conceded_summary_npxg',
       #'team_rolling_conceded_keeper_psxg'
   ]
   
   # Combine for full team features
   team_feature_cols = attack_feature_cols + defense_feature_cols
   
   # Opponent features (same structure)
   opp_attack_feature_cols = [
       'opp_team_rolling_summary_goals', 
       'opp_team_rolling_summary_xg',
       #'opp_team_rolling_summary_npxg',
       #'opp_team_rolling_keeper_psxg'
   ]
   
   opp_defense_feature_cols = [
       'opp_team_rolling_conceded_summary_goals',
       'opp_team_rolling_conceded_summary_xg',
       #'opp_team_rolling_conceded_summary_npxg', 
       #'opp_team_rolling_conceded_keeper_psxg'
   ]
   
   opp_feature_cols = opp_attack_feature_cols + opp_defense_feature_cols
   
   print(f"🔧 Using {len(team_feature_cols)} features per team:")
   print("⚔️ Attack features:")
   for col in attack_feature_cols:
       print(f"   - {col}")
   print("🛡️ Defense features:")
   for col in defense_feature_cols:
       print(f"   - {col}")
   
   # Extract features - home team is 'team', away team is 'opp_team'
   home_features = df[team_feature_cols].fillna(0).values  # Fill NaN with 0
   away_features = df[opp_feature_cols].fillna(0).values
   
   # Extract targets
   home_goals = df['goals'].values
   away_goals = df['opp_goals'].values
   
   # Scale features (important for neural networks)
   scaler = StandardScaler()
   
   # Fit scaler on all features combined for consistency
   all_features = np.vstack([home_features, away_features])
   scaler.fit(all_features)
   
   # Transform features
   home_features_scaled = scaler.transform(home_features)
   away_features_scaled = scaler.transform(away_features)
   
   print(f"✅ Prepared {len(home_features_scaled)} training examples")
   print(f"📈 Feature shape: {home_features_scaled.shape}")
   print(f"⚽ Average goals - Home: {home_goals.mean():.2f}, Away: {away_goals.mean():.2f}")
   
   return (home_features_scaled, away_features_scaled, 
           home_goals, away_goals, scaler, team_feature_cols)

def train_model(df, epochs=100000, learning_rate=0.001):
    """
    Train the match prediction model
    
    Args:
        df: Your prepared dataframe
        epochs: Number of training epochs
        learning_rate: Learning rate for optimizer
    
    Returns:
        Trained model, scaler, and feature columns
    """
    
    # Prepare data
    (home_features, away_features, home_goals, away_goals, 
     scaler, feature_cols) = prepare_training_data(df)
    
    # Convert to tensors
    home_tensor = torch.FloatTensor(home_features)
    away_tensor = torch.FloatTensor(away_features)
    home_goals_tensor = torch.FloatTensor(home_goals)
    away_goals_tensor = torch.FloatTensor(away_goals)
    
    # Create model
    n_features = home_features.shape[1]
    model = MatchPredictionModel(n_features)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    
    print(f"\n🧠 Training model for {epochs} epochs...")
    
    # Training loop
    model.train()
    for epoch in range(epochs):
        optimizer.zero_grad()
        
        # Forward pass
        pred_home_goals, pred_away_goals = model(home_tensor, away_tensor)
        
        # Poisson negative log-likelihood loss
        home_loss = torch.nn.PoissonNLLLoss()(pred_home_goals, home_goals_tensor)
        away_loss = torch.nn.PoissonNLLLoss()(pred_away_goals, away_goals_tensor)
        total_loss = home_loss + away_loss
        
        # Backward pass
        total_loss.backward()
        optimizer.step()
        
        # Print progress
        if epoch % 200 == 0 or epoch == epochs - 1:
            model.eval()
            with torch.no_grad():
                pred_h, pred_a = model(home_tensor, away_tensor)
                mae_home = torch.mean(torch.abs(pred_h - home_goals_tensor))
                mae_away = torch.mean(torch.abs(pred_a - away_goals_tensor))
            
            print(f"Epoch {epoch:4d}: Loss={total_loss.item():.4f}, "
                  f"MAE Home={mae_home:.3f}, MAE Away={mae_away:.3f}")
            model.train()
    
    print(f"\n✅ Training complete!")
    print(f"🏠 Learned home advantage: +{model.home_advantage.item():.3f} goals")
    
    return model, scaler, feature_cols

def extract_team_ratings(model, df, scaler, feature_cols):
    """
    Extract interpretable team attack and defense ratings from the trained model
    
    Args:
        model: Trained MatchPredictionModel
        df: Your dataframe with team data
        scaler: Fitted StandardScaler
        feature_cols: List of feature column names
    
    Returns:
        DataFrame with team ratings
    """
    
    model.eval()
    
    print("🏆 Extracting Team Ratings...")
    
    # Get unique teams and their latest features
    team_ratings = []
    
    # Get all unique teams from both home and away
    home_teams = df[['team'] + feature_cols].drop_duplicates('team')
    away_teams = df[['opp_team'] + [col.replace('team_rolling_', 'opp_team_rolling_') 
                                   for col in feature_cols]].drop_duplicates('opp_team')
    
    # Process home teams
    for _, row in home_teams.iterrows():
        team_name = row['team']
        team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
        team_features_scaled = scaler.transform(team_features)
        
        with torch.no_grad():
            features_tensor = torch.FloatTensor(team_features_scaled)
            attack, defense = model.get_team_strengths(features_tensor)
        
        team_ratings.append({
            'team': team_name,
            'attack_rating': attack.item(),
            'defense_rating': defense.item()
        })
    
    # Process away teams (if different features)
    opp_feature_cols = [col.replace('team_rolling_', 'opp_team_rolling_') for col in feature_cols]
    
    for _, row in away_teams.iterrows():
        team_name = row['opp_team']
        
        # Skip if already processed as home team
        if team_name in [r['team'] for r in team_ratings]:
            continue
            
        team_features = row[opp_feature_cols].fillna(0).values.reshape(1, -1)
        team_features_scaled = scaler.transform(team_features)
        
        with torch.no_grad():
            features_tensor = torch.FloatTensor(team_features_scaled)
            attack, defense = model.get_team_strengths(features_tensor)
        
        team_ratings.append({
            'team': team_name,
            'attack_rating': attack.item(),
            'defense_rating': defense.item()
        })
    
    # Convert to DataFrame and sort
    ratings_df = pd.DataFrame(team_ratings)
    
    # Display rankings
    attack_rankings = ratings_df.sort_values('attack_rating', ascending=False).reset_index(drop=True)
    defense_rankings = ratings_df.sort_values('defense_rating', ascending=False).reset_index(drop=True)
    
    print("\n⚔️ ATTACK RATINGS (Higher = Better Attack)")
    print("=" * 50)
    for i, row in attack_rankings.head(20).iterrows():
        print(f"{i+1:2d}. {row['team']:20s} {row['attack_rating']:.3f}")
    
    print("\n🛡️ DEFENSE RATINGS (Higher = Better Defense)")
    print("=" * 50)
    for i, row in defense_rankings.head(20).iterrows():
        print(f"{i+1:2d}. {row['team']:20s} {row['defense_rating']:.3f}")
    
    return ratings_df
def predict_match(model, scaler, feature_cols, home_team_stats, away_team_stats):
    """
    Predict a match using the trained model
    
    Args:
        model: Trained MatchPredictionModel
        scaler: Fitted StandardScaler
        feature_cols: List of feature column names
        home_team_stats: Dict with home team's rolling stats
        away_team_stats: Dict with away team's rolling stats
    
    Returns:
        Expected goals for home and away teams
    """
    
    model.eval()
    
    # Convert stats to arrays in correct order
    home_array = np.array([[home_team_stats.get(col.replace('team_rolling_', ''), 0) 
                           for col in feature_cols]])
    away_array = np.array([[away_team_stats.get(col.replace('opp_team_rolling_', ''), 0) 
                           for col in feature_cols]])
    
    # Scale features
    home_scaled = scaler.transform(home_array)
    away_scaled = scaler.transform(away_array)
    
    # Predict
    with torch.no_grad():
        home_tensor = torch.FloatTensor(home_scaled)
        away_tensor = torch.FloatTensor(away_scaled)
        pred_home, pred_away = model(home_tensor, away_tensor)
    
    return pred_home.item(), pred_away.item()

# Example usage with your data:
if __name__ == "__main__":
    print("🚀 Training Match Prediction Model")
    print("=" * 50)
    
    # Train the model (assuming df is your loaded dataframe)
    model, scaler, feature_cols = train_model(df)
    
    # Extract team ratings
    ratings_df = extract_team_ratings(model, df, scaler, feature_cols)
# Out:
# 🚀 Training Match Prediction Model
# ==================================================
# 📊 Preparing 380 matches for training...
# 🔧 Using 4 features per team:
# ⚔️ Attack features:
#    - team_rolling_summary_goals
#    - team_rolling_summary_xg
# 🛡️ Defense features:
#    - team_rolling_conceded_summary_goals
#    - team_rolling_conceded_summary_xg
# ✅ Prepared 380 training examples
# 📈 Feature shape: (380, 4)
# ⚽ Average goals - Home: 1.51, Away: 1.42
#
# 🧠 Training model for 100000 epochs...
# Epoch    0: Loss=1.8368, MAE Home=1.229, MAE Away=1.178
# Epoch  200: Loss=1.7001, MAE Home=1.255, MAE Away=1.189
# Epoch  400: Loss=1.6642, MAE Home=1.255, MAE Away=1.173
# Epoch  600: Loss=1.6322, MAE Home=1.261, MAE Away=1.176
# Epoch  800: Loss=1.6230, MAE Home=1.259, MAE Away=1.180
# Epoch 1000: Loss=1.5924, MAE Home=1.252, MAE Away=1.173
# Epoch 1200: Loss=1.5728, MAE Home=1.253, MAE Away=1.174
# Epoch 1400: Loss=1.5750, MAE Home=1.254, MAE Away=1.175
# Epoch 1600: Loss=1.5670, MAE Home=1.251, MAE Away=1.175
# Epoch 1800: Loss=1.5687, MAE Home=1.263, MAE Away=1.186
# Epoch 2000: Loss=1.5575, MAE Home=1.236, MAE Away=1.164
# Epoch 2200: Loss=1.5609, MAE Home=1.246, MAE Away=1.175
# Epoch 2400: Loss=1.5292, MAE Home=1.228, MAE Away=1.161
# Epoch 2600: Loss=1.5355, MAE Home=1.241, MAE Away=1.173
# Epoch 2800: Loss=1.5324, MAE Home=1.233, MAE Away=1.170
# Epoch 3000: Loss=1.5438, MAE Home=1.238, MAE Away=1.173
# Epoch 3200: Loss=1.5374, MAE Home=1.237, MAE Away=1.171
# Epoch 3400: Loss=1.5392, MAE Home=1.238, MAE Away=1.176
# Epoch 3600: Loss=1.5179, MAE Home=1.234, MAE Away=1.172
# Epoch 3800: Loss=1.5144, MAE Home=1.237, MAE Away=1.176
# Epoch 4000: Loss=1.5164, MAE Home=1.212, MAE Away=1.158
# Epoch 4200: Loss=1.5273, MAE Home=1.222, MAE Away=1.168
# Epoch 4400: Loss=1.5108, MAE Home=1.226, MAE Away=1.171
# Epoch 4600: Loss=1.5212, MAE Home=1.213, MAE Away=1.160
# Epoch 4800: Loss=1.5107, MAE Home=1.222, MAE Away=1.169
# Epoch 5000: Loss=1.5187, MAE Home=1.225, MAE Away=1.171
# Epoch 5200: Loss=1.5082, MAE Home=1.223, MAE Away=1.169
# Epoch 5400: Loss=1.4993, MAE Home=1.210, MAE Away=1.161
# Epoch 5600: Loss=1.4975, MAE Home=1.211, MAE Away=1.164
# Epoch 5800: Loss=1.4993, MAE Home=1.212, MAE Away=1.163
# Epoch 6000: Loss=1.4831, MAE Home=1.230, MAE Away=1.178
# Epoch 6200: Loss=1.4796, MAE Home=1.220, MAE Away=1.169
# Epoch 6400: Loss=1.4933, MAE Home=1.236, MAE Away=1.184
# Epoch 6600: Loss=1.4636, MAE Home=1.217, MAE Away=1.171
# Epoch 6800: Loss=1.4660, MAE Home=1.198, MAE Away=1.154
# Epoch 7000: Loss=1.4996, MAE Home=1.216, MAE Away=1.170
# Epoch 7200: Loss=1.4775, MAE Home=1.206, MAE Away=1.161
# Epoch 7400: Loss=1.4672, MAE Home=1.206, MAE Away=1.162
# Epoch 7600: Loss=1.4797, MAE Home=1.209, MAE Away=1.167
# Epoch 7800: Loss=1.4721, MAE Home=1.212, MAE Away=1.167
# Epoch 8000: Loss=1.4738, MAE Home=1.200, MAE Away=1.156
# Epoch 8200: Loss=1.4863, MAE Home=1.220, MAE Away=1.171
# Epoch 8400: Loss=1.4765, MAE Home=1.207, MAE Away=1.163
# Epoch 8600: Loss=1.4840, MAE Home=1.197, MAE Away=1.156
# Epoch 8800: Loss=1.4732, MAE Home=1.193, MAE Away=1.155
# Epoch 9000: Loss=1.4906, MAE Home=1.193, MAE Away=1.153
# Epoch 9200: Loss=1.4517, MAE Home=1.199, MAE Away=1.160
# Epoch 9400: Loss=1.4478, MAE Home=1.197, MAE Away=1.158
# Epoch 9600: Loss=1.4661, MAE Home=1.199, MAE Away=1.165
# Epoch 9800: Loss=1.4417, MAE Home=1.201, MAE Away=1.162
# Epoch 10000: Loss=1.4724, MAE Home=1.198, MAE Away=1.158
# Epoch 10200: Loss=1.4500, MAE Home=1.195, MAE Away=1.154
# Epoch 10400: Loss=1.4536, MAE Home=1.191, MAE Away=1.153
# Epoch 10600: Loss=1.4382, MAE Home=1.196, MAE Away=1.157
# Epoch 10800: Loss=1.4684, MAE Home=1.212, MAE Away=1.170
# Epoch 11000: Loss=1.4539, MAE Home=1.202, MAE Away=1.163
# Epoch 11200: Loss=1.4724, MAE Home=1.209, MAE Away=1.169
# Epoch 11400: Loss=1.4541, MAE Home=1.193, MAE Away=1.154
# Epoch 11600: Loss=1.4546, MAE Home=1.201, MAE Away=1.159
# Epoch 11800: Loss=1.4630, MAE Home=1.199, MAE Away=1.156
# Epoch 12000: Loss=1.4657, MAE Home=1.215, MAE Away=1.170
# Epoch 12200: Loss=1.4584, MAE Home=1.204, MAE Away=1.160
# Epoch 12400: Loss=1.4540, MAE Home=1.199, MAE Away=1.158
# Epoch 12600: Loss=1.4483, MAE Home=1.186, MAE Away=1.144
# Epoch 12800: Loss=1.4378, MAE Home=1.185, MAE Away=1.143
# Epoch 13000: Loss=1.4219, MAE Home=1.175, MAE Away=1.140
# Epoch 13200: Loss=1.4669, MAE Home=1.187, MAE Away=1.145
# Epoch 13400: Loss=1.4393, MAE Home=1.199, MAE Away=1.157
# Epoch 13600: Loss=1.4443, MAE Home=1.185, MAE Away=1.143
# Epoch 13800: Loss=1.4162, MAE Home=1.206, MAE Away=1.161
# Epoch 14000: Loss=1.4335, MAE Home=1.208, MAE Away=1.163
# Epoch 14200: Loss=1.4335, MAE Home=1.201, MAE Away=1.151
# Epoch 14400: Loss=1.4497, MAE Home=1.205, MAE Away=1.156
# Epoch 14600: Loss=1.4232, MAE Home=1.203, MAE Away=1.153
# Epoch 14800: Loss=1.4353, MAE Home=1.204, MAE Away=1.157
# Epoch 15000: Loss=1.4324, MAE Home=1.207, MAE Away=1.157
# Epoch 15200: Loss=1.4361, MAE Home=1.200, MAE Away=1.152
# Epoch 15400: Loss=1.4481, MAE Home=1.214, MAE Away=1.161
# Epoch 15600: Loss=1.4250, MAE Home=1.215, MAE Away=1.160
# Epoch 15800: Loss=1.4454, MAE Home=1.191, MAE Away=1.143
# Epoch 16000: Loss=1.4384, MAE Home=1.205, MAE Away=1.158
# Epoch 16200: Loss=1.4368, MAE Home=1.211, MAE Away=1.158
# Epoch 16400: Loss=1.4239, MAE Home=1.191, MAE Away=1.144
# Epoch 16600: Loss=1.4711, MAE Home=1.188, MAE Away=1.141
# Epoch 16800: Loss=1.4359, MAE Home=1.213, MAE Away=1.158
# Epoch 17000: Loss=1.4193, MAE Home=1.198, MAE Away=1.148
# Epoch 17200: Loss=1.4251, MAE Home=1.195, MAE Away=1.146
# Epoch 17400: Loss=1.4285, MAE Home=1.208, MAE Away=1.155
# Epoch 17600: Loss=1.4598, MAE Home=1.194, MAE Away=1.143
# Epoch 17800: Loss=1.4290, MAE Home=1.192, MAE Away=1.140
# Epoch 18000: Loss=1.4318, MAE Home=1.217, MAE Away=1.165
# Epoch 18200: Loss=1.4224, MAE Home=1.221, MAE Away=1.166
# Epoch 18400: Loss=1.4374, MAE Home=1.190, MAE Away=1.140
# Epoch 18600: Loss=1.4233, MAE Home=1.191, MAE Away=1.146
# Epoch 18800: Loss=1.4318, MAE Home=1.188, MAE Away=1.139
# Epoch 19000: Loss=1.4271, MAE Home=1.192, MAE Away=1.142
# Epoch 19200: Loss=1.4173, MAE Home=1.188, MAE Away=1.136
# Epoch 19400: Loss=1.4439, MAE Home=1.174, MAE Away=1.130
# Epoch 19600: Loss=1.4348, MAE Home=1.194, MAE Away=1.144
# Epoch 19800: Loss=1.4293, MAE Home=1.190, MAE Away=1.137
# Epoch 20000: Loss=1.4104, MAE Home=1.196, MAE Away=1.148
# Epoch 20200: Loss=1.4215, MAE Home=1.191, MAE Away=1.139
# Epoch 20400: Loss=1.4437, MAE Home=1.208, MAE Away=1.150
# Epoch 20600: Loss=1.4285, MAE Home=1.195, MAE Away=1.147
# Epoch 20800: Loss=1.4146, MAE Home=1.183, MAE Away=1.138
# Epoch 21000: Loss=1.4348, MAE Home=1.182, MAE Away=1.137
# Epoch 21200: Loss=1.4288, MAE Home=1.184, MAE Away=1.140
# Epoch 21400: Loss=1.4254, MAE Home=1.186, MAE Away=1.138
# Epoch 21600: Loss=1.4010, MAE Home=1.201, MAE Away=1.152
# Epoch 21800: Loss=1.4489, MAE Home=1.193, MAE Away=1.145
# Epoch 22000: Loss=1.4127, MAE Home=1.171, MAE Away=1.128
# Epoch 22200: Loss=1.4036, MAE Home=1.178, MAE Away=1.135
# Epoch 22400: Loss=1.4202, MAE Home=1.192, MAE Away=1.146
# Epoch 22600: Loss=1.4342, MAE Home=1.190, MAE Away=1.142
# Epoch 22800: Loss=1.4204, MAE Home=1.181, MAE Away=1.133
# Epoch 23000: Loss=1.4082, MAE Home=1.184, MAE Away=1.138
# Epoch 23200: Loss=1.4377, MAE Home=1.197, MAE Away=1.147
# Epoch 23400: Loss=1.4139, MAE Home=1.206, MAE Away=1.152
# Epoch 23600: Loss=1.4143, MAE Home=1.178, MAE Away=1.137
# Epoch 23800: Loss=1.4197, MAE Home=1.183, MAE Away=1.137
# Epoch 24000: Loss=1.4168, MAE Home=1.178, MAE Away=1.137
# Epoch 24200: Loss=1.4272, MAE Home=1.190, MAE Away=1.149
# Epoch 24400: Loss=1.4080, MAE Home=1.188, MAE Away=1.141
# Epoch 24600: Loss=1.4022, MAE Home=1.185, MAE Away=1.140
# Epoch 24800: Loss=1.4300, MAE Home=1.185, MAE Away=1.144
# Epoch 25000: Loss=1.4145, MAE Home=1.193, MAE Away=1.146
# Epoch 25200: Loss=1.4067, MAE Home=1.177, MAE Away=1.136
# Epoch 25400: Loss=1.4169, MAE Home=1.173, MAE Away=1.133
# Epoch 25600: Loss=1.4130, MAE Home=1.202, MAE Away=1.154
# Epoch 25800: Loss=1.4505, MAE Home=1.188, MAE Away=1.146
# Epoch 26000: Loss=1.4210, MAE Home=1.205, MAE Away=1.161
# Epoch 26200: Loss=1.4259, MAE Home=1.189, MAE Away=1.146
# Epoch 26400: Loss=1.4156, MAE Home=1.181, MAE Away=1.134
# Epoch 26600: Loss=1.3995, MAE Home=1.191, MAE Away=1.147
# Epoch 26800: Loss=1.3957, MAE Home=1.188, MAE Away=1.141
# Epoch 27000: Loss=1.3963, MAE Home=1.192, MAE Away=1.144
# Epoch 27200: Loss=1.3988, MAE Home=1.186, MAE Away=1.141
# Epoch 27400: Loss=1.4136, MAE Home=1.196, MAE Away=1.148
# Epoch 27600: Loss=1.4262, MAE Home=1.170, MAE Away=1.134
# Epoch 27800: Loss=1.4101, MAE Home=1.197, MAE Away=1.152
# Epoch 28000: Loss=1.3992, MAE Home=1.193, MAE Away=1.150
# Epoch 28200: Loss=1.4263, MAE Home=1.200, MAE Away=1.155
# Epoch 28400: Loss=1.4128, MAE Home=1.188, MAE Away=1.146
# Epoch 28600: Loss=1.4088, MAE Home=1.174, MAE Away=1.136
# Epoch 28800: Loss=1.4144, MAE Home=1.201, MAE Away=1.158
# Epoch 29000: Loss=1.4042, MAE Home=1.180, MAE Away=1.142
# Epoch 29200: Loss=1.4213, MAE Home=1.184, MAE Away=1.143
# Epoch 29400: Loss=1.4000, MAE Home=1.192, MAE Away=1.148
# Epoch 29600: Loss=1.3852, MAE Home=1.186, MAE Away=1.145
# Epoch 29800: Loss=1.3970, MAE Home=1.191, MAE Away=1.145
# Epoch 30000: Loss=1.4052, MAE Home=1.202, MAE Away=1.152
# Epoch 30200: Loss=1.4113, MAE Home=1.177, MAE Away=1.138
# Epoch 30400: Loss=1.4088, MAE Home=1.175, MAE Away=1.133
# Epoch 30600: Loss=1.3961, MAE Home=1.182, MAE Away=1.134
# Epoch 30800: Loss=1.4275, MAE Home=1.188, MAE Away=1.144
# Epoch 31000: Loss=1.4178, MAE Home=1.170, MAE Away=1.129
# Epoch 31200: Loss=1.4027, MAE Home=1.192, MAE Away=1.145
# Epoch 31400: Loss=1.4121, MAE Home=1.191, MAE Away=1.148
# Epoch 31600: Loss=1.3989, MAE Home=1.183, MAE Away=1.141
# Epoch 31800: Loss=1.3922, MAE Home=1.200, MAE Away=1.156
# Epoch 32000: Loss=1.4232, MAE Home=1.202, MAE Away=1.151
# Epoch 32200: Loss=1.3840, MAE Home=1.182, MAE Away=1.140
# Epoch 32400: Loss=1.3911, MAE Home=1.192, MAE Away=1.148
# Epoch 32600: Loss=1.3960, MAE Home=1.167, MAE Away=1.131
# Epoch 32800: Loss=1.4177, MAE Home=1.184, MAE Away=1.143
# Epoch 33000: Loss=1.3939, MAE Home=1.172, MAE Away=1.137
# Epoch 33200: Loss=1.3948, MAE Home=1.174, MAE Away=1.139
# Epoch 33400: Loss=1.4109, MAE Home=1.181, MAE Away=1.142
# Epoch 33600: Loss=1.3868, MAE Home=1.169, MAE Away=1.134
# Epoch 33800: Loss=1.4111, MAE Home=1.170, MAE Away=1.135
# Epoch 34000: Loss=1.4078, MAE Home=1.194, MAE Away=1.152
# Epoch 34200: Loss=1.4039, MAE Home=1.194, MAE Away=1.147
# Epoch 34400: Loss=1.4038, MAE Home=1.183, MAE Away=1.139
# Epoch 34600: Loss=1.4088, MAE Home=1.181, MAE Away=1.141
# Epoch 34800: Loss=1.4150, MAE Home=1.175, MAE Away=1.136
# Epoch 35000: Loss=1.3958, MAE Home=1.175, MAE Away=1.135
# Epoch 35200: Loss=1.3976, MAE Home=1.199, MAE Away=1.154
# Epoch 35400: Loss=1.4028, MAE Home=1.171, MAE Away=1.137
# Epoch 35600: Loss=1.4060, MAE Home=1.171, MAE Away=1.133
# Epoch 35800: Loss=1.4128, MAE Home=1.170, MAE Away=1.133
# Epoch 36000: Loss=1.3929, MAE Home=1.179, MAE Away=1.140
# Epoch 36200: Loss=1.4051, MAE Home=1.167, MAE Away=1.135
# Epoch 36400: Loss=1.3842, MAE Home=1.181, MAE Away=1.139
# Epoch 36600: Loss=1.3823, MAE Home=1.181, MAE Away=1.140
# Epoch 36800: Loss=1.4106, MAE Home=1.184, MAE Away=1.142
# Epoch 37000: Loss=1.3837, MAE Home=1.187, MAE Away=1.145
# Epoch 37200: Loss=1.3955, MAE Home=1.184, MAE Away=1.141
# Epoch 37400: Loss=1.3659, MAE Home=1.173, MAE Away=1.136
# Epoch 37600: Loss=1.3831, MAE Home=1.183, MAE Away=1.143
# Epoch 37800: Loss=1.3810, MAE Home=1.155, MAE Away=1.126
# Epoch 38000: Loss=1.3837, MAE Home=1.172, MAE Away=1.134
# Epoch 38200: Loss=1.3868, MAE Home=1.171, MAE Away=1.135
# Epoch 38400: Loss=1.3981, MAE Home=1.155, MAE Away=1.121
# Epoch 38600: Loss=1.3910, MAE Home=1.180, MAE Away=1.142
# Epoch 38800: Loss=1.4134, MAE Home=1.186, MAE Away=1.146
# Epoch 39000: Loss=1.3750, MAE Home=1.190, MAE Away=1.152
# Epoch 39200: Loss=1.4254, MAE Home=1.182, MAE Away=1.146
# Epoch 39400: Loss=1.3733, MAE Home=1.177, MAE Away=1.137
# Epoch 39600: Loss=1.4061, MAE Home=1.189, MAE Away=1.146
# Epoch 39800: Loss=1.4051, MAE Home=1.177, MAE Away=1.140
# Epoch 40000: Loss=1.3945, MAE Home=1.162, MAE Away=1.130
# Epoch 40200: Loss=1.3857, MAE Home=1.193, MAE Away=1.155
# Epoch 40400: Loss=1.3906, MAE Home=1.167, MAE Away=1.135
# Epoch 40600: Loss=1.3869, MAE Home=1.180, MAE Away=1.145
# Epoch 40800: Loss=1.3911, MAE Home=1.172, MAE Away=1.137
# Epoch 41000: Loss=1.3897, MAE Home=1.172, MAE Away=1.135
# Epoch 41200: Loss=1.4208, MAE Home=1.166, MAE Away=1.132
# Epoch 41400: Loss=1.3807, MAE Home=1.175, MAE Away=1.137
# Epoch 41600: Loss=1.3896, MAE Home=1.177, MAE Away=1.141
# Epoch 41800: Loss=1.4164, MAE Home=1.174, MAE Away=1.135
# Epoch 42000: Loss=1.4021, MAE Home=1.197, MAE Away=1.157
# Epoch 42200: Loss=1.3765, MAE Home=1.170, MAE Away=1.131
# Epoch 42400: Loss=1.4007, MAE Home=1.165, MAE Away=1.132
# Epoch 42600: Loss=1.4197, MAE Home=1.172, MAE Away=1.132
# Epoch 42800: Loss=1.3968, MAE Home=1.163, MAE Away=1.126
# Epoch 43000: Loss=1.3725, MAE Home=1.168, MAE Away=1.135
# Epoch 43200: Loss=1.3860, MAE Home=1.171, MAE Away=1.132
# Epoch 43400: Loss=1.3889, MAE Home=1.183, MAE Away=1.140
# Epoch 43600: Loss=1.3879, MAE Home=1.190, MAE Away=1.149
# Epoch 43800: Loss=1.3888, MAE Home=1.168, MAE Away=1.133
# Epoch 44000: Loss=1.3865, MAE Home=1.180, MAE Away=1.140
# Epoch 44200: Loss=1.3793, MAE Home=1.169, MAE Away=1.135
# Epoch 44400: Loss=1.4072, MAE Home=1.172, MAE Away=1.132
# Epoch 44600: Loss=1.3925, MAE Home=1.172, MAE Away=1.133
# Epoch 44800: Loss=1.3904, MAE Home=1.174, MAE Away=1.136
# Epoch 45000: Loss=1.3945, MAE Home=1.185, MAE Away=1.144
# Epoch 45200: Loss=1.3975, MAE Home=1.182, MAE Away=1.146
# Epoch 45400: Loss=1.4268, MAE Home=1.178, MAE Away=1.140
# Epoch 45600: Loss=1.4048, MAE Home=1.168, MAE Away=1.135
# Epoch 45800: Loss=1.3874, MAE Home=1.183, MAE Away=1.143
# Epoch 46000: Loss=1.4009, MAE Home=1.190, MAE Away=1.149
# Epoch 46200: Loss=1.3845, MAE Home=1.171, MAE Away=1.135
# Epoch 46400: Loss=1.3907, MAE Home=1.181, MAE Away=1.143
# Epoch 46600: Loss=1.4022, MAE Home=1.174, MAE Away=1.136
# Epoch 46800: Loss=1.3654, MAE Home=1.178, MAE Away=1.139
# Epoch 47000: Loss=1.3918, MAE Home=1.175, MAE Away=1.138
# Epoch 47200: Loss=1.3764, MAE Home=1.166, MAE Away=1.130
# Epoch 47400: Loss=1.4046, MAE Home=1.183, MAE Away=1.149
# Epoch 47600: Loss=1.3831, MAE Home=1.182, MAE Away=1.140
# Epoch 47800: Loss=1.4130, MAE Home=1.187, MAE Away=1.146
# Epoch 48000: Loss=1.3908, MAE Home=1.169, MAE Away=1.132
# Epoch 48200: Loss=1.3652, MAE Home=1.183, MAE Away=1.141
# Epoch 48400: Loss=1.3655, MAE Home=1.181, MAE Away=1.143
# Epoch 48600: Loss=1.3760, MAE Home=1.170, MAE Away=1.135
# Epoch 48800: Loss=1.3876, MAE Home=1.185, MAE Away=1.143
# Epoch 49000: Loss=1.3781, MAE Home=1.167, MAE Away=1.130
# Epoch 49200: Loss=1.3778, MAE Home=1.191, MAE Away=1.154
# Epoch 49400: Loss=1.4003, MAE Home=1.167, MAE Away=1.129
# Epoch 49600: Loss=1.3934, MAE Home=1.161, MAE Away=1.128
# Epoch 49800: Loss=1.3843, MAE Home=1.161, MAE Away=1.124
# Epoch 50000: Loss=1.4035, MAE Home=1.170, MAE Away=1.133
# Epoch 50200: Loss=1.3690, MAE Home=1.176, MAE Away=1.136
# Epoch 50400: Loss=1.3719, MAE Home=1.171, MAE Away=1.136
# Epoch 50600: Loss=1.3724, MAE Home=1.185, MAE Away=1.141
# Epoch 50800: Loss=1.3707, MAE Home=1.178, MAE Away=1.141
# Epoch 51000: Loss=1.4077, MAE Home=1.183, MAE Away=1.146
# Epoch 51200: Loss=1.3877, MAE Home=1.163, MAE Away=1.128
# Epoch 51400: Loss=1.3920, MAE Home=1.190, MAE Away=1.146
# Epoch 51600: Loss=1.3924, MAE Home=1.179, MAE Away=1.139
# Epoch 51800: Loss=1.3834, MAE Home=1.186, MAE Away=1.148
# Epoch 52000: Loss=1.3605, MAE Home=1.181, MAE Away=1.140
# Epoch 52200: Loss=1.3750, MAE Home=1.167, MAE Away=1.130
# Epoch 52400: Loss=1.3959, MAE Home=1.171, MAE Away=1.130
# Epoch 52600: Loss=1.4081, MAE Home=1.149, MAE Away=1.117
# Epoch 52800: Loss=1.3536, MAE Home=1.162, MAE Away=1.129
# Epoch 53000: Loss=1.3830, MAE Home=1.177, MAE Away=1.139
# Epoch 53200: Loss=1.3718, MAE Home=1.158, MAE Away=1.125
# Epoch 53400: Loss=1.3745, MAE Home=1.177, MAE Away=1.137
# Epoch 53600: Loss=1.3722, MAE Home=1.175, MAE Away=1.134
# Epoch 53800: Loss=1.3826, MAE Home=1.164, MAE Away=1.128
# Epoch 54000: Loss=1.3821, MAE Home=1.175, MAE Away=1.139
# Epoch 54200: Loss=1.3870, MAE Home=1.164, MAE Away=1.128
# Epoch 54400: Loss=1.3875, MAE Home=1.173, MAE Away=1.135
# Epoch 54600: Loss=1.3741, MAE Home=1.173, MAE Away=1.137
# Epoch 54800: Loss=1.3801, MAE Home=1.181, MAE Away=1.142
# Epoch 55000: Loss=1.3816, MAE Home=1.185, MAE Away=1.146
# Epoch 55200: Loss=1.3763, MAE Home=1.187, MAE Away=1.142
# Epoch 55400: Loss=1.3874, MAE Home=1.182, MAE Away=1.138
# Epoch 55600: Loss=1.3747, MAE Home=1.160, MAE Away=1.121
# Epoch 55800: Loss=1.3778, MAE Home=1.186, MAE Away=1.148
# Epoch 56000: Loss=1.3906, MAE Home=1.178, MAE Away=1.139
# Epoch 56200: Loss=1.3808, MAE Home=1.187, MAE Away=1.146
# Epoch 56400: Loss=1.4251, MAE Home=1.191, MAE Away=1.152
# Epoch 56600: Loss=1.3931, MAE Home=1.178, MAE Away=1.137
# Epoch 56800: Loss=1.3539, MAE Home=1.169, MAE Away=1.133
# Epoch 57000: Loss=1.3893, MAE Home=1.171, MAE Away=1.131
# Epoch 57200: Loss=1.3923, MAE Home=1.181, MAE Away=1.144
# Epoch 57400: Loss=1.3801, MAE Home=1.166, MAE Away=1.133
# Epoch 57600: Loss=1.3854, MAE Home=1.171, MAE Away=1.138
# Epoch 57800: Loss=1.3944, MAE Home=1.172, MAE Away=1.133
# Epoch 58000: Loss=1.3800, MAE Home=1.194, MAE Away=1.148
# Epoch 58200: Loss=1.3918, MAE Home=1.183, MAE Away=1.143
# Epoch 58400: Loss=1.3666, MAE Home=1.184, MAE Away=1.141
# Epoch 58600: Loss=1.3842, MAE Home=1.190, MAE Away=1.147
# Epoch 58800: Loss=1.3888, MAE Home=1.163, MAE Away=1.128
# Epoch 59000: Loss=1.3962, MAE Home=1.203, MAE Away=1.159
# Epoch 59200: Loss=1.3700, MAE Home=1.171, MAE Away=1.135
# Epoch 59400: Loss=1.4023, MAE Home=1.173, MAE Away=1.140
# Epoch 59600: Loss=1.4337, MAE Home=1.187, MAE Away=1.147
# Epoch 59800: Loss=1.3869, MAE Home=1.164, MAE Away=1.129
# Epoch 60000: Loss=1.3964, MAE Home=1.185, MAE Away=1.149
# Epoch 60200: Loss=1.3792, MAE Home=1.178, MAE Away=1.140
# Epoch 60400: Loss=1.3619, MAE Home=1.162, MAE Away=1.128
# Epoch 60600: Loss=1.3698, MAE Home=1.181, MAE Away=1.139
# Epoch 60800: Loss=1.4038, MAE Home=1.194, MAE Away=1.156
# Epoch 61000: Loss=1.3672, MAE Home=1.182, MAE Away=1.139
# Epoch 61200: Loss=1.3862, MAE Home=1.189, MAE Away=1.147
# Epoch 61400: Loss=1.3831, MAE Home=1.176, MAE Away=1.139
# Epoch 61600: Loss=1.3877, MAE Home=1.169, MAE Away=1.133
# Epoch 61800: Loss=1.3916, MAE Home=1.195, MAE Away=1.154
# Epoch 62000: Loss=1.3890, MAE Home=1.171, MAE Away=1.129
# Epoch 62200: Loss=1.4093, MAE Home=1.175, MAE Away=1.137
# Epoch 62400: Loss=1.3753, MAE Home=1.164, MAE Away=1.131
# Epoch 62600: Loss=1.3808, MAE Home=1.180, MAE Away=1.143
# Epoch 62800: Loss=1.3792, MAE Home=1.162, MAE Away=1.126
# Epoch 63000: Loss=1.3833, MAE Home=1.168, MAE Away=1.133
# Epoch 63200: Loss=1.3717, MAE Home=1.176, MAE Away=1.140
# Epoch 63400: Loss=1.3756, MAE Home=1.171, MAE Away=1.135
# Epoch 63600: Loss=1.3717, MAE Home=1.179, MAE Away=1.143
# Epoch 63800: Loss=1.3720, MAE Home=1.186, MAE Away=1.148
# Epoch 64000: Loss=1.3728, MAE Home=1.179, MAE Away=1.143
# Epoch 64200: Loss=1.3814, MAE Home=1.166, MAE Away=1.132
# Epoch 64400: Loss=1.3594, MAE Home=1.176, MAE Away=1.138
# Epoch 64600: Loss=1.3881, MAE Home=1.172, MAE Away=1.135
# Epoch 64800: Loss=1.3815, MAE Home=1.181, MAE Away=1.142
# Epoch 65000: Loss=1.3692, MAE Home=1.178, MAE Away=1.137
# Epoch 65200: Loss=1.3718, MAE Home=1.145, MAE Away=1.117
# Epoch 65400: Loss=1.3474, MAE Home=1.191, MAE Away=1.154
# Epoch 65600: Loss=1.3404, MAE Home=1.196, MAE Away=1.155
# Epoch 65800: Loss=1.3728, MAE Home=1.175, MAE Away=1.138
# Epoch 66000: Loss=1.3666, MAE Home=1.174, MAE Away=1.137
# Epoch 66200: Loss=1.3759, MAE Home=1.191, MAE Away=1.151
# Epoch 66400: Loss=1.3565, MAE Home=1.164, MAE Away=1.128
# Epoch 66600: Loss=1.3791, MAE Home=1.173, MAE Away=1.139
# Epoch 66800: Loss=1.3729, MAE Home=1.162, MAE Away=1.128
# Epoch 67000: Loss=1.3618, MAE Home=1.166, MAE Away=1.130
# Epoch 67200: Loss=1.3747, MAE Home=1.175, MAE Away=1.143
# Epoch 67400: Loss=1.3711, MAE Home=1.170, MAE Away=1.131
# Epoch 67600: Loss=1.3666, MAE Home=1.169, MAE Away=1.137
# Epoch 67800: Loss=1.3861, MAE Home=1.155, MAE Away=1.122
# Epoch 68000: Loss=1.3500, MAE Home=1.144, MAE Away=1.112
# Epoch 68200: Loss=1.3735, MAE Home=1.152, MAE Away=1.119
# Epoch 68400: Loss=1.3772, MAE Home=1.160, MAE Away=1.125
# Epoch 68600: Loss=1.3653, MAE Home=1.165, MAE Away=1.125
# Epoch 68800: Loss=1.3644, MAE Home=1.175, MAE Away=1.138
# Epoch 69000: Loss=1.3860, MAE Home=1.163, MAE Away=1.128
# Epoch 69200: Loss=1.3708, MAE Home=1.162, MAE Away=1.128
# Epoch 69400: Loss=1.3828, MAE Home=1.171, MAE Away=1.133
# Epoch 69600: Loss=1.3985, MAE Home=1.152, MAE Away=1.123
# Epoch 69800: Loss=1.3691, MAE Home=1.164, MAE Away=1.125
# Epoch 70000: Loss=1.3625, MAE Home=1.175, MAE Away=1.137
# Epoch 70200: Loss=1.3687, MAE Home=1.156, MAE Away=1.118
# Epoch 70400: Loss=1.3911, MAE Home=1.168, MAE Away=1.135
# Epoch 70600: Loss=1.3579, MAE Home=1.156, MAE Away=1.125
# Epoch 70800: Loss=1.3716, MAE Home=1.174, MAE Away=1.143
# Epoch 71000: Loss=1.3497, MAE Home=1.166, MAE Away=1.132
# Epoch 71200: Loss=1.3748, MAE Home=1.166, MAE Away=1.133
# Epoch 71400: Loss=1.4036, MAE Home=1.169, MAE Away=1.135
# Epoch 71600: Loss=1.3575, MAE Home=1.171, MAE Away=1.139
# Epoch 71800: Loss=1.3975, MAE Home=1.175, MAE Away=1.141
# Epoch 72000: Loss=1.3757, MAE Home=1.187, MAE Away=1.151
# Epoch 72200: Loss=1.3909, MAE Home=1.162, MAE Away=1.126
# Epoch 72400: Loss=1.3691, MAE Home=1.188, MAE Away=1.149
# Epoch 72600: Loss=1.3692, MAE Home=1.170, MAE Away=1.138
# Epoch 72800: Loss=1.4082, MAE Home=1.181, MAE Away=1.145
# Epoch 73000: Loss=1.3663, MAE Home=1.185, MAE Away=1.148
# Epoch 73200: Loss=1.3740, MAE Home=1.161, MAE Away=1.126
# Epoch 73400: Loss=1.3543, MAE Home=1.155, MAE Away=1.125
# Epoch 73600: Loss=1.3748, MAE Home=1.176, MAE Away=1.143
# Epoch 73800: Loss=1.3836, MAE Home=1.157, MAE Away=1.125
# Epoch 74000: Loss=1.3678, MAE Home=1.167, MAE Away=1.132
# Epoch 74200: Loss=1.3831, MAE Home=1.168, MAE Away=1.135
# Epoch 74400: Loss=1.3563, MAE Home=1.169, MAE Away=1.136
# Epoch 74600: Loss=1.3669, MAE Home=1.158, MAE Away=1.125
# Epoch 74800: Loss=1.3626, MAE Home=1.165, MAE Away=1.131
# Epoch 75000: Loss=1.4041, MAE Home=1.160, MAE Away=1.128
# Epoch 75200: Loss=1.3705, MAE Home=1.190, MAE Away=1.150
# Epoch 75400: Loss=1.3647, MAE Home=1.162, MAE Away=1.131
# Epoch 75600: Loss=1.3788, MAE Home=1.166, MAE Away=1.132
# Epoch 75800: Loss=1.3784, MAE Home=1.160, MAE Away=1.130
# Epoch 76000: Loss=1.3943, MAE Home=1.161, MAE Away=1.128
# Epoch 76200: Loss=1.3848, MAE Home=1.150, MAE Away=1.115
# Epoch 76400: Loss=1.3698, MAE Home=1.151, MAE Away=1.123
# Epoch 76600: Loss=1.3650, MAE Home=1.167, MAE Away=1.135
# Epoch 76800: Loss=1.3807, MAE Home=1.172, MAE Away=1.139
# Epoch 77000: Loss=1.3846, MAE Home=1.186, MAE Away=1.150
# Epoch 77200: Loss=1.3618, MAE Home=1.171, MAE Away=1.139
# Epoch 77400: Loss=1.3784, MAE Home=1.171, MAE Away=1.138
# Epoch 77600: Loss=1.3612, MAE Home=1.149, MAE Away=1.119
# Epoch 77800: Loss=1.3652, MAE Home=1.178, MAE Away=1.141
# Epoch 78000: Loss=1.3572, MAE Home=1.145, MAE Away=1.117
# Epoch 78200: Loss=1.3665, MAE Home=1.154, MAE Away=1.122
# Epoch 78400: Loss=1.4044, MAE Home=1.189, MAE Away=1.152
# Epoch 78600: Loss=1.3590, MAE Home=1.174, MAE Away=1.137
# Epoch 78800: Loss=1.3786, MAE Home=1.192, MAE Away=1.156
# Epoch 79000: Loss=1.4016, MAE Home=1.187, MAE Away=1.149
# Epoch 79200: Loss=1.3969, MAE Home=1.177, MAE Away=1.141
# Epoch 79400: Loss=1.3708, MAE Home=1.160, MAE Away=1.126
# Epoch 79600: Loss=1.3650, MAE Home=1.155, MAE Away=1.120
# Epoch 79800: Loss=1.3772, MAE Home=1.165, MAE Away=1.130
# Epoch 80000: Loss=1.3802, MAE Home=1.165, MAE Away=1.131
# Epoch 80200: Loss=1.3790, MAE Home=1.165, MAE Away=1.131
# Epoch 80400: Loss=1.3597, MAE Home=1.175, MAE Away=1.143
# Epoch 80600: Loss=1.3722, MAE Home=1.165, MAE Away=1.126
# Epoch 80800: Loss=1.3743, MAE Home=1.173, MAE Away=1.137
# Epoch 81000: Loss=1.3593, MAE Home=1.174, MAE Away=1.141
# Epoch 81200: Loss=1.3688, MAE Home=1.166, MAE Away=1.135
# Epoch 81400: Loss=1.3672, MAE Home=1.158, MAE Away=1.125
# Epoch 81600: Loss=1.3617, MAE Home=1.165, MAE Away=1.128
# Epoch 81800: Loss=1.3632, MAE Home=1.160, MAE Away=1.128
# Epoch 82000: Loss=1.3902, MAE Home=1.187, MAE Away=1.149
# Epoch 82200: Loss=1.3796, MAE Home=1.167, MAE Away=1.129
# Epoch 82400: Loss=1.3848, MAE Home=1.159, MAE Away=1.126
# Epoch 82600: Loss=1.3616, MAE Home=1.155, MAE Away=1.124
# Epoch 82800: Loss=1.3786, MAE Home=1.176, MAE Away=1.137
# Epoch 83000: Loss=1.3770, MAE Home=1.160, MAE Away=1.128
# Epoch 83200: Loss=1.3602, MAE Home=1.146, MAE Away=1.112
# Epoch 83400: Loss=1.3455, MAE Home=1.162, MAE Away=1.128
# Epoch 83600: Loss=1.3793, MAE Home=1.185, MAE Away=1.150
# Epoch 83800: Loss=1.3750, MAE Home=1.144, MAE Away=1.114
# Epoch 84000: Loss=1.3726, MAE Home=1.167, MAE Away=1.132
# Epoch 84200: Loss=1.3661, MAE Home=1.176, MAE Away=1.135
# Epoch 84400: Loss=1.3633, MAE Home=1.180, MAE Away=1.138
# Epoch 84600: Loss=1.3712, MAE Home=1.164, MAE Away=1.128
# Epoch 84800: Loss=1.3903, MAE Home=1.173, MAE Away=1.136
# Epoch 85000: Loss=1.3661, MAE Home=1.177, MAE Away=1.141
# Epoch 85200: Loss=1.3673, MAE Home=1.154, MAE Away=1.118
# Epoch 85400: Loss=1.3586, MAE Home=1.175, MAE Away=1.134
# Epoch 85600: Loss=1.3885, MAE Home=1.164, MAE Away=1.133
# Epoch 85800: Loss=1.3517, MAE Home=1.167, MAE Away=1.133
# Epoch 86000: Loss=1.3800, MAE Home=1.166, MAE Away=1.132
# Epoch 86200: Loss=1.3784, MAE Home=1.157, MAE Away=1.123
# Epoch 86400: Loss=1.3644, MAE Home=1.161, MAE Away=1.130
# Epoch 86600: Loss=1.3881, MAE Home=1.156, MAE Away=1.123
# Epoch 86800: Loss=1.3661, MAE Home=1.160, MAE Away=1.128
# Epoch 87000: Loss=1.3672, MAE Home=1.158, MAE Away=1.125
# Epoch 87200: Loss=1.3515, MAE Home=1.178, MAE Away=1.135
# Epoch 87400: Loss=1.3872, MAE Home=1.158, MAE Away=1.126
# Epoch 87600: Loss=1.3739, MAE Home=1.162, MAE Away=1.126
# Epoch 87800: Loss=1.3968, MAE Home=1.170, MAE Away=1.134
# Epoch 88000: Loss=1.3609, MAE Home=1.177, MAE Away=1.145
# Epoch 88200: Loss=1.3726, MAE Home=1.176, MAE Away=1.141
# Epoch 88400: Loss=1.3685, MAE Home=1.160, MAE Away=1.127
# Epoch 88600: Loss=1.3741, MAE Home=1.183, MAE Away=1.144
# Epoch 88800: Loss=1.3635, MAE Home=1.176, MAE Away=1.135
# Epoch 89000: Loss=1.3609, MAE Home=1.152, MAE Away=1.119
# Epoch 89200: Loss=1.3719, MAE Home=1.174, MAE Away=1.137
# Epoch 89400: Loss=1.3682, MAE Home=1.160, MAE Away=1.125
# Epoch 89600: Loss=1.3592, MAE Home=1.167, MAE Away=1.135
# Epoch 89800: Loss=1.3771, MAE Home=1.196, MAE Away=1.160
# Epoch 90000: Loss=1.3582, MAE Home=1.154, MAE Away=1.120
# Epoch 90200: Loss=1.3602, MAE Home=1.176, MAE Away=1.136
# Epoch 90400: Loss=1.3332, MAE Home=1.181, MAE Away=1.147
# Epoch 90600: Loss=1.3922, MAE Home=1.172, MAE Away=1.137
# Epoch 90800: Loss=1.3775, MAE Home=1.175, MAE Away=1.140
# Epoch 91000: Loss=1.3427, MAE Home=1.185, MAE Away=1.145
# Epoch 91200: Loss=1.3686, MAE Home=1.154, MAE Away=1.121
# Epoch 91400: Loss=1.3658, MAE Home=1.164, MAE Away=1.135
# Epoch 91600: Loss=1.3689, MAE Home=1.164, MAE Away=1.128
# Epoch 91800: Loss=1.3617, MAE Home=1.154, MAE Away=1.122
# Epoch 92000: Loss=1.3688, MAE Home=1.156, MAE Away=1.118
# Epoch 92200: Loss=1.3872, MAE Home=1.169, MAE Away=1.138
# Epoch 92400: Loss=1.3748, MAE Home=1.166, MAE Away=1.132
# Epoch 92600: Loss=1.3799, MAE Home=1.168, MAE Away=1.134
# Epoch 92800: Loss=1.3500, MAE Home=1.166, MAE Away=1.136
# Epoch 93000: Loss=1.3754, MAE Home=1.170, MAE Away=1.140
# Epoch 93200: Loss=1.3447, MAE Home=1.159, MAE Away=1.129
# Epoch 93400: Loss=1.3842, MAE Home=1.175, MAE Away=1.138
# Epoch 93600: Loss=1.3456, MAE Home=1.152, MAE Away=1.120
# Epoch 93800: Loss=1.3459, MAE Home=1.180, MAE Away=1.145
# Epoch 94000: Loss=1.3523, MAE Home=1.159, MAE Away=1.119
# Epoch 94200: Loss=1.3981, MAE Home=1.164, MAE Away=1.131
# Epoch 94400: Loss=1.3610, MAE Home=1.159, MAE Away=1.131
# Epoch 94600: Loss=1.3747, MAE Home=1.173, MAE Away=1.139
# Epoch 94800: Loss=1.3417, MAE Home=1.159, MAE Away=1.128
# Epoch 95000: Loss=1.3692, MAE Home=1.163, MAE Away=1.129
# Epoch 95200: Loss=1.3673, MAE Home=1.155, MAE Away=1.121
# Epoch 95400: Loss=1.3830, MAE Home=1.170, MAE Away=1.138
# Epoch 95600: Loss=1.3485, MAE Home=1.173, MAE Away=1.135
# Epoch 95800: Loss=1.3525, MAE Home=1.178, MAE Away=1.137
# Epoch 96000: Loss=1.3714, MAE Home=1.162, MAE Away=1.130
# Epoch 96200: Loss=1.3671, MAE Home=1.168, MAE Away=1.131
# Epoch 96400: Loss=1.3602, MAE Home=1.160, MAE Away=1.120
# Epoch 96600: Loss=1.3603, MAE Home=1.162, MAE Away=1.130
# Epoch 96800: Loss=1.3811, MAE Home=1.153, MAE Away=1.121
# Epoch 97000: Loss=1.3591, MAE Home=1.144, MAE Away=1.113
# Epoch 97200: Loss=1.3602, MAE Home=1.190, MAE Away=1.152
# Epoch 97400: Loss=1.3825, MAE Home=1.172, MAE Away=1.134
# Epoch 97600: Loss=1.3962, MAE Home=1.156, MAE Away=1.121
# Epoch 97800: Loss=1.3580, MAE Home=1.161, MAE Away=1.130
# Epoch 98000: Loss=1.3607, MAE Home=1.171, MAE Away=1.136
# Epoch 98200: Loss=1.3470, MAE Home=1.172, MAE Away=1.136
# Epoch 98400: Loss=1.3615, MAE Home=1.155, MAE Away=1.120
# Epoch 98600: Loss=1.3850, MAE Home=1.165, MAE Away=1.134
# Epoch 98800: Loss=1.3650, MAE Home=1.170, MAE Away=1.134
# Epoch 99000: Loss=1.3502, MAE Home=1.160, MAE Away=1.131
# Epoch 99200: Loss=1.3794, MAE Home=1.148, MAE Away=1.116
# Epoch 99400: Loss=1.3643, MAE Home=1.153, MAE Away=1.123
# Epoch 99600: Loss=1.3672, MAE Home=1.161, MAE Away=1.128
# Epoch 99800: Loss=1.3656, MAE Home=1.153, MAE Away=1.120
# Epoch 99999: Loss=1.3580, MAE Home=1.169, MAE Away=1.135
#
# ✅ Training complete!
# 🏠 Learned home advantage: +0.167 goals
# 🏆 Extracting Team Ratings...
#
# ⚔️ ATTACK RATINGS (Higher = Better Attack)
# ==================================================
#  1. Crystal Palace       1.510
#  2. Brentford            1.475
#  3. Brighton             1.455
#  4. Liverpool            1.352
#  5. West Ham             1.143
#  6. Everton              1.010
#  7. Manchester City      0.909
#  8. Manchester Utd       0.903
#  9. Arsenal              0.768
# 10. Bournemouth          0.653
# 11. Aston Villa          0.633
# 12. Chelsea              0.452
# 13. Newcastle Utd        0.332
# 14. Tottenham            0.220
# 15. Nott'ham Forest      0.114
# 16. Fulham               0.003
# 17. Wolves               0.000
# 18. Ipswich Town         0.000
# 19. Southampton          0.000
# 20. Leicester City       0.000
#
# 🛡️ DEFENSE RATINGS (Higher = Better Defense)
# ==================================================
#  1. Leicester City       1.013
#  2. Ipswich Town         0.854
#  3. Tottenham            0.850
#  4. Southampton          0.680
#  5. Aston Villa          0.618
#  6. Bournemouth          0.596
#  7. Wolves               0.593
#  8. Brentford            0.496
#  9. Brighton             0.435
# 10. Arsenal              0.401
# 11. Manchester City      0.391
# 12. Newcastle Utd        0.241
# 13. Nott'ham Forest      0.214
# 14. Everton              0.171
# 15. Chelsea              0.169
# 16. Fulham               0.042
# 17. West Ham             0.029
# 18. Manchester Utd       0.024
# 19. Liverpool            0.010
# 20. Crystal Palace       0.004
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5632\2239893120.py:241: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   team_features = row[feature_cols].fillna(0).values.reshape(1, -1)
