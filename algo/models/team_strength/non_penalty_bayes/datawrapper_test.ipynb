# %%
from datawrapper import Datawrapper
dw = Datawrapper(access_token = "ZVnOtN7rfXBTiW0BCZMKlhsUayDXBMoCRM39KzRRLmSj3Q1Far3V1FaSC0yIyhbM")
# Out:
# Collecting datawrapper
#   Downloading datawrapper-2.0.15-py3-none-any.whl.metadata (4.9 kB)
# Collecting importlib_metadata (from datawrapper)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: rich in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from datawrapper) (14.1.0)
# Requirement already satisfied: requests in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from datawrapper) (2.32.5)
# Requirement already satisfied: pandas in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from datawrapper) (2.3.3)
# Collecting pydantic (from datawrapper)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: ipython in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from datawrapper) (9.6.0)
# Collecting zipp>=3.20 (from importlib_metadata->datawrapper)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: decorator in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from ipython->datawrapper) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from ipython->datawrapper) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from ipython->datawrapper) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from ipython->datawrapper) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from ipython->datawrapper) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from ipython->datawrapper) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from ipython->datawrapper) (2.19.2)
# Requirement already satisfied: stack_data in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from ipython->datawrapper) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from ipython->datawrapper) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->datawrapper) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython->datawrapper) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython->datawrapper) (0.7.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from pandas->datawrapper) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from pandas->datawrapper) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from pandas->datawrapper) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from pandas->datawrapper) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datawrapper) (1.17.0)
# Collecting annotated-types>=0.6.0 (from pydantic->datawrapper)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic->datawrapper)
#   Downloading pydantic_core-2.41.5-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from pydantic->datawrapper) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic->datawrapper)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from requests->datawrapper) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from requests->datawrapper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from requests->datawrapper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from requests->datawrapper) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from rich->datawrapper) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->datawrapper) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from stack_data->ipython->datawrapper) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from stack_data->ipython->datawrapper) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/admin/Documents/dev/algobetting/.venv/lib/python3.13/site-packages (from stack_data->ipython->datawrapper) (0.2.3)
# Downloading datawrapper-2.0.15-py3-none-any.whl (102 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 30.7 MB/s  0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: zipp, typing-inspection, pydantic-core, annotated-types, pydantic, importlib_metadata, datawrapper
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [datawrapper] [pydantic]
# Successfully installed annotated-types-0.7.0 datawrapper-2.0.15 importlib_metadata-8.7.0 pydantic-2.12.5 pydantic-core-2.41.5 typing-inspection-0.4.2 zipp-3.23.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
