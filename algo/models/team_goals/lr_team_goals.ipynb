# %%
import pandas as pd
import sqlite3
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
conn = sqlite3.connect(r'C:\Users\Owner\dev\algobetting\infra\data\db\algobetting.db')

df = pd.read_sql_query("SELECT * FROM fbref_team_goals_features", conn)

df
# Out:
#                                              match_url           match_date  \
# 0    https://fbref.com/en/matches/d8efb6cc/Leiceste...  2025-04-07 00:00:00
# 1    https://fbref.com/en/matches/d8efb6cc/Leiceste...  2025-04-07 00:00:00
# 2    https://fbref.com/en/matches/53e359bb/Manchest...  2025-04-06 00:00:00
# 3    https://fbref.com/en/matches/53e359bb/Manchest...  2025-04-06 00:00:00
# 4    https://fbref.com/en/matches/f671e515/Tottenha...  2025-04-06 00:00:00
# ..                                                 ...                  ...
# 613  https://fbref.com/en/matches/34557647/Newcastl...  2024-08-17 00:00:00
# 614  https://fbref.com/en/matches/a1d0d529/Ipswich-...  2024-08-17 00:00:00
# 615  https://fbref.com/en/matches/a1d0d529/Ipswich-...  2024-08-17 00:00:00
# 616  https://fbref.com/en/matches/cc5b4244/Manchest...  2024-08-16 00:00:00
# 617  https://fbref.com/en/matches/cc5b4244/Manchest...  2024-08-16 00:00:00
#
#         season             team         opp_team  is_home  \
# 0    2024-2025   Leicester City    Newcastle Utd        1
# 1    2024-2025    Newcastle Utd   Leicester City        0
# 2    2024-2025   Manchester Utd  Manchester City        1
# 3    2024-2025  Manchester City   Manchester Utd        0
# 4    2024-2025        Tottenham      Southampton        1
# ..         ...              ...              ...      ...
# 613  2024-2025      Southampton    Newcastle Utd        0
# 614  2024-2025     Ipswich Town        Liverpool        1
# 615  2024-2025        Liverpool     Ipswich Town        0
# 616  2024-2025   Manchester Utd           Fulham        1
# 617  2024-2025           Fulham   Manchester Utd        0
#
#      weighted_attack_shots  weighted_attack_shots_on_target  \
# 0                 8.105350                         2.600351
# 1                13.165634                         4.004774
# 2                13.689871                         4.284051
# 3                15.209960                         5.343318
# 4                13.140963                         4.770302
# ..                     ...                              ...
# 613                    NaN                              NaN
# 614                    NaN                              NaN
# 615                    NaN                              NaN
# 616                    NaN                              NaN
# 617                    NaN                              NaN
#
#      weighted_attack_xg  weighted_attack_npxg  ...  \
# 0              0.750664              0.720087  ...
# 1              1.641469              1.525481  ...
# 2              1.353017              1.266695  ...
# 3              1.781890              1.685822  ...
# 4              1.518244              1.448217  ...
# ..                  ...                   ...  ...
# 613                 NaN                   NaN  ...
# 614                 NaN                   NaN  ...
# 615                 NaN                   NaN  ...
# 616                 NaN                   NaN  ...
# 617                 NaN                   NaN  ...
#
#      weighted_attack_corner_kicks  weighted_defense_opp_shots_opp  \
# 0                        3.423464                       12.765053
# 1                        5.298801                       16.130546
# 2                        5.174914                        9.717322
# 3                        6.215298                       11.391665
# 4                        6.690033                       17.076964
# ..                            ...                             ...
# 613                           NaN                             NaN
# 614                           NaN                             NaN
# 615                           NaN                             NaN
# 616                           NaN                             NaN
# 617                           NaN                             NaN
#
#      weighted_defense_opp_shots_on_target_opp  weighted_defense_opp_xg_opp  \
# 0                                    4.325572                     1.312010
# 1                                    5.494694                     1.887059
# 2                                    3.708855                     1.319316
# 3                                    3.949791                     1.501332
# 4                                    6.432989                     2.281046
# ..                                        ...                          ...
# 613                                       NaN                          NaN
# 614                                       NaN                          NaN
# 615                                       NaN                          NaN
# 616                                       NaN                          NaN
# 617                                       NaN                          NaN
#
#      weighted_defense_opp_npxg_opp  \
# 0                         1.262558
# 1                         1.825313
# 2                         1.248066
# 3                         1.414472
# 4                         2.105396
# ..                             ...
# 613                            NaN
# 614                            NaN
# 615                            NaN
# 616                            NaN
# 617                            NaN
#
#      weighted_defense_opp_touches_att_pen_area_opp  \
# 0                                        24.266470
# 1                                        31.816265
# 2                                        18.973256
# 3                                        21.819881
# 4                                        32.140872
# ..                                             ...
# 613                                            NaN
# 614                                            NaN
# 615                                            NaN
# 616                                            NaN
# 617                                            NaN
#
#      weighted_defense_opp_touches_att_3rd_opp  \
# 0                                  154.910355
# 1                                  195.700380
# 2                                  103.936086
# 3                                  148.418899
# 4                                  176.702024
# ..                                        ...
# 613                                       NaN
# 614                                       NaN
# 615                                       NaN
# 616                                       NaN
# 617                                       NaN
#
#      weighted_defense_opp_touches_opp  weighted_defense_opp_pens_won_opp  \
# 0                          602.153551                           0.061815
# 1                          690.196090                           0.073388
# 2                          518.077414                           0.089062
# 3                          585.695759                           0.072168
# 4                          626.645503                           0.143379
# ..                                ...                                ...
# 613                               NaN                                NaN
# 614                               NaN                                NaN
# 615                               NaN                                NaN
# 616                               NaN                                NaN
# 617                               NaN                                NaN
#
#      weighted_defense_opp_corner_kicks_opp
# 0                                 4.921473
# 1                                 6.049093
# 2                                 3.511343
# 3                                 4.958106
# 4                                 5.438184
# ..                                     ...
# 613                                    NaN
# 614                                    NaN
# 615                                    NaN
# 616                                    NaN
# 617                                    NaN
#
# [618 rows x 24 columns]
