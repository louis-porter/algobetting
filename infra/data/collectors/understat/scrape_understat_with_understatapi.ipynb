# %% [markdown]
# #### First the understatapi
#
# -- This package is not actively maintained so use at your own risk

# %%
# !pip install understatapi --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selenium 4.41.0 requires certifi>=2026.1.4, but you have certifi 2025.11.12 which is incompatible.
# selenium 4.41.0 requires urllib3[socks]<3.0,>=2.6.3, but you have urllib3 1.26.5 which is incompatible.
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import understatapi

client = understatapi.UnderstatClient()

# %%
# Let's first get data from a league to retrieve a list of matches
league_data = client.league(league="EPL").get_match_data(season="2025")
league_data[0]
# Out:
# {'id': '28778',
#  'isResult': True,
#  'h': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#  'a': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#  'goals': {'h': '4', 'a': '2'},
#  'xG': {'h': '2.33007', 'a': '1.57303'},
#  'datetime': '2025-08-15 19:00:00',
#  'forecast': {'w': '0.5498', 'd': '0.2276', 'l': '0.2226'}}

# %%
# now we can use the match id to get the match data
shot_data = client.match(match=league_data[0]["id"]).get_shot_data()
shot_data
# Out:
# {'h': [{'id': '637500',
#    'minute': '2',
#    'result': 'SavedShot',
#    'X': '0.7619999694824219',
#    'Y': '0.6990000152587891',
#    'xG': '0.014601008035242558',
#    'player': 'Hugo Ekitike',
#    'h_a': 'h',
#    'player_id': '8995',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Cody Gakpo',
#    'lastAction': 'Pass'},
#   {'id': '637501',
#    'minute': '3',
#    'result': 'SavedShot',
#    'X': '0.855999984741211',
#    'Y': '0.3129999923706055',
#    'xG': '0.04265604913234711',
#    'player': 'Mohamed Salah',
#    'h_a': 'h',
#    'player_id': '1250',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'LeftFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Hugo Ekitike',
#    'lastAction': 'Pass'},
#   {'id': '637502',
#    'minute': '4',
#    'result': 'MissedShots',
#    'X': '0.914000015258789',
#    'Y': '0.505',
#    'xG': '0.25797542929649353',
#    'player': 'Virgil van Dijk',
#    'h_a': 'h',
#    'player_id': '833',
#    'situation': 'FromCorner',
#    'season': '2025',
#    'shotType': 'Head',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Mohamed Salah',
#    'lastAction': 'Cross'},
#   {'id': '637505',
#    'minute': '30',
#    'result': 'SavedShot',
#    'X': '0.9119999694824219',
#    'Y': '0.5320000076293945',
#    'xG': '0.0776621475815773',
#    'player': 'Virgil van Dijk',
#    'h_a': 'h',
#    'player_id': '833',
#    'situation': 'FromCorner',
#    'season': '2025',
#    'shotType': 'Head',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Florian Wirtz',
#    'lastAction': 'Cross'},
#   {'id': '637507',
#    'minute': '36',
#    'result': 'Goal',
#    'X': '0.8909999847412109',
#    'Y': '0.524000015258789',
#    'xG': '0.40409132838249207',
#    'player': 'Hugo Ekitike',
#    'h_a': 'h',
#    'player_id': '8995',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Alexis Mac Allister',
#    'lastAction': 'TakeOn'},
#   {'id': '637508',
#    'minute': '38',
#    'result': 'MissedShots',
#    'X': '0.9419999694824219',
#    'Y': '0.4829999923706055',
#    'xG': '0.534849226474762',
#    'player': 'Hugo Ekitike',
#    'h_a': 'h',
#    'player_id': '8995',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'Head',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Cody Gakpo',
#    'lastAction': 'Cross'},
#   {'id': '637511',
#    'minute': '47',
#    'result': 'BlockedShot',
#    'X': '0.85',
#    'Y': '0.42700000762939455',
#    'xG': '0.11337560415267944',
#    'player': 'Mohamed Salah',
#    'h_a': 'h',
#    'player_id': '1250',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'LeftFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Cody Gakpo',
#    'lastAction': 'Pass'},
#   {'id': '637513',
#    'minute': '46',
#    'result': 'MissedShots',
#    'X': '0.960999984741211',
#    'Y': '0.5209999847412109',
#    'xG': '0.1347046047449112',
#    'player': 'Hugo Ekitike',
#    'h_a': 'h',
#    'player_id': '8995',
#    'situation': 'FromCorner',
#    'season': '2025',
#    'shotType': 'OtherBodyPart',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Florian Wirtz',
#    'lastAction': 'Aerial'},
#   {'id': '637514',
#    'minute': '48',
#    'result': 'Goal',
#    'X': '0.850999984741211',
#    'Y': '0.49200000762939455',
#    'xG': '0.0957067683339119',
#    'player': 'Cody Gakpo',
#    'h_a': 'h',
#    'player_id': '11296',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Hugo Ekitike',
#    'lastAction': 'Pass'},
#   {'id': '637515',
#    'minute': '51',
#    'result': 'SavedShot',
#    'X': '0.76',
#    'Y': '0.34799999237060547',
#    'xG': '0.027150798588991165',
#    'player': 'Alexis Mac Allister',
#    'h_a': 'h',
#    'player_id': '8379',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Florian Wirtz',
#    'lastAction': 'LayOff'},
#   {'id': '637516',
#    'minute': '52',
#    'result': 'BlockedShot',
#    'X': '0.754000015258789',
#    'Y': '0.37200000762939456',
#    'xG': '0.015647554770112038',
#    'player': 'Jeremie Frimpong',
#    'h_a': 'h',
#    'player_id': '9328',
#    'situation': 'FromCorner',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '637517',
#    'minute': '53',
#    'result': 'MissedShots',
#    'X': '0.7090000152587891',
#    'Y': '0.5570000076293945',
#    'xG': '0.014567305333912373',
#    'player': 'Dominik Szoboszlai',
#    'h_a': 'h',
#    'player_id': '9788',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '637518',
#    'minute': '62',
#    'result': 'MissedShots',
#    'X': '0.84',
#    'Y': '0.45799999237060546',
#    'xG': '0.11103862524032593',
#    'player': 'Florian Wirtz',
#    'h_a': 'h',
#    'player_id': '8397',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Dominik Szoboszlai',
#    'lastAction': 'Pass'},
#   {'id': '637520',
#    'minute': '69',
#    'result': 'SavedShot',
#    'X': '0.8519999694824218',
#    'Y': '0.7609999847412109',
#    'xG': '0.03299751132726669',
#    'player': 'Cody Gakpo',
#    'h_a': 'h',
#    'player_id': '11296',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Dominik Szoboszlai',
#    'lastAction': 'Pass'},
#   {'id': '637524',
#    'minute': '79',
#    'result': 'MissedShots',
#    'X': '0.855',
#    'Y': '0.4420000076293945',
#    'xG': '0.09390604496002197',
#    'player': 'Dominik Szoboszlai',
#    'h_a': 'h',
#    'player_id': '9788',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'LeftFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Curtis Jones',
#    'lastAction': 'Pass'},
#   {'id': '637525',
#    'minute': '80',
#    'result': 'SavedShot',
#    'X': '0.865',
#    'Y': '0.33599998474121096',
#    'xG': '0.05117299035191536',
#    'player': 'Dominik Szoboszlai',
#    'h_a': 'h',
#    'player_id': '9788',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Mohamed Salah',
#    'lastAction': 'Pass'},
#   {'id': '637526',
#    'minute': '87',
#    'result': 'MissedShots',
#    'X': '0.909000015258789',
#    'Y': '0.624000015258789',
#    'xG': '0.07005230337381363',
#    'player': 'Cody Gakpo',
#    'h_a': 'h',
#    'player_id': '11296',
#    'situation': 'SetPiece',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '637527',
#    'minute': '87',
#    'result': 'Goal',
#    'X': '0.8980000305175782',
#    'Y': '0.534000015258789',
#    'xG': '0.09901324659585953',
#    'player': 'Federico Chiesa',
#    'h_a': 'h',
#    'player_id': '1433',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '637528',
#    'minute': '93',
#    'result': 'Goal',
#    'X': '0.899000015258789',
#    'Y': '0.6129999923706054',
#    'xG': '0.13890482485294342',
#    'player': 'Mohamed Salah',
#    'h_a': 'h',
#    'player_id': '1250',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Wataru Endo',
#    'lastAction': 'BallRecovery'}],
#  'a': [{'id': '637503',
#    'minute': '5',
#    'result': 'MissedShots',
#    'X': '0.9080000305175782',
#    'Y': '0.44400001525878907',
#    'xG': '0.3169209659099579',
#    'player': 'Antoine Semenyo',
#    'h_a': 'a',
#    'player_id': '11363',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Adrien Truffert',
#    'lastAction': 'Cross'},
#   {'id': '637504',
#    'minute': '9',
#    'result': 'MissedShots',
#    'X': '0.9490000152587891',
#    'Y': '0.4109999847412109',
#    'xG': '0.071727454662323',
#    'player': 'Evanilson',
#    'h_a': 'a',
#    'player_id': '12963',
#    'situation': 'FromCorner',
#    'season': '2025',
#    'shotType': 'Head',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'David Brooks',
#    'lastAction': 'Cross'},
#   {'id': '637506',
#    'minute': '34',
#    'result': 'SavedShot',
#    'X': '0.87',
#    'Y': '0.5209999847412109',
#    'xG': '0.35100075602531433',
#    'player': 'Marcus Tavernier',
#    'h_a': 'a',
#    'player_id': '10741',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Adam Smith',
#    'lastAction': 'Pass'},
#   {'id': '637509',
#    'minute': '41',
#    'result': 'BlockedShot',
#    'X': '0.855',
#    'Y': '0.685',
#    'xG': '0.038630276918411255',
#    'player': 'David Brooks',
#    'h_a': 'a',
#    'player_id': '6820',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'RightFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '637510',
#    'minute': '46',
#    'result': 'BlockedShot',
#    'X': '0.75',
#    'Y': '0.315',
#    'xG': '0.045542508363723755',
#    'player': 'Marcus Tavernier',
#    'h_a': 'a',
#    'player_id': '10741',
#    'situation': 'DirectFreekick',
#    'season': '2025',
#    'shotType': 'LeftFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '637512',
#    'minute': '48',
#    'result': 'MissedShots',
#    'X': '0.8769999694824219',
#    'Y': '0.6559999847412109',
#    'xG': '0.09731415659189224',
#    'player': 'Evanilson',
#    'h_a': 'a',
#    'player_id': '12963',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'LeftFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'David Brooks',
#    'lastAction': 'Pass'},
#   {'id': '637519',
#    'minute': '63',
#    'result': 'Goal',
#    'X': '0.9080000305175782',
#    'Y': '0.5129999923706055',
#    'xG': '0.42599424719810486',
#    'player': 'Antoine Semenyo',
#    'h_a': 'a',
#    'player_id': '11363',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'LeftFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'David Brooks',
#    'lastAction': 'Cross'},
#   {'id': '637521',
#    'minute': '70',
#    'result': 'BlockedShot',
#    'X': '0.8959999847412109',
#    'Y': '0.63',
#    'xG': '0.07709097117185593',
#    'player': 'David Brooks',
#    'h_a': 'a',
#    'player_id': '6820',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'LeftFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Marcus Tavernier',
#    'lastAction': 'TakeOn'},
#   {'id': '637522',
#    'minute': '70',
#    'result': 'MissedShots',
#    'X': '0.9119999694824219',
#    'Y': '0.595',
#    'xG': '0.05321967601776123',
#    'player': 'Evanilson',
#    'h_a': 'a',
#    'player_id': '12963',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'Head',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Marcos Senesi',
#    'lastAction': 'Cross'},
#   {'id': '637523',
#    'minute': '75',
#    'result': 'Goal',
#    'X': '0.825',
#    'Y': '0.4829999923706055',
#    'xG': '0.09559009969234467',
#    'player': 'Antoine Semenyo',
#    'h_a': 'a',
#    'player_id': '11363',
#    'situation': 'OpenPlay',
#    'season': '2025',
#    'shotType': 'LeftFoot',
#    'match_id': '28778',
#    'h_team': 'Liverpool',
#    'a_team': 'Bournemouth',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2025-08-15 19:00:00',
#    'player_assisted': 'Hamed Junior Traore',
#    'lastAction': 'Pass'}]}

# %%
# now let's get all of the data for a player, with this method you need to use the player_id
# This is literally every shot they ever took. 

player_data = client.player(player='1228').get_shot_data()
player_data[0]
# Out:
# {'id': '41640',
#  'minute': '79',
#  'result': 'BlockedShot',
#  'X': '0.730999984741211',
#  'Y': '0.5059999847412109',
#  'xG': '0.031210700049996376',
#  'player': 'Bruno Fernandes',
#  'h_a': 'h',
#  'player_id': '1228',
#  'situation': 'OpenPlay',
#  'season': '2014',
#  'shotType': 'RightFoot',
#  'match_id': '5158',
#  'h_team': 'Udinese',
#  'a_team': 'Empoli',
#  'h_goals': '2',
#  'a_goals': '0',
#  'date': '2014-08-31 19:45:00',
#  'player_assisted': 'Cyril Théréau',
#  'lastAction': 'Pass'}

# %%
df = pd.DataFrame(player_data)

# %%
df
# Out:
#          id minute       result                   X                   Y  \
# 0     41640     79  BlockedShot   0.730999984741211  0.5059999847412109
# 1     41641     82  MissedShots  0.9569999694824218  0.6170000076293946
# 2     41643     86    SavedShot                0.77  0.5170000076293946
# 3     41807     47  BlockedShot   0.759000015258789   0.664000015258789
# 4     42170     42  BlockedShot   0.754000015258789   0.534000015258789
# ..      ...    ...          ...                 ...                 ...
# 755  671574     63  MissedShots                0.78  0.6969999694824218
# 756  672324     81  MissedShots                0.81  0.5929999923706055
# 757  674425     19  BlockedShot  0.7269999694824218  0.3820000076293945
# 758  674431     42  MissedShots  0.7390000152587891  0.6880000305175781
# 759  674433     50  BlockedShot  0.8030000305175782                0.31
#
#                        xG           player h_a player_id situation season  \
# 0    0.031210700049996376  Bruno Fernandes   h      1228  OpenPlay   2014
# 1     0.11918000131845474  Bruno Fernandes   h      1228  OpenPlay   2014
# 2    0.037953298538923264  Bruno Fernandes   h      1228  OpenPlay   2014
# 3     0.01848829910159111  Bruno Fernandes   a      1228  OpenPlay   2014
# 4     0.02486089989542961  Bruno Fernandes   h      1228  OpenPlay   2014
# ..                    ...              ...  ..       ...       ...    ...
# 755  0.016284747049212456  Bruno Fernandes   h      1228  OpenPlay   2025
# 756   0.04061715304851532  Bruno Fernandes   a      1228  OpenPlay   2025
# 757  0.013531903736293316  Bruno Fernandes   h      1228  OpenPlay   2025
# 758   0.03037339262664318  Bruno Fernandes   h      1228  OpenPlay   2025
# 759  0.021025920286774635  Bruno Fernandes   h      1228  OpenPlay   2025
#
#       shotType match_id             h_team             a_team h_goals a_goals  \
# 0    RightFoot     5158            Udinese             Empoli       2       0
# 1    RightFoot     5158            Udinese             Empoli       2       0
# 2    RightFoot     5158            Udinese             Empoli       2       0
# 3    RightFoot     5110           Juventus            Udinese       2       0
# 4     LeftFoot     5125            Udinese             Napoli       1       0
# ..         ...      ...                ...                ...     ...     ...
# 755  RightFoot    29055  Manchester United     Crystal Palace       2       1
# 756  RightFoot    29065   Newcastle United  Manchester United       2       1
# 757   LeftFoot    29074  Manchester United        Aston Villa       3       1
# 758  RightFoot    29074  Manchester United        Aston Villa       3       1
# 759  RightFoot    29074  Manchester United        Aston Villa       3       1
#
#                     date     player_assisted lastAction
# 0    2014-08-31 19:45:00       Cyril Théréau       Pass
# 1    2014-08-31 19:45:00   Antonio Di Natale    Chipped
# 2    2014-08-31 19:45:00     Panagiotis Kone       Pass
# 3    2014-09-13 19:45:00   Antonio Di Natale     LayOff
# 4    2014-09-21 17:00:00       Emmanuel Badu       Pass
# ..                   ...                 ...        ...
# 755  2026-03-01 14:00:00            Casemiro    Chipped
# 756  2026-03-04 20:15:00       Matheus Cunha       Pass
# 757  2026-03-15 14:00:00  Amad Diallo Traore       Pass
# 758  2026-03-15 14:00:00       Kobbie Mainoo       Pass
# 759  2026-03-15 14:00:00  Amad Diallo Traore       Pass
#
# [760 rows x 20 columns]

# %%
df.to_csv('/Users/mckayjohns/Documents/GitHub/youtube-videos/data/bruno_fernandes_all_shots.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.to_csv('/Users/mckayjohns/Documents/GitHub/youtube-videos/data/bruno_fernandes_all_shots.csv', index=False)
#
# File ~/dev/algobetting/.venv/lib/python3.13/site-packages/pandas/core/generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3977 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3979 formatter = DataFrameFormatter(
#    3980     frame=df,
#    3981     header=header,
#    (...)   3985     decimal=decimal,
#    3986 )
# -> 3988 return DataFrameRenderer(formatter).to_csv(
#    3989     path_or_buf,
#    3990     lineterminator=lineterminator,
#    3991     sep=sep,
#    3992     encoding=encoding,
#    3993     errors=errors,
#    3994     compression=compression,
#    3995     quoting=quoting,
#    3996     columns=columns,
#    3997     index_label=index_label,
#    3998     mode=mode,
#    3999     chunksize=chunksize,
#    4000     quotechar=quotechar,
#    4001     date_format=date_format,
#    4002     doublequote=doublequote,
#    4003     escapechar=escapechar,
#    4004     storage_options=storage_options,
#    4005 )
#
# File ~/dev/algobetting/.venv/lib/python3.13/site-packages/pandas/io/formats/format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File ~/dev/algobetting/.venv/lib/python3.13/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
#     272     self._save()
#
# File ~/dev/algobetting/.venv/lib/python3.13/site-packages/pandas/io/common.py:793, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     791 # Only for write methods
#     792 if "r" not in mode and is_path:
# --> 793     check_parent_directory(str(handle))
#     795 if compression:
#     796     if compression != "zstd":
#     797         # compression libraries do not like an explicit text-mode
#
# File ~/dev/algobetting/.venv/lib/python3.13/site-packages/pandas/io/common.py:652, in check_parent_directory(path)
#     650 parent = Path(path).parent
#     651 if not parent.is_dir():
# --> 652     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '/Users/mckayjohns/Documents/GitHub/youtube-videos/data'

# %% [markdown]
# #### Now let's scrape it ourselves with requests and BeautifulSoup. This is a bit more work so we'll look at only a single match
# You'll need to install:
# - requests
# - BeautifulSoup
# - lxml

# %%
import re
import requests
import json

from bs4 import BeautifulSoup

response = requests.get("https://understat.com/match/27760")
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')
ugly_soup = str(soup)

# %%
# strip unnecessary symbols and get only JSON data
shots_data = re.search("var shotsData .*= JSON.parse\('(.*)'\)", ugly_soup).group(1)
data = json.loads(shots_data.encode('utf8').decode('unicode_escape'))

# %%
data
# Out:
# {'h': [{'id': '590347',
#    'minute': '2',
#    'result': 'SavedShot',
#    'X': '0.8930000305175781',
#    'Y': '0.36200000762939455',
#    'xG': '0.011930749751627445',
#    'player': 'Ramy Bensebaini',
#    'h_a': 'h',
#    'player_id': '3349',
#    'situation': 'SetPiece',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'},
#   {'id': '590348',
#    'minute': '5',
#    'result': 'MissedShots',
#    'X': '0.7959999847412109',
#    'Y': '0.40099998474121096',
#    'xG': '0.040396686643362045',
#    'player': 'Pascal Groß',
#    'h_a': 'h',
#    'player_id': '239',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Julian Ryerson',
#    'lastAction': 'BallTouch'},
#   {'id': '590349',
#    'minute': '10',
#    'result': 'Goal',
#    'X': '0.8230000305175781',
#    'Y': '0.51',
#    'xG': '0.07171561568975449',
#    'player': 'Donyell Malen',
#    'h_a': 'h',
#    'player_id': '9749',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Karim Adeyemi',
#    'lastAction': 'Pass'},
#   {'id': '590350',
#    'minute': '16',
#    'result': 'Goal',
#    'X': '0.915',
#    'Y': '0.65',
#    'xG': '0.34929072856903076',
#    'player': 'Karim Adeyemi',
#    'h_a': 'h',
#    'player_id': '10772',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Julian Brandt',
#    'lastAction': 'Pass'},
#   {'id': '590355',
#    'minute': '36',
#    'result': 'BlockedShot',
#    'X': '0.8590000152587891',
#    'Y': '0.7030000305175781',
#    'xG': '0.08351726084947586',
#    'player': 'Serhou Guirassy',
#    'h_a': 'h',
#    'player_id': '3738',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Felix Nmecha',
#    'lastAction': 'Chipped'},
#   {'id': '590357',
#    'minute': '40',
#    'result': 'Goal',
#    'X': '0.8619999694824219',
#    'Y': '0.5159999847412109',
#    'xG': '0.11208920180797577',
#    'player': 'Karim Adeyemi',
#    'h_a': 'h',
#    'player_id': '10772',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Julian Ryerson',
#    'lastAction': 'Pass'},
#   {'id': '590358',
#    'minute': '44',
#    'result': 'BlockedShot',
#    'X': '0.845',
#    'Y': '0.27100000381469724',
#    'xG': '0.02453427016735077',
#    'player': 'Donyell Malen',
#    'h_a': 'h',
#    'player_id': '9749',
#    'situation': 'SetPiece',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Julian Brandt',
#    'lastAction': 'Pass'},
#   {'id': '590360',
#    'minute': '48',
#    'result': 'BlockedShot',
#    'X': '0.894000015258789',
#    'Y': '0.4470000076293945',
#    'xG': '0.05760763958096504',
#    'player': 'Serhou Guirassy',
#    'h_a': 'h',
#    'player_id': '3738',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Pascal Groß',
#    'lastAction': 'Cross'},
#   {'id': '590361',
#    'minute': '51',
#    'result': 'MissedShots',
#    'X': '0.845',
#    'Y': '0.47900001525878905',
#    'xG': '0.11947015672922134',
#    'player': 'Donyell Malen',
#    'h_a': 'h',
#    'player_id': '9749',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Karim Adeyemi',
#    'lastAction': 'Pass'},
#   {'id': '590363',
#    'minute': '58',
#    'result': 'MissedShots',
#    'X': '0.909000015258789',
#    'Y': '0.4909999847412109',
#    'xG': '0.5432764291763306',
#    'player': 'Serhou Guirassy',
#    'h_a': 'h',
#    'player_id': '3738',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Karim Adeyemi',
#    'lastAction': 'Pass'},
#   {'id': '590366',
#    'minute': '66',
#    'result': 'SavedShot',
#    'X': '0.9219999694824219',
#    'Y': '0.525',
#    'xG': '0.5830580592155457',
#    'player': 'Serhou Guirassy',
#    'h_a': 'h',
#    'player_id': '3738',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '590369',
#    'minute': '89',
#    'result': 'BlockedShot',
#    'X': '0.8440000152587891',
#    'Y': '0.5479999923706055',
#    'xG': '0.08599820733070374',
#    'player': 'Maximilian Beier',
#    'h_a': 'h',
#    'player_id': '8137',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '590370',
#    'minute': '92',
#    'result': 'Goal',
#    'X': '0.885',
#    'Y': '0.5',
#    'xG': '0.75777667760849',
#    'player': 'Emre Can',
#    'h_a': 'h',
#    'player_id': '604',
#    'situation': 'Penalty',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'}],
#  'a': [{'id': '590351',
#    'minute': '18',
#    'result': 'SavedShot',
#    'X': '0.7440000152587891',
#    'Y': '0.49900001525878906',
#    'xG': '0.019263489171862602',
#    'player': 'Léo Scienza',
#    'h_a': 'a',
#    'player_id': '12986',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': None,
#    'lastAction': 'Dispossessed'},
#   {'id': '590352',
#    'minute': '20',
#    'result': 'BlockedShot',
#    'X': '0.825',
#    'Y': '0.7090000152587891',
#    'xG': '0.09373574703931808',
#    'player': 'Léo Scienza',
#    'h_a': 'a',
#    'player_id': '12986',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Marvin Pieringer',
#    'lastAction': 'LayOff'},
#   {'id': '590353',
#    'minute': '23',
#    'result': 'BlockedShot',
#    'X': '0.775',
#    'Y': '0.51',
#    'xG': '0.015238136053085327',
#    'player': 'Jonas Föhrenbach',
#    'h_a': 'a',
#    'player_id': '5347',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Lennard Maloney',
#    'lastAction': 'HeadPass'},
#   {'id': '590354',
#    'minute': '35',
#    'result': 'SavedShot',
#    'X': '0.9109999847412109',
#    'Y': '0.500999984741211',
#    'xG': '0.2738282382488251',
#    'player': 'Marvin Pieringer',
#    'h_a': 'a',
#    'player_id': '11856',
#    'situation': 'SetPiece',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Léo Scienza',
#    'lastAction': 'Cross'},
#   {'id': '590356',
#    'minute': '38',
#    'result': 'Goal',
#    'X': '0.9259999847412109',
#    'Y': '0.49700000762939456',
#    'xG': '0.14551830291748047',
#    'player': 'Marvin Pieringer',
#    'h_a': 'a',
#    'player_id': '11856',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Omar Traoré',
#    'lastAction': 'Cross'},
#   {'id': '590359',
#    'minute': '46',
#    'result': 'MissedShots',
#    'X': '0.9119999694824219',
#    'Y': '0.705',
#    'xG': '0.05068356171250343',
#    'player': 'Paul Wanner',
#    'h_a': 'a',
#    'player_id': '10245',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Jan Schöppner',
#    'lastAction': 'Pass'},
#   {'id': '590362',
#    'minute': '57',
#    'result': 'BlockedShot',
#    'X': '0.8619999694824219',
#    'Y': '0.6880000305175781',
#    'xG': '0.048226162791252136',
#    'player': 'Léo Scienza',
#    'h_a': 'a',
#    'player_id': '12986',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Paul Wanner',
#    'lastAction': 'Pass'},
#   {'id': '590364',
#    'minute': '62',
#    'result': 'BlockedShot',
#    'X': '0.8430000305175781',
#    'Y': '0.565',
#    'xG': '0.06455931812524796',
#    'player': 'Léo Scienza',
#    'h_a': 'a',
#    'player_id': '12986',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Marvin Pieringer',
#    'lastAction': 'BallTouch'},
#   {'id': '590365',
#    'minute': '63',
#    'result': 'BlockedShot',
#    'X': '0.875999984741211',
#    'Y': '0.5540000152587891',
#    'xG': '0.07842864096164703',
#    'player': 'Léo Scienza',
#    'h_a': 'a',
#    'player_id': '12986',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '590367',
#    'minute': '73',
#    'result': 'Goal',
#    'X': '0.885',
#    'Y': '0.5',
#    'xG': '0.75777667760849',
#    'player': 'Maximilian Breunig',
#    'h_a': 'a',
#    'player_id': '11849',
#    'situation': 'Penalty',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '590368',
#    'minute': '85',
#    'result': 'MissedShots',
#    'X': '0.9230000305175782',
#    'Y': '0.654000015258789',
#    'xG': '0.07186885178089142',
#    'player': 'Jonas Föhrenbach',
#    'h_a': 'a',
#    'player_id': '5347',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '27760',
#    'h_team': 'Borussia Dortmund',
#    'a_team': 'FC Heidenheim',
#    'h_goals': '4',
#    'a_goals': '2',
#    'date': '2024-09-13 18:30:00',
#    'player_assisted': 'Mikkel Kaufmann',
#    'lastAction': 'Pass'}]}

# %%
h_df = pd.DataFrame(data['h'])

# %%
h_df
# Out:
#         id minute       result                   X                    Y  \
# 0   590347      2    SavedShot  0.8930000305175781  0.36200000762939455
# 1   590348      5  MissedShots  0.7959999847412109  0.40099998474121096
# 2   590349     10         Goal  0.8230000305175781                 0.51
# 3   590350     16         Goal               0.915                 0.65
# 4   590355     36  BlockedShot  0.8590000152587891   0.7030000305175781
# 5   590357     40         Goal  0.8619999694824219   0.5159999847412109
# 6   590358     44  BlockedShot               0.845  0.27100000381469724
# 7   590360     48  BlockedShot   0.894000015258789   0.4470000076293945
# 8   590361     51  MissedShots               0.845  0.47900001525878905
# 9   590363     58  MissedShots   0.909000015258789   0.4909999847412109
# 10  590366     66    SavedShot  0.9219999694824219                0.525
# 11  590369     89  BlockedShot  0.8440000152587891   0.5479999923706055
# 12  590370     92         Goal               0.885                  0.5
#
#                       xG            player h_a player_id   situation season  \
# 0   0.011930749751627445   Ramy Bensebaini   h      3349    SetPiece   2024
# 1   0.040396686643362045       Pascal Groß   h       239    OpenPlay   2024
# 2    0.07171561568975449     Donyell Malen   h      9749    OpenPlay   2024
# 3    0.34929072856903076     Karim Adeyemi   h     10772    OpenPlay   2024
# 4    0.08351726084947586   Serhou Guirassy   h      3738    OpenPlay   2024
# 5    0.11208920180797577     Karim Adeyemi   h     10772    OpenPlay   2024
# 6    0.02453427016735077     Donyell Malen   h      9749    SetPiece   2024
# 7    0.05760763958096504   Serhou Guirassy   h      3738  FromCorner   2024
# 8    0.11947015672922134     Donyell Malen   h      9749    OpenPlay   2024
# 9     0.5432764291763306   Serhou Guirassy   h      3738    OpenPlay   2024
# 10    0.5830580592155457   Serhou Guirassy   h      3738    OpenPlay   2024
# 11   0.08599820733070374  Maximilian Beier   h      8137    OpenPlay   2024
# 12      0.75777667760849          Emre Can   h       604     Penalty   2024
#
#      shotType match_id             h_team         a_team h_goals a_goals  \
# 0        Head    27760  Borussia Dortmund  FC Heidenheim       4       2
# 1   RightFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 2   RightFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 3   RightFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 4   RightFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 5   RightFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 6   RightFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 7   RightFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 8   RightFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 9    LeftFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 10  RightFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 11   LeftFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
# 12  RightFoot    27760  Borussia Dortmund  FC Heidenheim       4       2
#
#                    date player_assisted lastAction
# 0   2024-09-13 18:30:00            None     Aerial
# 1   2024-09-13 18:30:00  Julian Ryerson  BallTouch
# 2   2024-09-13 18:30:00   Karim Adeyemi       Pass
# 3   2024-09-13 18:30:00   Julian Brandt       Pass
# 4   2024-09-13 18:30:00    Felix Nmecha    Chipped
# 5   2024-09-13 18:30:00  Julian Ryerson       Pass
# 6   2024-09-13 18:30:00   Julian Brandt       Pass
# 7   2024-09-13 18:30:00     Pascal Groß      Cross
# 8   2024-09-13 18:30:00   Karim Adeyemi       Pass
# 9   2024-09-13 18:30:00   Karim Adeyemi       Pass
# 10  2024-09-13 18:30:00            None       None
# 11  2024-09-13 18:30:00            None       None
# 12  2024-09-13 18:30:00            None   Standard
